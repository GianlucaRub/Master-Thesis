# %%
import networkx as nx
from pykeen.pipeline import pipeline
from pykeen.datasets import Nations, get_dataset
import matplotlib.pyplot as plt
import matplotlib as mpl
import torch
from pykeen.models import predict
import json

# %%
from pykeen.hpo import hpo_pipeline
import os
NATIONS_TRAIN_PATH = "397d8cae76d1c0a7.tsv"
NATIONS_TEST_PATH = "944c8368543f21fb.tsv"
NATIONS_VALIDATE_PATH = "f78363e3cc31c563.tsv"

pipeline_result = pipeline(
#     n_trials=3,  # you probably want more than this
    training=NATIONS_TRAIN_PATH,
    testing=NATIONS_TEST_PATH,
    validation=NATIONS_VALIDATE_PATH,
    model='TransE',
    epochs=5,  # short epochs for testing - you should go higher
)
pipeline_result.save_to_directory(os.getcwd()+'/prova_deathstarbench')
# Out:
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 597307975.
# WARNING:pykeen.utils:No cuda devices were available. The model runs on CPU
# INFO:pykeen.pipeline.api:Using device: None
# WARNING:pykeen.triples.triples_factory:You're trying to map triples with 2 entities and 3 relations that are not in the training set. These triples will be excluded from the mapping.
# WARNING:pykeen.triples.triples_factory:In total 5 from 33 triples were filtered out
# WARNING:pykeen.triples.triples_factory:You're trying to map triples with 3 entities and 4 relations that are not in the training set. These triples will be excluded from the mapping.
# WARNING:pykeen.triples.triples_factory:In total 7 from 33 triples were filtered out
# Training epochs on cpu:   0%|          | 0/5 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|          | 0/1 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/1 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/1 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/1 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/1 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu:   0%|          | 0.00/28.0 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.05s seconds
# INFO:pykeen.triples.triples_factory:Stored TriplesFactory(num_entities=34, num_relations=20, create_inverse_triples=False, num_triples=33, path="C:\Users\gianl\OneDrive - Politecnico di Milano\Master Thesis\prove\deathstarbench_traces\397d8cae76d1c0a7.tsv") to file:///C:/Users/gianl/OneDrive%20-%20Politecnico%20di%20Milano/Master%20Thesis/prove/deathstarbench_traces/prova_deathstarbench/training_triples
# INFO:pykeen.pipeline.api:Saved to directory: file:///C:/Users/gianl/OneDrive%20-%20Politecnico%20di%20Milano/Master%20Thesis/prove/deathstarbench_traces/prova_deathstarbench

# %%
# pipeline_result = pipeline(
#     dataset='Nations',
#     model='TransE',
# )
# pipeline_result.save_to_directory('/nations_transe')

# %%
pipeline_result.plot_losses()
# Out:
# <AxesSubplot:title={'center':'Losses Plot'}, xlabel='Epoch', ylabel='marginranking Loss'>

# %%
pipeline_result.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pipeline_result.plot()
#
# File ~\anaconda3\envs\MasterThesis\lib\site-packages\pykeen\pipeline\api.py:365, in PipelineResult.plot(self, **kwargs)
#     358 """Plot all plots.
#     359
#     360 :param kwargs: The keyword arguments passed to :func:`pykeen.pipeline_plot.plot`
#     361 :returns: The axis
#     362 """
#     363 from .plot_utils import plot
# --> 365 return plot(self, **kwargs)
#
# File ~\anaconda3\envs\MasterThesis\lib\site-packages\pykeen\pipeline\plot_utils.py:285, in plot(pipeline_result, er_kwargs, figsize)
#     282 fig, axes = plt.subplots(1, 2, figsize=figsize)
#     284 pipeline_result.plot_losses(ax=axes[0])
# --> 285 pipeline_result.plot_er(ax=axes[1], **(er_kwargs or {}))
#     287 plt.tight_layout()
#     288 return fig, axes
#
# File ~\anaconda3\envs\MasterThesis\lib\site-packages\pykeen\pipeline\api.py:355, in PipelineResult.plot_er(self, **kwargs)
#     343 """Plot the reduced entities and relation vectors in 2D.
#     344
#     345 :param kwargs: The keyword arguments passed to :func:`pykeen.pipeline.plot_utils.plot_er`
#    (...)
#     351     meaningful for translational distance models like TransE.
#     352 """
#     353 from .plot_utils import plot_er
# --> 355 return plot_er(self, **kwargs)
#
# File ~\anaconda3\envs\MasterThesis\lib\site-packages\pykeen\pipeline\plot_utils.py:146, in plot_er(pipeline_result, model, entities, relations, apply_limits, margin, plot_entities, plot_relations, annotation_x_offset, annotation_y_offset, entity_embedding_getter, relation_embedding_getter, ax, subtitle, **kwargs)
#     143     relation_embedding_getter = _default_relation_embedding_getter
#     145 if plot_relations and plot_entities:
# --> 146     e_embeddings, e_reduced = _reduce_embeddings(entity_embedding_getter(pipeline_result.model), reducer, fit=True)
#     147     r_embeddings, r_reduced = _reduce_embeddings(
#     148         relation_embedding_getter(pipeline_result.model),
#     149         reducer,
#     150         fit=False,
#     151     )
#     153     xmax = max(r_embeddings[:, 0].max(), e_embeddings[:, 0].max()) + margin
#
# File ~\anaconda3\envs\MasterThesis\lib\site-packages\pykeen\pipeline\plot_utils.py:59, in _default_entity_embedding_getter(m)
#      58 def _default_entity_embedding_getter(m) -> Embedding:
# ---> 59     x = m.entity_embeddings
#      60     assert isinstance(x, Embedding)
#      61     return x
#
# File ~\anaconda3\envs\MasterThesis\lib\site-packages\torch\nn\modules\module.py:1269, in Module.__getattr__(self, name)
#    1267     if name in modules:
#    1268         return modules[name]
# -> 1269 raise AttributeError("'{}' object has no attribute '{}'".format(
#    1270     type(self).__name__, name))
#
# AttributeError: 'TransE' object has no attribute 'entity_embeddings'

# %%
model = pipeline_result.model
# Predict tails
predicted_tails_df = predict.get_prediction_df(
    model=model, head_label=1, relation_label=10, triples_factory=pipeline_result.training,
)
# Predict relations
predicted_relations_df = predict.get_prediction_df(
    model=model, head_label="brazil", tail_label="uk", triples_factory=pipeline_result.training,
)
# Predict heads
predicted_heads_df = predict.get_prediction_df(
    model=model, relation_label="conferences", tail_label="brazil", triples_factory=pipeline_result.training
)
predicted_tails_df

# %%
# Score all triples (memory intensive)
predictions_df = predict.get_all_prediction_df(model, triples_factory=pipeline_result.training)

# %%
# Score top K triples (computationally expensive)
top_k_predictions_df = predict.get_all_prediction_df(model, k=150, triples_factory=pipeline_result.training)

# %%
# Score a given list of triples
score_df = predict.predict_triples_df(
    model=model,
    triples=[("brazil", "conferences", "uk"), ("brazil", "intergovorgs", "uk")],
    triples_factory=pipeline_result.training,
)
score_df

# %%
from pykeen.evaluation import evaluate, ClassificationEvaluator

# %%
results = evaluate(model=model,mapped_triples=pipeline_result.training.mapped_triples,evaluator = ClassificationEvaluator(),mode=None,additional_filter_triples=[pipeline_result.training.mapped_triples])

# %%
results.to_dict()

# %%
Nations().summarize()

# %%
nations_dataset = get_dataset(dataset='nations')
nations_training = nations_dataset.training
triples = nations_training.mapped_triples
triples_list = triples.tolist() # head, relation type, tail
pairs = list(map(lambda x: [x[0],x[2]],triples_list))
pairs

# %%
# Create a graph object
G = nx.Graph()

# Add the edges from the PyKEEN dataset
G.add_edges_from(pairs)

# Use NetworkX's built-in drawing function to visualize the graph
nx.draw(G)

# Import matplotlib library to show the graph
plt.show()

# %%
# Create a graph object
G = nx.Graph()

# Add the edges from the PyKEEN dataset
for triplet in triples_list:
    G.add_edge(triplet[0], triplet[2], label=triplet[1])

# Use NetworkX's built-in drawing function to visualize the graph
nx.draw(G)
pos = nx.spring_layout(G)

nx.draw_networkx_edge_labels(G,pos,edge_labels=nx.get_edge_attributes(G,'label'))

# Import matplotlib library to show the graph
plt.show()

# %%
cmap = mpl.cm.nipy_spectral
norm = mpl.colors.Normalize(vmin=1, vmax=55)

# Create a graph object
G = nx.Graph()

# Add the edges from the PyKEEN dataset
for triplet in triples_list:
    G.add_edge(triplet[0], triplet[2], color=cmap(norm(triplet[1])))
    
colors = nx.get_edge_attributes(G,'color').values()

# Use NetworkX's built-in drawing function to visualize the graph
nx.draw(G,edge_color = colors)


# Import matplotlib library to show the graph
plt.show()

# %%
triples_factory = Nations().training
entity_ids = torch.as_tensor(triples_factory.entities_to_ids(["china", "egypt"]))
relation_ids = torch.as_tensor(triples_factory.relations_to_ids(["independence", "embassy"]))

# %%
relation_ids
