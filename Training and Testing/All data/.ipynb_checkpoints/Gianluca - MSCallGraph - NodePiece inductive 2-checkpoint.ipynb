# %% [markdown]
# second version of training that uses aggregation mlp

# %%
from pykeen.pipeline import pipeline
from pykeen.datasets import Nations, get_dataset
import torch
from pykeen.evaluation import evaluate, RankBasedEvaluator
from pykeen.metrics.ranking import HitsAtK
import pandas as pd


import logging
from pathlib import Path

import click
import more_click
import torch
from pykeen.evaluation import RankBasedEvaluator
from pykeen.losses import NSSALoss,CrossEntropyLoss
from pykeen.models.inductive import InductiveNodePiece, InductiveNodePieceGNN
from pykeen.trackers import ConsoleResultTracker, WANDBResultTracker, FileResultTracker
from pykeen.training import SLCWATrainingLoop
from pykeen.typing import TESTING, TRAINING, VALIDATION
from pykeen.utils import resolve_device, set_random_seed
from torch.optim import Adam


from pykeen.metrics.ranking import HitsAtK

from pathlib import Path

from pykeen.datasets.inductive.base import DisjointInductivePathDataset
from typing_extensions import Literal
import os
from pykeen.hpo import hpo_pipeline
from pykeen.triples import TriplesFactory
from pykeen.models import InductiveNodePiece
from pykeen.typing import TESTING, TRAINING, VALIDATION

import time

import platform

import sys

import cpuinfo

import psutil

import subprocess

import zipfile

seed = 1234

# %%
class InductiveLPDataset(DisjointInductivePathDataset):
    """An inductive link prediction dataset for the ILPC 2022 Challenge."""

    
    
    
    def __init__(self , **kwargs):
        """Initialize the inductive link prediction dataset.

        :param size: "small" or "large"
        :param kwargs: keyword arguments to forward to the base dataset class, cf. DisjointInductivePathDataset
        """
        DATA_TYPE = "_fully_inductive.tsv"
        TRAIN_PATH = "MSCallGraph_train" + DATA_TYPE
        TEST_PATH = "MSCallGraph_test" + DATA_TYPE
        VALIDATE_PATH = "MSCallGraph_validation" + DATA_TYPE
        INFERENCE_PATH = "MSCallGraph_inference" + DATA_TYPE


        super().__init__(
            transductive_training_path=os.getcwd()+"/"+TRAIN_PATH,
            inductive_inference_path=os.getcwd()+"/"+INFERENCE_PATH,
            inductive_validation_path=os.getcwd()+"/"+VALIDATE_PATH,
            inductive_testing_path=os.getcwd()+"/"+TEST_PATH,
            create_inverse_triples=True,
            eager=True,
            **kwargs
        )

# %%
def show_metrics(dictionary,model_name,csv_name):
    for key in dictionary.keys():
        print(key)
        df = pd.DataFrame(dictionary[key])
        df.to_csv(f"{model_name}/{model_name}_{csv_name}_{key}.csv")
        print(df)

# %%
dataset = InductiveLPDataset()

# %%
model_name = 'nodepiece_inductive_2'

# %%
tracker = ConsoleResultTracker()

# %%
loss = NSSALoss() #used by RotatE and NodePiece
num_tokens = 20
embedding_dim = 200

# %%
model = InductiveNodePiece(
        triples_factory=dataset.transductive_training,
        inference_factory=dataset.inductive_inference,
        random_seed = seed,
        loss = loss,
        num_tokens = num_tokens,
        embedding_dim = embedding_dim,
        aggregation = "mlp"
    ).to(resolve_device())
print(f"Number of parameters: {sum(p.numel() for p in model.parameters())}")
print(f"Space occupied: {model.num_parameter_bytes} bytes")
# Out:
# sampling:   0%|          | 0.00/9.06k [00:00<?, ?it/s]
# No symbolic computation of output shape.
# sampling:   0%|          | 0.00/3.79k [00:00<?, ?it/s]
# No symbolic computation of output shape.
# Number of parameters: 1683200
# Space occupied: 6732800 bytes

# %%
directory = model_name

if not os.path.exists(directory):
    os.makedirs(directory)
    print(f'Directory {directory} created successfully!')
else:
    print(f'Directory {directory} already exists.')
# Out:
# Directory nodepiece_inductive_2 created successfully!

# %%
learning_rate = 1e-3
optimizer = Adam(params=model.parameters(), lr=learning_rate)
num_epochs = 2000
patience = 20

# %%
metrics = ['meanreciprocalrank', HitsAtK(1),
                 HitsAtK(3), HitsAtK(5), HitsAtK(10)]

train_evaluator = RankBasedEvaluator(
        mode=TRAINING,
        metrics=metrics,
        add_defaults=False,
    )
valid_evaluator = RankBasedEvaluator(
        mode=VALIDATION,
        metrics=metrics,
        add_defaults=False,
    )
test_evaluator = RankBasedEvaluator(
        mode=TESTING,
        metrics = metrics,
        add_defaults=False
    )

# %%
from pykeen.stoppers import EarlyStopper

stopper = EarlyStopper(
    model = model,
    metric='meanreciprocalrank',
    patience=patience,
    frequency=1,
    evaluator = valid_evaluator,
    training_triples_factory = dataset.inductive_inference,
    evaluation_triples_factory = dataset.inductive_validation,
    result_tracker = tracker

)

# %%
# default training regime is negative sampling (SLCWA)
# you can also use the 1-N regime with the LCWATrainingLoop
# the LCWA loop does not need negative sampling kwargs, but accepts label_smoothing in the .train() method
training_loop = SLCWATrainingLoop(
        triples_factory=dataset.transductive_training,
        model=model,
        mode=TRAINING,  # must be specified for the inductive setup
        result_tracker=tracker,
        optimizer=optimizer
)

# %%
training_start = time.time()
train_epoch =  training_loop.train(
        triples_factory=dataset.transductive_training,
        num_epochs=num_epochs,
        stopper = stopper
        
    )
training_duration = time.time() - training_start
# Out:
# Training epochs on cuda:0:   0%|          | 0/2000 [00:00<?, ?epoch/s]
# Training batches on cuda:0:   0%|          | 0/12 [00:00<?, ?batch/s]
# Step: 1
# Metric: loss = 13.936063488324484
# Step: 1
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.001726448374744672
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.0366779739701912
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.019202211172467936
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.0015338140074163675
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.036632511764764786
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.019083164632320404
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.001447303256466358
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.036589315129378686
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.019018309192922526
# Metric: validation.head.optimistic.hits_at_1 = 0.0006395906619763352
# Metric: validation.tail.optimistic.hits_at_1 = 0.020147105852254557
# Metric: validation.both.optimistic.hits_at_1 = 0.010393348257115445
# Metric: validation.head.realistic.hits_at_1 = 0.0006395906619763352
# Metric: validation.tail.realistic.hits_at_1 = 0.020147105852254557
# Metric: validation.both.realistic.hits_at_1 = 0.010393348257115445
# Metric: validation.head.pessimistic.hits_at_1 = 0.0006395906619763352
# Metric: validation.tail.pessimistic.hits_at_1 = 0.020147105852254557
# Metric: validation.both.pessimistic.hits_at_1 = 0.010393348257115445
# Metric: validation.head.optimistic.hits_at_3 = 0.0006395906619763352
# Metric: validation.tail.optimistic.hits_at_3 = 0.029740965781899584
# Metric: validation.both.optimistic.hits_at_3 = 0.015190278221937959
# Metric: validation.head.realistic.hits_at_3 = 0.0006395906619763352
# Metric: validation.tail.realistic.hits_at_3 = 0.029740965781899584
# Metric: validation.both.realistic.hits_at_3 = 0.015190278221937959
# Metric: validation.head.pessimistic.hits_at_3 = 0.0006395906619763352
# Metric: validation.tail.pessimistic.hits_at_3 = 0.029740965781899584
# Metric: validation.both.pessimistic.hits_at_3 = 0.015190278221937959
# Metric: validation.head.optimistic.hits_at_5 = 0.0006395906619763352
# Metric: validation.tail.optimistic.hits_at_5 = 0.032619123760793095
# Metric: validation.both.optimistic.hits_at_5 = 0.016629357211384713
# Metric: validation.head.realistic.hits_at_5 = 0.0006395906619763352
# Metric: validation.tail.realistic.hits_at_5 = 0.032619123760793095
# Metric: validation.both.realistic.hits_at_5 = 0.016629357211384713
# Metric: validation.head.pessimistic.hits_at_5 = 0.0006395906619763352
# Metric: validation.tail.pessimistic.hits_at_5 = 0.032619123760793095
# Metric: validation.both.pessimistic.hits_at_5 = 0.016629357211384713
# Metric: validation.head.optimistic.hits_at_10 = 0.0006395906619763352
# Metric: validation.tail.optimistic.hits_at_10 = 0.04605052766229613
# Metric: validation.both.optimistic.hits_at_10 = 0.023345059162136233
# Metric: validation.head.realistic.hits_at_10 = 0.0006395906619763352
# Metric: validation.tail.realistic.hits_at_10 = 0.04605052766229613
# Metric: validation.both.realistic.hits_at_10 = 0.023345059162136233
# Metric: validation.head.pessimistic.hits_at_10 = 0.0006395906619763352
# Metric: validation.tail.pessimistic.hits_at_10 = 0.04605052766229613
# Metric: validation.both.pessimistic.hits_at_10 = 0.023345059162136233
# Training batches on cuda:0:   0%|          | 0/12 [00:00<?, ?batch/s]
# Step: 2
# Metric: loss = 1.1692130366961162
# Step: 2
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.011218383236620968
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.03240926764992323
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.0218138254432721
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.011018582619726658
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.032366760075092316
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.02169267274439335
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.010922966146544567
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.03232624345582315
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.021624604801183854
# Metric: validation.head.optimistic.hits_at_1 = 0.0031979533098816758
# Metric: validation.tail.optimistic.hits_at_1 = 0.009913655260633194
# Metric: validation.both.optimistic.hits_at_1 = 0.006555804285257435
# Metric: validation.head.realistic.hits_at_1 = 0.0031979533098816758
# Metric: validation.tail.realistic.hits_at_1 = 0.009913655260633194
# Metric: validation.both.realistic.hits_at_1 = 0.006555804285257435
# Metric: validation.head.pessimistic.hits_at_1 = 0.0031979533098816758
# Metric: validation.tail.pessimistic.hits_at_1 = 0.009913655260633194
# Metric: validation.both.pessimistic.hits_at_1 = 0.006555804285257435
# Metric: validation.head.optimistic.hits_at_3 = 0.012152222577550368
# Metric: validation.tail.optimistic.hits_at_3 = 0.025903421810041575
# Metric: validation.both.optimistic.hits_at_3 = 0.019027822193795972
# Metric: validation.head.realistic.hits_at_3 = 0.012152222577550368
# Metric: validation.tail.realistic.hits_at_3 = 0.025903421810041575
# Metric: validation.both.realistic.hits_at_3 = 0.019027822193795972
# Metric: validation.head.pessimistic.hits_at_3 = 0.012152222577550368
# Metric: validation.tail.pessimistic.hits_at_3 = 0.025903421810041575
# Metric: validation.both.pessimistic.hits_at_3 = 0.019027822193795972
# Metric: validation.head.optimistic.hits_at_5 = 0.014070994563479372
# Metric: validation.tail.optimistic.hits_at_5 = 0.03581707707067477
# Metric: validation.both.optimistic.hits_at_5 = 0.02494403581707707
# Metric: validation.head.realistic.hits_at_5 = 0.014070994563479372
# Metric: validation.tail.realistic.hits_at_5 = 0.03581707707067477
# Metric: validation.both.realistic.hits_at_5 = 0.02494403581707707
# Metric: validation.head.pessimistic.hits_at_5 = 0.014070994563479372
# Metric: validation.tail.pessimistic.hits_at_5 = 0.03581707707067477
# Metric: validation.both.pessimistic.hits_at_5 = 0.02494403581707707
# Metric: validation.head.optimistic.hits_at_10 = 0.015350175887432043
# Metric: validation.tail.optimistic.hits_at_10 = 0.040294211704509114
# Metric: validation.both.optimistic.hits_at_10 = 0.02782219379597058
# Metric: validation.head.realistic.hits_at_10 = 0.015350175887432043
# Metric: validation.tail.realistic.hits_at_10 = 0.040294211704509114
# Metric: validation.both.realistic.hits_at_10 = 0.02782219379597058
# Metric: validation.head.pessimistic.hits_at_10 = 0.015350175887432043
# Metric: validation.tail.pessimistic.hits_at_10 = 0.040294211704509114
# Metric: validation.both.pessimistic.hits_at_10 = 0.02782219379597058
# Training batches on cuda:0:   0%|          | 0/12 [00:00<?, ?batch/s]
# Step: 3
# Metric: loss = 0.8488643517096838
# Step: 3
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.009323169832702365
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.03380217578909246
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.021562672810897413
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.009090648964047432
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.033470723778009415
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.021280687302350998
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.008966923415684735
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.033179495104935536
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.021073209260310134
# Metric: validation.head.optimistic.hits_at_1 = 0.0025583626479053407
# Metric: validation.tail.optimistic.hits_at_1 = 0.009913655260633194
# Metric: validation.both.optimistic.hits_at_1 = 0.006236008954269267
# Metric: validation.head.realistic.hits_at_1 = 0.0025583626479053407
# Metric: validation.tail.realistic.hits_at_1 = 0.009913655260633194
# Metric: validation.both.realistic.hits_at_1 = 0.006236008954269267
# Metric: validation.head.pessimistic.hits_at_1 = 0.0025583626479053407
# Metric: validation.tail.pessimistic.hits_at_1 = 0.009913655260633194
# Metric: validation.both.pessimistic.hits_at_1 = 0.006236008954269267
# Metric: validation.head.optimistic.hits_at_3 = 0.008954269267668692
# Metric: validation.tail.optimistic.hits_at_3 = 0.030060761112887753
# Metric: validation.both.optimistic.hits_at_3 = 0.019507515190278223
# Metric: validation.head.realistic.hits_at_3 = 0.008954269267668692
# Metric: validation.tail.realistic.hits_at_3 = 0.030060761112887753
# Metric: validation.both.realistic.hits_at_3 = 0.019507515190278223
# Metric: validation.head.pessimistic.hits_at_3 = 0.008954269267668692
# Metric: validation.tail.pessimistic.hits_at_3 = 0.030060761112887753
# Metric: validation.both.pessimistic.hits_at_3 = 0.019507515190278223
# Metric: validation.head.optimistic.hits_at_5 = 0.012791813239526703
# Metric: validation.tail.optimistic.hits_at_5 = 0.03581707707067477
# Metric: validation.both.optimistic.hits_at_5 = 0.024304445155100735
# Metric: validation.head.realistic.hits_at_5 = 0.012791813239526703
# Metric: validation.tail.realistic.hits_at_5 = 0.0354972817396866
# Metric: validation.both.realistic.hits_at_5 = 0.024144547489606653
# Metric: validation.head.pessimistic.hits_at_5 = 0.012791813239526703
# Metric: validation.tail.pessimistic.hits_at_5 = 0.0354972817396866
# Metric: validation.both.pessimistic.hits_at_5 = 0.024144547489606653
# Metric: validation.head.optimistic.hits_at_10 = 0.015350175887432043
# Metric: validation.tail.optimistic.hits_at_10 = 0.07483210745123121
# Metric: validation.both.optimistic.hits_at_10 = 0.045091141669331626
# Metric: validation.head.realistic.hits_at_10 = 0.015350175887432043
# Metric: validation.tail.realistic.hits_at_10 = 0.07483210745123121
# Metric: validation.both.realistic.hits_at_10 = 0.045091141669331626
# Metric: validation.head.pessimistic.hits_at_10 = 0.015350175887432043
# Metric: validation.tail.pessimistic.hits_at_10 = 0.07483210745123121
# Metric: validation.both.pessimistic.hits_at_10 = 0.045091141669331626
# Training batches on cuda:0:   0%|          | 0/12 [00:00<?, ?batch/s]
# Step: 4
# Metric: loss = 0.7402614305416743
# Step: 4
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.009836212433100561
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.02895012587172129
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.019393169152410922
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.009381596930325031
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.02861245162785053
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.01899702474474907
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.009185789333503032
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.0283592096167615
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.01877249947513226
# Metric: validation.head.optimistic.hits_at_1 = 0.0031979533098816758
# Metric: validation.tail.optimistic.hits_at_1 = 0.009593859929645027
# Metric: validation.both.optimistic.hits_at_1 = 0.0063959066197633516
# Metric: validation.head.realistic.hits_at_1 = 0.0031979533098816758
# Metric: validation.tail.realistic.hits_at_1 = 0.009593859929645027
# Metric: validation.both.realistic.hits_at_1 = 0.0063959066197633516
# Metric: validation.head.pessimistic.hits_at_1 = 0.0031979533098816758
# Metric: validation.tail.pessimistic.hits_at_1 = 0.009593859929645027
# Metric: validation.both.pessimistic.hits_at_1 = 0.0063959066197633516
# Metric: validation.head.optimistic.hits_at_3 = 0.009913655260633194
# Metric: validation.tail.optimistic.hits_at_3 = 0.01854812919731372
# Metric: validation.both.optimistic.hits_at_3 = 0.014230892228973457
# Metric: validation.head.realistic.hits_at_3 = 0.009913655260633194
# Metric: validation.tail.realistic.hits_at_3 = 0.01854812919731372
# Metric: validation.both.realistic.hits_at_3 = 0.014230892228973457
# Metric: validation.head.pessimistic.hits_at_3 = 0.009913655260633194
# Metric: validation.tail.pessimistic.hits_at_3 = 0.01854812919731372
# Metric: validation.both.pessimistic.hits_at_3 = 0.014230892228973457
# Metric: validation.head.optimistic.hits_at_5 = 0.013751199232491206
# Metric: validation.tail.optimistic.hits_at_5 = 0.03709625839462744
# Metric: validation.both.optimistic.hits_at_5 = 0.025423728813559324
# Metric: validation.head.realistic.hits_at_5 = 0.0118324272465622
# Metric: validation.tail.realistic.hits_at_5 = 0.03709625839462744
# Metric: validation.both.realistic.hits_at_5 = 0.024464342820594818
# Metric: validation.head.pessimistic.hits_at_5 = 0.0118324272465622
# Metric: validation.tail.pessimistic.hits_at_5 = 0.03709625839462744
# Metric: validation.both.pessimistic.hits_at_5 = 0.024464342820594818
# Metric: validation.head.optimistic.hits_at_10 = 0.013751199232491206
# Metric: validation.tail.optimistic.hits_at_10 = 0.06555804285257436
# Metric: validation.both.optimistic.hits_at_10 = 0.03965462104253278
# Metric: validation.head.realistic.hits_at_10 = 0.013751199232491206
# Metric: validation.tail.realistic.hits_at_10 = 0.06491845219059801
# Metric: validation.both.realistic.hits_at_10 = 0.03933482571154461
# Metric: validation.head.pessimistic.hits_at_10 = 0.0118324272465622
# Metric: validation.tail.pessimistic.hits_at_10 = 0.06491845219059801
# Metric: validation.both.pessimistic.hits_at_10 = 0.03837543971858011
# Training batches on cuda:0:   0%|          | 0/12 [00:00<?, ?batch/s]
# Step: 5
# Metric: loss = 0.6885590453942617
# Step: 5
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.010777417273005359
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.03395113567451835
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.022364276473761855
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.010549056343734264
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.03380352631211281
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.022176289930939674
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.01043215540713532
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.033679569252274326
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.022055862329704825
# Metric: validation.head.optimistic.hits_at_1 = 0.0031979533098816758
# Metric: validation.tail.optimistic.hits_at_1 = 0.007355292612727854
# Metric: validation.both.optimistic.hits_at_1 = 0.005276622961304765
# Metric: validation.head.realistic.hits_at_1 = 0.0031979533098816758
# Metric: validation.tail.realistic.hits_at_1 = 0.007355292612727854
# Metric: validation.both.realistic.hits_at_1 = 0.005276622961304765
# Metric: validation.head.pessimistic.hits_at_1 = 0.0031979533098816758
# Metric: validation.tail.pessimistic.hits_at_1 = 0.007355292612727854
# Metric: validation.both.pessimistic.hits_at_1 = 0.005276622961304765
# Metric: validation.head.optimistic.hits_at_3 = 0.012472017908538535
# Metric: validation.tail.optimistic.hits_at_3 = 0.028781579788935082
# Metric: validation.both.optimistic.hits_at_3 = 0.02062679884873681
# Metric: validation.head.realistic.hits_at_3 = 0.012472017908538535
# Metric: validation.tail.realistic.hits_at_3 = 0.028781579788935082
# Metric: validation.both.realistic.hits_at_3 = 0.02062679884873681
# Metric: validation.head.pessimistic.hits_at_3 = 0.012472017908538535
# Metric: validation.tail.pessimistic.hits_at_3 = 0.028781579788935082
# Metric: validation.both.pessimistic.hits_at_3 = 0.02062679884873681
# Metric: validation.head.optimistic.hits_at_5 = 0.01311160857051487
# Metric: validation.tail.optimistic.hits_at_5 = 0.03837543971858011
# Metric: validation.both.optimistic.hits_at_5 = 0.02574352414454749
# Metric: validation.head.realistic.hits_at_5 = 0.01311160857051487
# Metric: validation.tail.realistic.hits_at_5 = 0.03837543971858011
# Metric: validation.both.realistic.hits_at_5 = 0.02574352414454749
# Metric: validation.head.pessimistic.hits_at_5 = 0.01311160857051487
# Metric: validation.tail.pessimistic.hits_at_5 = 0.03837543971858011
# Metric: validation.both.pessimistic.hits_at_5 = 0.02574352414454749
# Metric: validation.head.optimistic.hits_at_10 = 0.014390789894467541
# Metric: validation.tail.optimistic.hits_at_10 = 0.0738727214582667
# Metric: validation.both.optimistic.hits_at_10 = 0.044131755676367124
# Metric: validation.head.realistic.hits_at_10 = 0.014390789894467541
# Metric: validation.tail.realistic.hits_at_10 = 0.0738727214582667
# Metric: validation.both.realistic.hits_at_10 = 0.044131755676367124
# Metric: validation.head.pessimistic.hits_at_10 = 0.014390789894467541
# Metric: validation.tail.pessimistic.hits_at_10 = 0.0738727214582667
# Metric: validation.both.pessimistic.hits_at_10 = 0.044131755676367124
# Training batches on cuda:0:   0%|          | 0/12 [00:00<?, ?batch/s]
# Step: 6
# Metric: loss = 0.633075217405955
# Step: 6
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.011953300894906451
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.036698726069799105
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.02432601348235278
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.01124742440879345
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.0354899987578392
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.02336871065199375
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.01108222832603774
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.03487167010972805
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.02297694921788289
# Metric: validation.head.optimistic.hits_at_1 = 0.003517748640869843
# Metric: validation.tail.optimistic.hits_at_1 = 0.007035497281739686
# Metric: validation.both.optimistic.hits_at_1 = 0.005276622961304765
# Metric: validation.head.realistic.hits_at_1 = 0.003517748640869843
# Metric: validation.tail.realistic.hits_at_1 = 0.007035497281739686
# Metric: validation.both.realistic.hits_at_1 = 0.005276622961304765
# Metric: validation.head.pessimistic.hits_at_1 = 0.003517748640869843
# Metric: validation.tail.pessimistic.hits_at_1 = 0.007035497281739686
# Metric: validation.both.pessimistic.hits_at_1 = 0.005276622961304765
# Metric: validation.head.optimistic.hits_at_3 = 0.012472017908538535
# Metric: validation.tail.optimistic.hits_at_3 = 0.021426287176207228
# Metric: validation.both.optimistic.hits_at_3 = 0.01694915254237288
# Metric: validation.head.realistic.hits_at_3 = 0.012472017908538535
# Metric: validation.tail.realistic.hits_at_3 = 0.021426287176207228
# Metric: validation.both.realistic.hits_at_3 = 0.01694915254237288
# Metric: validation.head.pessimistic.hits_at_3 = 0.012472017908538535
# Metric: validation.tail.pessimistic.hits_at_3 = 0.021426287176207228
# Metric: validation.both.pessimistic.hits_at_3 = 0.01694915254237288
# Metric: validation.head.optimistic.hits_at_5 = 0.013751199232491206
# Metric: validation.tail.optimistic.hits_at_5 = 0.05020786696514231
# Metric: validation.both.optimistic.hits_at_5 = 0.03197953309881676
# Metric: validation.head.realistic.hits_at_5 = 0.013751199232491206
# Metric: validation.tail.realistic.hits_at_5 = 0.05020786696514231
# Metric: validation.both.realistic.hits_at_5 = 0.03197953309881676
# Metric: validation.head.pessimistic.hits_at_5 = 0.013751199232491206
# Metric: validation.tail.pessimistic.hits_at_5 = 0.05020786696514231
# Metric: validation.both.pessimistic.hits_at_5 = 0.03197953309881676
# Metric: validation.head.optimistic.hits_at_10 = 0.017588743204349215
# Metric: validation.tail.optimistic.hits_at_10 = 0.08378637671889991
# Metric: validation.both.optimistic.hits_at_10 = 0.05068755996162456
# Metric: validation.head.realistic.hits_at_10 = 0.017588743204349215
# Metric: validation.tail.realistic.hits_at_10 = 0.07643108410617205
# Metric: validation.both.realistic.hits_at_10 = 0.04700991365526063
# Metric: validation.head.pessimistic.hits_at_10 = 0.017588743204349215
# Metric: validation.tail.pessimistic.hits_at_10 = 0.06683722417652702
# Metric: validation.both.pessimistic.hits_at_10 = 0.04221298369043812
# Training batches on cuda:0:   0%|          | 0/12 [00:00<?, ?batch/s]
# Step: 7
# Metric: loss = 0.5833791593710581
# Step: 7
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.43213946412887494
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.04737339743499308
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.239756430781934
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.011814865283668041
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.03928034007549286
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.02554759941995144
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.011446885434589622
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.03758456192234294
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.02451572367846628
# Metric: validation.head.optimistic.hits_at_1 = 0.42436840422129835
# Metric: validation.tail.optimistic.hits_at_1 = 0.009913655260633194
# Metric: validation.both.optimistic.hits_at_1 = 0.21714102974096577
# Metric: validation.head.realistic.hits_at_1 = 0.0063959066197633516
# Metric: validation.tail.realistic.hits_at_1 = 0.009913655260633194
# Metric: validation.both.realistic.hits_at_1 = 0.008154780940198274
# Metric: validation.head.pessimistic.hits_at_1 = 0.0063959066197633516
# Metric: validation.tail.pessimistic.hits_at_1 = 0.009913655260633194
# Metric: validation.both.pessimistic.hits_at_1 = 0.008154780940198274
# Metric: validation.head.optimistic.hits_at_3 = 0.4269267668692037
# Metric: validation.tail.optimistic.hits_at_3 = 0.048289094979213305
# Metric: validation.both.optimistic.hits_at_3 = 0.2376079309242085
# Metric: validation.head.realistic.hits_at_3 = 0.008954269267668692
# Metric: validation.tail.realistic.hits_at_3 = 0.024304445155100735
# Metric: validation.both.realistic.hits_at_3 = 0.016629357211384713
# Metric: validation.head.pessimistic.hits_at_3 = 0.008954269267668692
# Metric: validation.tail.pessimistic.hits_at_3 = 0.024304445155100735
# Metric: validation.both.pessimistic.hits_at_3 = 0.016629357211384713
# Metric: validation.head.optimistic.hits_at_5 = 0.42948512951710904
# Metric: validation.tail.optimistic.hits_at_5 = 0.060121522225775506
# Metric: validation.both.optimistic.hits_at_5 = 0.24480332587144227
# Metric: validation.head.realistic.hits_at_5 = 0.011192836584585865
# Metric: validation.tail.realistic.hits_at_5 = 0.03581707707067477
# Metric: validation.both.realistic.hits_at_5 = 0.023504956827630315
# Metric: validation.head.pessimistic.hits_at_5 = 0.011192836584585865
# Metric: validation.tail.pessimistic.hits_at_5 = 0.03581707707067477
# Metric: validation.both.pessimistic.hits_at_5 = 0.023504956827630315
# Metric: validation.head.optimistic.hits_at_10 = 0.4381196034537896
# Metric: validation.tail.optimistic.hits_at_10 = 0.09625839462743845
# Metric: validation.both.optimistic.hits_at_10 = 0.267188999040614
# Metric: validation.head.realistic.hits_at_10 = 0.017908538535337384
# Metric: validation.tail.realistic.hits_at_10 = 0.09625839462743845
# Metric: validation.both.realistic.hits_at_10 = 0.05708346658138791
# Metric: validation.head.pessimistic.hits_at_10 = 0.017588743204349215
# Metric: validation.tail.pessimistic.hits_at_10 = 0.07227374480332587
# Metric: validation.both.pessimistic.hits_at_10 = 0.044931244003837544
# Training batches on cuda:0:   0%|          | 0/12 [00:00<?, ?batch/s]
# Step: 8
# Metric: loss = 0.5351741760969162
# Step: 8
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.4961730620069659
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.048216206904978326
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.27219463445597214
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.012341286055743694
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.04107031598687172
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.02670580148696899
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.011374973809480519
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.03934887825094123
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.02536192603021087
# Metric: validation.head.optimistic.hits_at_1 = 0.4745762711864407
# Metric: validation.tail.optimistic.hits_at_1 = 0.012152222577550368
# Metric: validation.both.optimistic.hits_at_1 = 0.2433642468819955
# Metric: validation.head.realistic.hits_at_1 = 0.005756315957787016
# Metric: validation.tail.realistic.hits_at_1 = 0.0118324272465622
# Metric: validation.both.realistic.hits_at_1 = 0.008794371602174608
# Metric: validation.head.pessimistic.hits_at_1 = 0.005756315957787016
# Metric: validation.tail.pessimistic.hits_at_1 = 0.0118324272465622
# Metric: validation.both.pessimistic.hits_at_1 = 0.008794371602174608
# Metric: validation.head.optimistic.hits_at_3 = 0.49024624240486087
# Metric: validation.tail.optimistic.hits_at_3 = 0.04573073233130796
# Metric: validation.both.optimistic.hits_at_3 = 0.26798848736808445
# Metric: validation.head.realistic.hits_at_3 = 0.008314678605692356
# Metric: validation.tail.realistic.hits_at_3 = 0.026862807803006077
# Metric: validation.both.realistic.hits_at_3 = 0.017588743204349215
# Metric: validation.head.pessimistic.hits_at_3 = 0.008314678605692356
# Metric: validation.tail.pessimistic.hits_at_3 = 0.026862807803006077
# Metric: validation.both.pessimistic.hits_at_3 = 0.017588743204349215
# Metric: validation.head.optimistic.hits_at_5 = 0.4921650143907899
# Metric: validation.tail.optimistic.hits_at_5 = 0.062999680204669
# Metric: validation.both.optimistic.hits_at_5 = 0.27758234729772946
# Metric: validation.head.realistic.hits_at_5 = 0.010233450591621363
# Metric: validation.tail.realistic.hits_at_5 = 0.045091141669331626
# Metric: validation.both.realistic.hits_at_5 = 0.027662296130476494
# Metric: validation.head.pessimistic.hits_at_5 = 0.010233450591621363
# Metric: validation.tail.pessimistic.hits_at_5 = 0.044131755676367124
# Metric: validation.both.pessimistic.hits_at_5 = 0.027182603133994242
# Metric: validation.head.optimistic.hits_at_10 = 0.49856092101055327
# Metric: validation.tail.optimistic.hits_at_10 = 0.08570514870482891
# Metric: validation.both.optimistic.hits_at_10 = 0.2921330348576911
# Metric: validation.head.realistic.hits_at_10 = 0.018228333866325552
# Metric: validation.tail.realistic.hits_at_10 = 0.08250719539494723
# Metric: validation.both.realistic.hits_at_10 = 0.05036776463063639
# Metric: validation.head.pessimistic.hits_at_10 = 0.015350175887432043
# Metric: validation.tail.pessimistic.hits_at_10 = 0.08250719539494723
# Metric: validation.both.pessimistic.hits_at_10 = 0.048928685641189636
# Training batches on cuda:0:   0%|          | 0/12 [00:00<?, ?batch/s]
# Step: 9
# Metric: loss = 0.5100162525971731
# Step: 9
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.6511171380526195
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.04997398243698453
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.350545560244802
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.011600407771766186
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.04198693856596947
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.026793671771883965
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.010478518154204107
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.04031196662628276
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.025395242390243433
# Metric: validation.head.optimistic.hits_at_1 = 0.6418292292932524
# Metric: validation.tail.optimistic.hits_at_1 = 0.011512631915574032
# Metric: validation.both.optimistic.hits_at_1 = 0.32667093060441316
# Metric: validation.head.realistic.hits_at_1 = 0.003837543971858011
# Metric: validation.tail.realistic.hits_at_1 = 0.01055324592260953
# Metric: validation.both.realistic.hits_at_1 = 0.0071953949472337705
# Metric: validation.head.pessimistic.hits_at_1 = 0.003837543971858011
# Metric: validation.tail.pessimistic.hits_at_1 = 0.01055324592260953
# Metric: validation.both.pessimistic.hits_at_1 = 0.0071953949472337705
# Metric: validation.head.optimistic.hits_at_3 = 0.6491845219059802
# Metric: validation.tail.optimistic.hits_at_3 = 0.04924848097217781
# Metric: validation.both.optimistic.hits_at_3 = 0.349216501439079
# Metric: validation.head.realistic.hits_at_3 = 0.008634473936680525
# Metric: validation.tail.realistic.hits_at_3 = 0.02910137511992325
# Metric: validation.both.realistic.hits_at_3 = 0.018867924528301886
# Metric: validation.head.pessimistic.hits_at_3 = 0.008634473936680525
# Metric: validation.tail.pessimistic.hits_at_3 = 0.02910137511992325
# Metric: validation.both.pessimistic.hits_at_3 = 0.018867924528301886
# Metric: validation.head.optimistic.hits_at_5 = 0.6498241125679565
# Metric: validation.tail.optimistic.hits_at_5 = 0.06683722417652702
# Metric: validation.both.optimistic.hits_at_5 = 0.35833066837224176
# Metric: validation.head.realistic.hits_at_5 = 0.008954269267668692
# Metric: validation.tail.realistic.hits_at_5 = 0.048289094979213305
# Metric: validation.both.realistic.hits_at_5 = 0.028621682123441
# Metric: validation.head.pessimistic.hits_at_5 = 0.008954269267668692
# Metric: validation.tail.pessimistic.hits_at_5 = 0.046690118324272466
# Metric: validation.both.pessimistic.hits_at_5 = 0.02782219379597058
# Metric: validation.head.optimistic.hits_at_10 = 0.6555804285257435
# Metric: validation.tail.optimistic.hits_at_10 = 0.07930924208506555
# Metric: validation.both.optimistic.hits_at_10 = 0.36744483530540456
# Metric: validation.head.realistic.hits_at_10 = 0.016629357211384713
# Metric: validation.tail.realistic.hits_at_10 = 0.07611128877518389
# Metric: validation.both.realistic.hits_at_10 = 0.0463703229932843
# Metric: validation.head.pessimistic.hits_at_10 = 0.014070994563479372
# Metric: validation.tail.pessimistic.hits_at_10 = 0.06651742884553885
# Metric: validation.both.pessimistic.hits_at_10 = 0.040294211704509114
# Training batches on cuda:0:   0%|          | 0/12 [00:00<?, ?batch/s]
# Step: 10
# Metric: loss = 0.48911319176356
# Step: 10
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.6763939828695206
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.04688635930925477
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.3616401710893876
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.011089288629591465
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.036551978439092636
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.023820636793971058
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.009946228093551834
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.03479189958883162
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.022369063841191725
# Metric: validation.head.optimistic.hits_at_1 = 0.6693316277582347
# Metric: validation.tail.optimistic.hits_at_1 = 0.015350175887432043
# Metric: validation.both.optimistic.hits_at_1 = 0.3423409018228334
# Metric: validation.head.realistic.hits_at_1 = 0.003517748640869843
# Metric: validation.tail.realistic.hits_at_1 = 0.010233450591621363
# Metric: validation.both.realistic.hits_at_1 = 0.006875599616245603
# Metric: validation.head.pessimistic.hits_at_1 = 0.003517748640869843
# Metric: validation.tail.pessimistic.hits_at_1 = 0.010233450591621363
# Metric: validation.both.pessimistic.hits_at_1 = 0.006875599616245603
# Metric: validation.head.optimistic.hits_at_3 = 0.6766869203709626
# Metric: validation.tail.optimistic.hits_at_3 = 0.05148704828909498
# Metric: validation.both.optimistic.hits_at_3 = 0.3640869843300288
# Metric: validation.head.realistic.hits_at_3 = 0.008314678605692356
# Metric: validation.tail.realistic.hits_at_3 = 0.03197953309881676
# Metric: validation.both.realistic.hits_at_3 = 0.020147105852254557
# Metric: validation.head.pessimistic.hits_at_3 = 0.008314678605692356
# Metric: validation.tail.pessimistic.hits_at_3 = 0.03197953309881676
# Metric: validation.both.pessimistic.hits_at_3 = 0.020147105852254557
# Metric: validation.head.optimistic.hits_at_5 = 0.6776463063639271
# Metric: validation.tail.optimistic.hits_at_5 = 0.05884234090182283
# Metric: validation.both.optimistic.hits_at_5 = 0.36824432363287496
# Metric: validation.head.realistic.hits_at_5 = 0.00927406459865686
# Metric: validation.tail.realistic.hits_at_5 = 0.03613687240166293
# Metric: validation.both.realistic.hits_at_5 = 0.0227054685001599
# Metric: validation.head.pessimistic.hits_at_5 = 0.00927406459865686
# Metric: validation.tail.pessimistic.hits_at_5 = 0.0345378957467221
# Metric: validation.both.pessimistic.hits_at_5 = 0.02190598017268948
# Metric: validation.head.optimistic.hits_at_10 = 0.6824432363287496
# Metric: validation.tail.optimistic.hits_at_10 = 0.07483210745123121
# Metric: validation.both.optimistic.hits_at_10 = 0.3786376718899904
# Metric: validation.head.realistic.hits_at_10 = 0.016309561880396548
# Metric: validation.tail.realistic.hits_at_10 = 0.07483210745123121
# Metric: validation.both.realistic.hits_at_10 = 0.04557083466581388
# Metric: validation.head.pessimistic.hits_at_10 = 0.013751199232491206
# Metric: validation.tail.pessimistic.hits_at_10 = 0.05404541093700032
# Metric: validation.both.pessimistic.hits_at_10 = 0.03389830508474576
# Training batches on cuda:0:   0%|          | 0/12 [00:00<?, ?batch/s]
# Step: 11
# Metric: loss = 0.4727499609192212
# Step: 11
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.669145816357354
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.05263100107054629
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.36088840871395017
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.01103246957063675
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.04196609556674957
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.02649928256869316
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.009802401794169135
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.040192080363095864
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.0249972410786325
# Metric: validation.head.optimistic.hits_at_1 = 0.662296130476495
# Metric: validation.tail.optimistic.hits_at_1 = 0.016309561880396548
# Metric: validation.both.optimistic.hits_at_1 = 0.3393028461784458
# Metric: validation.head.realistic.hits_at_1 = 0.0031979533098816758
# Metric: validation.tail.realistic.hits_at_1 = 0.01055324592260953
# Metric: validation.both.realistic.hits_at_1 = 0.006875599616245603
# Metric: validation.head.pessimistic.hits_at_1 = 0.0031979533098816758
# Metric: validation.tail.pessimistic.hits_at_1 = 0.01055324592260953
# Metric: validation.both.pessimistic.hits_at_1 = 0.006875599616245603
# Metric: validation.head.optimistic.hits_at_3 = 0.6674128557723057
# Metric: validation.tail.optimistic.hits_at_3 = 0.05148704828909498
# Metric: validation.both.optimistic.hits_at_3 = 0.35944995203070035
# Metric: validation.head.realistic.hits_at_3 = 0.008634473936680525
# Metric: validation.tail.realistic.hits_at_3 = 0.03197953309881676
# Metric: validation.both.realistic.hits_at_3 = 0.02030700351774864
# Metric: validation.head.pessimistic.hits_at_3 = 0.008314678605692356
# Metric: validation.tail.pessimistic.hits_at_3 = 0.03197953309881676
# Metric: validation.both.pessimistic.hits_at_3 = 0.020147105852254557
# Metric: validation.head.optimistic.hits_at_5 = 0.6680524464342821
# Metric: validation.tail.optimistic.hits_at_5 = 0.06811640550047969
# Metric: validation.both.optimistic.hits_at_5 = 0.3680844259673809
# Metric: validation.head.realistic.hits_at_5 = 0.00927406459865686
# Metric: validation.tail.realistic.hits_at_5 = 0.04477134633834346
# Metric: validation.both.realistic.hits_at_5 = 0.02702270546850016
# Metric: validation.head.pessimistic.hits_at_5 = 0.00927406459865686
# Metric: validation.tail.pessimistic.hits_at_5 = 0.04381196034537896
# Metric: validation.both.pessimistic.hits_at_5 = 0.02654301247201791
# Metric: validation.head.optimistic.hits_at_10 = 0.6811640550047969
# Metric: validation.tail.optimistic.hits_at_10 = 0.09050207866965142
# Metric: validation.both.optimistic.hits_at_10 = 0.3858330668372242
# Metric: validation.head.realistic.hits_at_10 = 0.015350175887432043
# Metric: validation.tail.realistic.hits_at_10 = 0.09050207866965142
# Metric: validation.both.realistic.hits_at_10 = 0.052926127278541735
# Metric: validation.head.pessimistic.hits_at_10 = 0.013751199232491206
# Metric: validation.tail.pessimistic.hits_at_10 = 0.07035497281739686
# Metric: validation.both.pessimistic.hits_at_10 = 0.042053086024944036
# Training batches on cuda:0:   0%|          | 0/12 [00:00<?, ?batch/s]
# Step: 12
# Metric: loss = 0.45761721829573315
# Step: 12
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.6791433926050092
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.04990496238371099
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.36452417749436
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.010905476287007332
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.03853151202201843
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.024718496948480606
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.009652839200256374
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.0366665313230057
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.02315968526163104
# Metric: validation.head.optimistic.hits_at_1 = 0.6738087623920691
# Metric: validation.tail.optimistic.hits_at_1 = 0.018867924528301886
# Metric: validation.both.optimistic.hits_at_1 = 0.3463383434601855
# Metric: validation.head.realistic.hits_at_1 = 0.003517748640869843
# Metric: validation.tail.realistic.hits_at_1 = 0.009913655260633194
# Metric: validation.both.realistic.hits_at_1 = 0.006715701950751519
# Metric: validation.head.pessimistic.hits_at_1 = 0.003517748640869843
# Metric: validation.tail.pessimistic.hits_at_1 = 0.009913655260633194
# Metric: validation.both.pessimistic.hits_at_1 = 0.006715701950751519
# Metric: validation.head.optimistic.hits_at_3 = 0.6779661016949152
# Metric: validation.tail.optimistic.hits_at_3 = 0.03965462104253278
# Metric: validation.both.optimistic.hits_at_3 = 0.358810361368724
# Metric: validation.head.realistic.hits_at_3 = 0.007675087943716022
# Metric: validation.tail.realistic.hits_at_3 = 0.02078669651423089
# Metric: validation.both.realistic.hits_at_3 = 0.014230892228973457
# Metric: validation.head.pessimistic.hits_at_3 = 0.007675087943716022
# Metric: validation.tail.pessimistic.hits_at_3 = 0.02078669651423089
# Metric: validation.both.pessimistic.hits_at_3 = 0.014230892228973457
# Metric: validation.head.optimistic.hits_at_5 = 0.6792452830188679
# Metric: validation.tail.optimistic.hits_at_5 = 0.053725615606012155
# Metric: validation.both.optimistic.hits_at_5 = 0.36648544931244004
# Metric: validation.head.realistic.hits_at_5 = 0.009913655260633194
# Metric: validation.tail.realistic.hits_at_5 = 0.04381196034537896
# Metric: validation.both.realistic.hits_at_5 = 0.026862807803006077
# Metric: validation.head.pessimistic.hits_at_5 = 0.008954269267668692
# Metric: validation.tail.pessimistic.hits_at_5 = 0.034857691077710265
# Metric: validation.both.pessimistic.hits_at_5 = 0.02190598017268948
# Metric: validation.head.optimistic.hits_at_10 = 0.6814838503357851
# Metric: validation.tail.optimistic.hits_at_10 = 0.1016949152542373
# Metric: validation.both.optimistic.hits_at_10 = 0.3915893827950112
# Metric: validation.head.realistic.hits_at_10 = 0.014390789894467541
# Metric: validation.tail.realistic.hits_at_10 = 0.08666453469779341
# Metric: validation.both.realistic.hits_at_10 = 0.050527662296130475
# Metric: validation.head.pessimistic.hits_at_10 = 0.01311160857051487
# Metric: validation.tail.pessimistic.hits_at_10 = 0.07834985609210106
# Metric: validation.both.pessimistic.hits_at_10 = 0.04573073233130796
# Training batches on cuda:0:   0%|          | 0/12 [00:00<?, ?batch/s]
# Step: 13
# Metric: loss = 0.45048896223306656
# Step: 13
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.6780949596031918
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.05085573157809155
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.3644753455906417
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.010042806155979633
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.03870965167880058
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.02437623031437397
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.008778232396426477
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.0369224704090075
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.022850351402716986
# Metric: validation.head.optimistic.hits_at_1 = 0.6725295810681164
# Metric: validation.tail.optimistic.hits_at_1 = 0.020466901183242726
# Metric: validation.both.optimistic.hits_at_1 = 0.34649824112567956
# Metric: validation.head.realistic.hits_at_1 = 0.0025583626479053407
# Metric: validation.tail.realistic.hits_at_1 = 0.008954269267668692
# Metric: validation.both.realistic.hits_at_1 = 0.005756315957787016
# Metric: validation.head.pessimistic.hits_at_1 = 0.0025583626479053407
# Metric: validation.tail.pessimistic.hits_at_1 = 0.008954269267668692
# Metric: validation.both.pessimistic.hits_at_1 = 0.005756315957787016
# Metric: validation.head.optimistic.hits_at_3 = 0.6782858970259035
# Metric: validation.tail.optimistic.hits_at_3 = 0.05468500159897666
# Metric: validation.both.optimistic.hits_at_3 = 0.36648544931244004
# Metric: validation.head.realistic.hits_at_3 = 0.00799488327470419
# Metric: validation.tail.realistic.hits_at_3 = 0.03517748640869843
# Metric: validation.both.realistic.hits_at_3 = 0.02158618484170131
# Metric: validation.head.pessimistic.hits_at_3 = 0.00799488327470419
# Metric: validation.tail.pessimistic.hits_at_3 = 0.03517748640869843
# Metric: validation.both.pessimistic.hits_at_3 = 0.02158618484170131
# Metric: validation.head.optimistic.hits_at_5 = 0.6789254876878797
# Metric: validation.tail.optimistic.hits_at_5 = 0.059801726894787334
# Metric: validation.both.optimistic.hits_at_5 = 0.36936360729133355
# Metric: validation.head.realistic.hits_at_5 = 0.009593859929645027
# Metric: validation.tail.realistic.hits_at_5 = 0.0473297089862488
# Metric: validation.both.realistic.hits_at_5 = 0.028461784457946913
# Metric: validation.head.pessimistic.hits_at_5 = 0.008954269267668692
# Metric: validation.tail.pessimistic.hits_at_5 = 0.040294211704509114
# Metric: validation.both.pessimistic.hits_at_5 = 0.024624240486088904
# Metric: validation.head.optimistic.hits_at_10 = 0.6824432363287496
# Metric: validation.tail.optimistic.hits_at_10 = 0.09657818995842661
# Metric: validation.both.optimistic.hits_at_10 = 0.3895107131435881
# Metric: validation.head.realistic.hits_at_10 = 0.015030380556443877
# Metric: validation.tail.realistic.hits_at_10 = 0.0847457627118644
# Metric: validation.both.realistic.hits_at_10 = 0.04988807163415414
# Metric: validation.head.pessimistic.hits_at_10 = 0.01311160857051487
# Metric: validation.tail.pessimistic.hits_at_10 = 0.07323313079629037
# Metric: validation.both.pessimistic.hits_at_10 = 0.04317236968340262
# Training batches on cuda:0:   0%|          | 0/12 [00:00<?, ?batch/s]
# Step: 14
# Metric: loss = 0.4413221925497055
# Step: 14
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.6791135573693858
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.04901392914890586
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.36406374325914587
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.01022439543157816
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.037924353033304214
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.02407437562942505
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.008782436031533173
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.036092250279285705
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.02243734315540944
# Metric: validation.head.optimistic.hits_at_1 = 0.6728493763991046
# Metric: validation.tail.optimistic.hits_at_1 = 0.017908538535337384
# Metric: validation.both.optimistic.hits_at_1 = 0.34537895746722097
# Metric: validation.head.realistic.hits_at_1 = 0.0015989766549408379
# Metric: validation.tail.realistic.hits_at_1 = 0.007035497281739686
# Metric: validation.both.realistic.hits_at_1 = 0.0043172369683402625
# Metric: validation.head.pessimistic.hits_at_1 = 0.0015989766549408379
# Metric: validation.tail.pessimistic.hits_at_1 = 0.007035497281739686
# Metric: validation.both.pessimistic.hits_at_1 = 0.0043172369683402625
# Metric: validation.head.optimistic.hits_at_3 = 0.6782858970259035
# Metric: validation.tail.optimistic.hits_at_3 = 0.04061400703549728
# Metric: validation.both.optimistic.hits_at_3 = 0.35944995203070035
# Metric: validation.head.realistic.hits_at_3 = 0.006715701950751519
# Metric: validation.tail.realistic.hits_at_3 = 0.02622321714102974
# Metric: validation.both.realistic.hits_at_3 = 0.01646945954589063
# Metric: validation.head.pessimistic.hits_at_3 = 0.006715701950751519
# Metric: validation.tail.pessimistic.hits_at_3 = 0.02622321714102974
# Metric: validation.both.pessimistic.hits_at_3 = 0.01646945954589063
# Metric: validation.head.optimistic.hits_at_5 = 0.6798848736808443
# Metric: validation.tail.optimistic.hits_at_5 = 0.0700351774864087
# Metric: validation.both.optimistic.hits_at_5 = 0.37496002558362646
# Metric: validation.head.realistic.hits_at_5 = 0.013751199232491206
# Metric: validation.tail.realistic.hits_at_5 = 0.06172049888071634
# Metric: validation.both.realistic.hits_at_5 = 0.03773584905660377
# Metric: validation.head.pessimistic.hits_at_5 = 0.008314678605692356
# Metric: validation.tail.pessimistic.hits_at_5 = 0.05084745762711865
# Metric: validation.both.pessimistic.hits_at_5 = 0.029581068116405502
# Metric: validation.head.optimistic.hits_at_10 = 0.6897985289414774
# Metric: validation.tail.optimistic.hits_at_10 = 0.11160857051487048
# Metric: validation.both.optimistic.hits_at_10 = 0.40070354972817396
# Metric: validation.head.realistic.hits_at_10 = 0.01982731052126639
# Metric: validation.tail.realistic.hits_at_10 = 0.09401982731052126
# Metric: validation.both.realistic.hits_at_10 = 0.05692356891589383
# Metric: validation.head.pessimistic.hits_at_10 = 0.01982731052126639
# Metric: validation.tail.pessimistic.hits_at_10 = 0.08858330668372241
# Metric: validation.both.pessimistic.hits_at_10 = 0.0542053086024944
# Training batches on cuda:0:   0%|          | 0/12 [00:00<?, ?batch/s]
# Step: 15
# Metric: loss = 0.4357111106316249
# Step: 15
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.6795404493855361
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.05115396681326771
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.36534720809940185
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.010094133205711842
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.03726476430892944
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.023679446429014206
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.008675104143829375
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.03521304551053839
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.02194407482718388
# Metric: validation.head.optimistic.hits_at_1 = 0.6741285577230572
# Metric: validation.tail.optimistic.hits_at_1 = 0.02110649184521906
# Metric: validation.both.optimistic.hits_at_1 = 0.34761752478413815
# Metric: validation.head.realistic.hits_at_1 = 0.0025583626479053407
# Metric: validation.tail.realistic.hits_at_1 = 0.007035497281739686
# Metric: validation.both.realistic.hits_at_1 = 0.004796929964822514
# Metric: validation.head.pessimistic.hits_at_1 = 0.0025583626479053407
# Metric: validation.tail.pessimistic.hits_at_1 = 0.007035497281739686
# ...
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.011373373637648254
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.03825616394585121
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.02481476879174973
# Metric: validation.head.optimistic.hits_at_1 = 0.7057882954908858
# Metric: validation.tail.optimistic.hits_at_1 = 0.04157339302846178
# Metric: validation.both.optimistic.hits_at_1 = 0.3736808442596738
# Metric: validation.head.realistic.hits_at_1 = 0.002238567316917173
# Metric: validation.tail.realistic.hits_at_1 = 0.01726894787336105
# Metric: validation.both.realistic.hits_at_1 = 0.009753757595139112
# Metric: validation.head.pessimistic.hits_at_1 = 0.002238567316917173
# Metric: validation.tail.pessimistic.hits_at_1 = 0.01726894787336105
# Metric: validation.both.pessimistic.hits_at_1 = 0.009753757595139112
# Metric: validation.head.optimistic.hits_at_3 = 0.7134633834346018
# Metric: validation.tail.optimistic.hits_at_3 = 0.05564438759194116
# Metric: validation.both.optimistic.hits_at_3 = 0.3845538855132715
# Metric: validation.head.realistic.hits_at_3 = 0.009913655260633194
# Metric: validation.tail.realistic.hits_at_3 = 0.030700351774864087
# Metric: validation.both.realistic.hits_at_3 = 0.02030700351774864
# Metric: validation.head.pessimistic.hits_at_3 = 0.009913655260633194
# Metric: validation.tail.pessimistic.hits_at_3 = 0.030700351774864087
# Metric: validation.both.pessimistic.hits_at_3 = 0.02030700351774864
# Metric: validation.head.optimistic.hits_at_5 = 0.715701950751519
# Metric: validation.tail.optimistic.hits_at_5 = 0.059162136232811004
# Metric: validation.both.optimistic.hits_at_5 = 0.38743204349216503
# Metric: validation.head.realistic.hits_at_5 = 0.012472017908538535
# Metric: validation.tail.realistic.hits_at_5 = 0.0335785097537576
# Metric: validation.both.realistic.hits_at_5 = 0.023025263831148064
# Metric: validation.head.pessimistic.hits_at_5 = 0.012152222577550368
# Metric: validation.tail.pessimistic.hits_at_5 = 0.03197953309881676
# Metric: validation.both.pessimistic.hits_at_5 = 0.022065877838183562
# Metric: validation.head.optimistic.hits_at_10 = 0.7220978573712824
# Metric: validation.tail.optimistic.hits_at_10 = 0.06779661016949153
# Metric: validation.both.optimistic.hits_at_10 = 0.39494723377038693
# Metric: validation.head.realistic.hits_at_10 = 0.021426287176207228
# Metric: validation.tail.realistic.hits_at_10 = 0.06651742884553885
# Metric: validation.both.realistic.hits_at_10 = 0.04397185801087304
# Metric: validation.head.pessimistic.hits_at_10 = 0.020147105852254557
# Metric: validation.tail.pessimistic.hits_at_10 = 0.050527662296130475
# Metric: validation.both.pessimistic.hits_at_10 = 0.03533738407419252
# Training batches on cuda:0:   0%|          | 0/12 [00:00<?, ?batch/s]
# Step: 52
# Metric: loss = 0.3620243618885676
# Step: 52
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.7163082021070435
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.063833110295422
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.3900706562012327
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.013382446020841599
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.042303334921598434
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.027842888608574867
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.012013656624268797
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.03978523859656134
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.02589944761041507
# Metric: validation.head.optimistic.hits_at_1 = 0.708026862807803
# Metric: validation.tail.optimistic.hits_at_1 = 0.03901503038055645
# Metric: validation.both.optimistic.hits_at_1 = 0.3735209465941797
# Metric: validation.head.realistic.hits_at_1 = 0.0025583626479053407
# Metric: validation.tail.realistic.hits_at_1 = 0.014070994563479372
# Metric: validation.both.realistic.hits_at_1 = 0.008314678605692356
# Metric: validation.head.pessimistic.hits_at_1 = 0.0025583626479053407
# Metric: validation.tail.pessimistic.hits_at_1 = 0.014070994563479372
# Metric: validation.both.pessimistic.hits_at_1 = 0.008314678605692356
# Metric: validation.head.optimistic.hits_at_3 = 0.7134633834346018
# Metric: validation.tail.optimistic.hits_at_3 = 0.06651742884553885
# Metric: validation.both.optimistic.hits_at_3 = 0.38999040614007036
# Metric: validation.head.realistic.hits_at_3 = 0.00799488327470419
# Metric: validation.tail.realistic.hits_at_3 = 0.04157339302846178
# Metric: validation.both.realistic.hits_at_3 = 0.024784138151582986
# Metric: validation.head.pessimistic.hits_at_3 = 0.00799488327470419
# Metric: validation.tail.pessimistic.hits_at_3 = 0.04157339302846178
# Metric: validation.both.pessimistic.hits_at_3 = 0.024784138151582986
# Metric: validation.head.optimistic.hits_at_5 = 0.7179405180684362
# Metric: validation.tail.optimistic.hits_at_5 = 0.07259354013431404
# Metric: validation.both.optimistic.hits_at_5 = 0.3952670291013751
# Metric: validation.head.realistic.hits_at_5 = 0.014710585225455708
# Metric: validation.tail.realistic.hits_at_5 = 0.0463703229932843
# Metric: validation.both.realistic.hits_at_5 = 0.030540454109370004
# Metric: validation.head.pessimistic.hits_at_5 = 0.012472017908538535
# Metric: validation.tail.pessimistic.hits_at_5 = 0.044131755676367124
# Metric: validation.both.pessimistic.hits_at_5 = 0.02830188679245283
# Metric: validation.head.optimistic.hits_at_10 = 0.7294531499840102
# Metric: validation.tail.optimistic.hits_at_10 = 0.0809082187400064
# Metric: validation.both.optimistic.hits_at_10 = 0.4051806843620083
# Metric: validation.head.realistic.hits_at_10 = 0.028781579788935082
# Metric: validation.tail.realistic.hits_at_10 = 0.07898944675407739
# Metric: validation.both.realistic.hits_at_10 = 0.05388551327150624
# Metric: validation.head.pessimistic.hits_at_10 = 0.02750239846498241
# Metric: validation.tail.pessimistic.hits_at_10 = 0.05948193156379917
# Metric: validation.both.pessimistic.hits_at_10 = 0.043492165014390786
# Training batches on cuda:0:   0%|          | 0/12 [00:00<?, ?batch/s]
# Step: 53
# Metric: loss = 0.3638702904184659
# Step: 53
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.7149189933798764
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.06589022484379743
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.39040460911183694
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.013022261671721935
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.04530135914683343
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.02916181273758411
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.011728036755817229
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.042926850732635254
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.027327443744226243
# Metric: validation.head.optimistic.hits_at_1 = 0.7070674768148385
# Metric: validation.tail.optimistic.hits_at_1 = 0.03901503038055645
# Metric: validation.both.optimistic.hits_at_1 = 0.37304125359769746
# Metric: validation.head.realistic.hits_at_1 = 0.002878157978893508
# Metric: validation.tail.realistic.hits_at_1 = 0.015350175887432043
# Metric: validation.both.realistic.hits_at_1 = 0.009114166933162776
# Metric: validation.head.pessimistic.hits_at_1 = 0.002878157978893508
# Metric: validation.tail.pessimistic.hits_at_1 = 0.015350175887432043
# Metric: validation.both.pessimistic.hits_at_1 = 0.009114166933162776
# Metric: validation.head.optimistic.hits_at_3 = 0.7125039974416374
# Metric: validation.tail.optimistic.hits_at_3 = 0.060761112887751836
# Metric: validation.both.optimistic.hits_at_3 = 0.3866325551646946
# Metric: validation.head.realistic.hits_at_3 = 0.008314678605692356
# Metric: validation.tail.realistic.hits_at_3 = 0.036456667732651105
# Metric: validation.both.realistic.hits_at_3 = 0.02238567316917173
# Metric: validation.head.pessimistic.hits_at_3 = 0.008314678605692356
# Metric: validation.tail.pessimistic.hits_at_3 = 0.036456667732651105
# Metric: validation.both.pessimistic.hits_at_3 = 0.02238567316917173
# Metric: validation.head.optimistic.hits_at_5 = 0.7163415414134954
# Metric: validation.tail.optimistic.hits_at_5 = 0.06523824752158619
# Metric: validation.both.optimistic.hits_at_5 = 0.39078989446754075
# Metric: validation.head.realistic.hits_at_5 = 0.015030380556443877
# Metric: validation.tail.realistic.hits_at_5 = 0.04221298369043812
# Metric: validation.both.realistic.hits_at_5 = 0.028621682123441
# Metric: validation.head.pessimistic.hits_at_5 = 0.012152222577550368
# Metric: validation.tail.pessimistic.hits_at_5 = 0.04061400703549728
# Metric: validation.both.pessimistic.hits_at_5 = 0.026383114806523826
# Metric: validation.head.optimistic.hits_at_10 = 0.7278541733290694
# Metric: validation.tail.optimistic.hits_at_10 = 0.10777102654301247
# Metric: validation.both.optimistic.hits_at_10 = 0.4178125999360409
# Metric: validation.head.realistic.hits_at_10 = 0.025263831148065238
# Metric: validation.tail.realistic.hits_at_10 = 0.10201471058522546
# Metric: validation.both.realistic.hits_at_10 = 0.06363927086664535
# Metric: validation.head.pessimistic.hits_at_10 = 0.02494403581707707
# Metric: validation.tail.pessimistic.hits_at_10 = 0.08570514870482891
# Metric: validation.both.pessimistic.hits_at_10 = 0.05532459226095299
# Training batches on cuda:0:   0%|          | 0/12 [00:00<?, ?batch/s]
# Step: 54
# Metric: loss = 0.3756554077068965
# Step: 54
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.6920751728188457
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.0623829579344613
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.37722906537665346
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.012586485594511034
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.04129819944500923
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.02694234251976013
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.011389155048968081
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.03879752522701589
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.025093340137991985
# Metric: validation.head.optimistic.hits_at_1 = 0.6846818036456668
# Metric: validation.tail.optimistic.hits_at_1 = 0.038695235049568275
# Metric: validation.both.optimistic.hits_at_1 = 0.36168851934761753
# Metric: validation.head.realistic.hits_at_1 = 0.003517748640869843
# Metric: validation.tail.realistic.hits_at_1 = 0.014710585225455708
# Metric: validation.both.realistic.hits_at_1 = 0.009114166933162776
# Metric: validation.head.pessimistic.hits_at_1 = 0.003517748640869843
# Metric: validation.tail.pessimistic.hits_at_1 = 0.014710585225455708
# Metric: validation.both.pessimistic.hits_at_1 = 0.009114166933162776
# Metric: validation.head.optimistic.hits_at_3 = 0.686920370962584
# Metric: validation.tail.optimistic.hits_at_3 = 0.061400703549728174
# Metric: validation.both.optimistic.hits_at_3 = 0.37416053725615606
# Metric: validation.head.realistic.hits_at_3 = 0.005756315957787016
# Metric: validation.tail.realistic.hits_at_3 = 0.036456667732651105
# Metric: validation.both.realistic.hits_at_3 = 0.02110649184521906
# Metric: validation.head.pessimistic.hits_at_3 = 0.005756315957787016
# Metric: validation.tail.pessimistic.hits_at_3 = 0.036456667732651105
# Metric: validation.both.pessimistic.hits_at_3 = 0.02110649184521906
# Metric: validation.head.optimistic.hits_at_5 = 0.6917173009274065
# Metric: validation.tail.optimistic.hits_at_5 = 0.06523824752158619
# Metric: validation.both.optimistic.hits_at_5 = 0.3784777742244963
# Metric: validation.head.realistic.hits_at_5 = 0.01055324592260953
# Metric: validation.tail.realistic.hits_at_5 = 0.03933482571154461
# Metric: validation.both.realistic.hits_at_5 = 0.02494403581707707
# Metric: validation.head.pessimistic.hits_at_5 = 0.01055324592260953
# Metric: validation.tail.pessimistic.hits_at_5 = 0.038055644387591944
# Metric: validation.both.pessimistic.hits_at_5 = 0.024304445155100735
# Metric: validation.head.optimistic.hits_at_10 = 0.700351774864087
# Metric: validation.tail.optimistic.hits_at_10 = 0.07291333546530221
# Metric: validation.both.optimistic.hits_at_10 = 0.3866325551646946
# Metric: validation.head.realistic.hits_at_10 = 0.021746082507195393
# Metric: validation.tail.realistic.hits_at_10 = 0.07067476814838504
# Metric: validation.both.realistic.hits_at_10 = 0.04621042532779021
# Metric: validation.head.pessimistic.hits_at_10 = 0.020466901183242726
# Metric: validation.tail.pessimistic.hits_at_10 = 0.05468500159897666
# Metric: validation.both.pessimistic.hits_at_10 = 0.03757595139110969
# Training batches on cuda:0:   0%|          | 0/12 [00:00<?, ?batch/s]
# Step: 55
# Metric: loss = 0.3712865759929021
# Step: 55
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.6917446531082926
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.055775696363616845
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.37376017473595463
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.012265313416719437
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.03434399142861366
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.0233046505600214
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.011075072378529857
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.03180349328095008
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.021439282829739968
# Metric: validation.head.optimistic.hits_at_1 = 0.6846818036456668
# Metric: validation.tail.optimistic.hits_at_1 = 0.038055644387591944
# Metric: validation.both.optimistic.hits_at_1 = 0.36136872401662934
# Metric: validation.head.realistic.hits_at_1 = 0.003517748640869843
# Metric: validation.tail.realistic.hits_at_1 = 0.014070994563479372
# Metric: validation.both.realistic.hits_at_1 = 0.008794371602174608
# Metric: validation.head.pessimistic.hits_at_1 = 0.003517748640869843
# Metric: validation.tail.pessimistic.hits_at_1 = 0.014070994563479372
# Metric: validation.both.pessimistic.hits_at_1 = 0.008794371602174608
# Metric: validation.head.optimistic.hits_at_3 = 0.6859609849696194
# Metric: validation.tail.optimistic.hits_at_3 = 0.04988807163415414
# Metric: validation.both.optimistic.hits_at_3 = 0.36792452830188677
# Metric: validation.head.realistic.hits_at_3 = 0.004796929964822514
# Metric: validation.tail.realistic.hits_at_3 = 0.023025263831148064
# Metric: validation.both.realistic.hits_at_3 = 0.01391109689798529
# Metric: validation.head.pessimistic.hits_at_3 = 0.004796929964822514
# Metric: validation.tail.pessimistic.hits_at_3 = 0.023025263831148064
# Metric: validation.both.pessimistic.hits_at_3 = 0.01391109689798529
# Metric: validation.head.optimistic.hits_at_5 = 0.6933162775823473
# Metric: validation.tail.optimistic.hits_at_5 = 0.052126638951071315
# Metric: validation.both.optimistic.hits_at_5 = 0.3727214582667093
# Metric: validation.head.realistic.hits_at_5 = 0.012152222577550368
# Metric: validation.tail.realistic.hits_at_5 = 0.028141989126958745
# Metric: validation.both.realistic.hits_at_5 = 0.020147105852254557
# Metric: validation.head.pessimistic.hits_at_5 = 0.012152222577550368
# Metric: validation.tail.pessimistic.hits_at_5 = 0.024624240486088904
# Metric: validation.both.pessimistic.hits_at_5 = 0.018388231531819635
# Metric: validation.head.optimistic.hits_at_10 = 0.6997121842021107
# Metric: validation.tail.optimistic.hits_at_10 = 0.060121522225775506
# Metric: validation.both.optimistic.hits_at_10 = 0.3799168532139431
# Metric: validation.head.realistic.hits_at_10 = 0.02110649184521906
# Metric: validation.tail.realistic.hits_at_10 = 0.05788295490885833
# Metric: validation.both.realistic.hits_at_10 = 0.039494723377038694
# Metric: validation.head.pessimistic.hits_at_10 = 0.01982731052126639
# Metric: validation.tail.pessimistic.hits_at_10 = 0.04125359769747362
# Metric: validation.both.pessimistic.hits_at_10 = 0.030540454109370004

# %%
torch.save(model,f"{model_name}/model.pth")
model = torch.load(f"{model_name}/model.pth")

# %%
print("Train error per epoch:")
df = pd.DataFrame(train_epoch)
print(df)
df.to_csv(f"{model_name}/{model_name}_train_error_per_epoch.csv")
# Out:
# Train error per epoch:
#             0
# 0   13.936063
# 1    1.169213
# 2    0.848864
# 3    0.740261
# 4    0.688559
# 5    0.633075
# 6    0.583379
# 7    0.535174
# 8    0.510016
# 9    0.489113
# 10   0.472750
# 11   0.457617
# 12   0.450489
# 13   0.441322
# 14   0.435711
# 15   0.428196
# 16   0.425377
# 17   0.419690
# 18   0.414642
# 19   0.435817
# 20   0.414560
# 21   0.410659
# 22   0.402583
# 23   0.605001
# 24   0.593615
# 25   0.469207
# 26   0.421530
# 27   0.404054
# 28   0.397219
# 29   0.391775
# 30   0.398771
# 31   0.389330
# 32   0.388027
# 33   0.389657
# 34   0.384070
# 35   0.380354
# 36   0.381545
# 37   0.384992
# 38   0.393981
# 39   0.384644
# 40   0.375737
# 41   0.378440
# 42   0.375183
# 43   0.382741
# 44   0.373558
# 45   0.373169
# 46   0.378763
# 47   0.378922
# 48   0.372768
# 49   0.375338
# 50   0.374727
# 51   0.362024
# 52   0.363870
# 53   0.375655
# 54   0.371287

# %%
training_evaluation_start = time.time()
# train
print("Train error")
show_metrics(train_evaluator.evaluate(
        model=model,
        mapped_triples=dataset.transductive_training.mapped_triples,
        additional_filter_triples=[
        dataset.transductive_training.mapped_triples,
    ]
    ).to_dict(),model_name,'train_metrics')
training_evaluation_duration = time.time() - training_evaluation_start
# Out:
# Train error
# Evaluating on cuda:0:   0%|          | 0.00/23.5k [00:00<?, ?triple/s]
# head
#                             optimistic  realistic  pessimistic
# inverse_harmonic_mean_rank    0.648273   0.007317     0.006520
# hits_at_1                     0.642446   0.000596     0.000596
# hits_at_3                     0.647600   0.005409     0.005409
# hits_at_5                     0.651646   0.009413     0.009413
# hits_at_10                    0.655479   0.012777     0.012777
# tail
#                             optimistic  realistic  pessimistic
# inverse_harmonic_mean_rank    0.052546   0.015215     0.013568
# hits_at_1                     0.041015   0.001320     0.001320
# hits_at_3                     0.045573   0.005878     0.005878
# hits_at_5                     0.047489   0.007794     0.007794
# hits_at_10                    0.057413   0.017590     0.016781
# both
#                             optimistic  realistic  pessimistic
# inverse_harmonic_mean_rank    0.350409   0.011266     0.010044
# hits_at_1                     0.341731   0.000958     0.000958
# hits_at_3                     0.346586   0.005643     0.005643
# hits_at_5                     0.349568   0.008603     0.008603
# hits_at_10                    0.356446   0.015184     0.014779

# %%
validation_evaluation_start = time.time()
# validation
print("Validation error")
show_metrics(valid_evaluator.evaluate(
        model=model,
        mapped_triples=dataset.inductive_validation.mapped_triples,
        additional_filter_triples=[
            # filtering of other positive triples
            dataset.inductive_validation.mapped_triples
        ],
    ).to_dict(),model_name,'validation_metrics')
validation_evaluation_duration = time.time() - validation_evaluation_start
# Out:
# Validation error
# Evaluating on cuda:0:   0%|          | 0.00/3.13k [00:00<?, ?triple/s]
# head
#                             optimistic  realistic  pessimistic
# inverse_harmonic_mean_rank    0.693597   0.012565     0.011224
# hits_at_1                     0.685641   0.002558     0.002558
# hits_at_3                     0.693956   0.010873     0.010873
# hits_at_5                     0.695875   0.015030     0.012792
# hits_at_10                    0.700352   0.021106     0.018868
# tail
#                             optimistic  realistic  pessimistic
# inverse_harmonic_mean_rank    0.069156   0.052648     0.050401
# hits_at_1                     0.046370   0.027822     0.027822
# hits_at_3                     0.066198   0.044452     0.044452
# hits_at_5                     0.072594   0.061720     0.050528
# hits_at_10                    0.095939   0.079309     0.071314
# both
#                             optimistic  realistic  pessimistic
# inverse_harmonic_mean_rank    0.381377   0.032606     0.030813
# hits_at_1                     0.366006   0.015190     0.015190
# hits_at_3                     0.380077   0.027662     0.027662
# hits_at_5                     0.384234   0.038375     0.031660
# hits_at_10                    0.398145   0.050208     0.045091

# %%
testing_evaluation_start = time.time()
# result on the test set
print("Test error")
show_metrics(test_evaluator.evaluate(
        model=model,
        mapped_triples=dataset.inductive_testing.mapped_triples,
        additional_filter_triples=[
            # filtering of other positive triples
            dataset.inductive_validation.mapped_triples,
        ],
    ).to_dict(),model_name,'test_metrics')
testing_evaluation_duration = time.time() - testing_evaluation_start
# Out:
# Test error
# Evaluating on cuda:0:   0%|          | 0.00/3.98k [00:00<?, ?triple/s]
# head
#                             optimistic  realistic  pessimistic
# inverse_harmonic_mean_rank    0.689833   0.013618     0.012160
# hits_at_1                     0.681156   0.003015     0.003015
# hits_at_3                     0.690452   0.011809     0.011809
# hits_at_5                     0.692211   0.015327     0.013317
# hits_at_10                    0.698241   0.024372     0.021608
# tail
#                             optimistic  realistic  pessimistic
# inverse_harmonic_mean_rank    0.064085   0.046283     0.043638
# hits_at_1                     0.040955   0.021357     0.021357
# hits_at_3                     0.063317   0.037186     0.036683
# hits_at_5                     0.068844   0.057286     0.042211
# hits_at_10                    0.090201   0.074372     0.068593
# both
#                             optimistic  realistic  pessimistic
# inverse_harmonic_mean_rank    0.376959   0.029950     0.027899
# hits_at_1                     0.361055   0.012186     0.012186
# hits_at_3                     0.376884   0.024497     0.024246
# hits_at_5                     0.380528   0.036307     0.027764
# hits_at_10                    0.394221   0.049372     0.045101

# %%
infodict = {}
infodict['device'] = model.device
infodict['parameters bytes'] = model.num_parameter_bytes
infodict['number parameters'] = model.num_parameters
infodict['training duration'] = training_duration
infodict['training evaluation duration'] = training_evaluation_duration
infodict['validation evaluation duration'] = validation_evaluation_duration
infodict['testing evaluation duration'] = testing_evaluation_duration
infodict["Operating system name"] = platform.system()
infodict["Operating system version"] = platform.release()
infodict["Processor architecture"] = platform.machine()
infodict["Python version"] = sys.version
infodict["Processor model name"] = cpuinfo.get_cpu_info()['brand_raw']
infodict['Number cpu cores'] = os.cpu_count()
infodict["Total physical memory"] = psutil.virtual_memory().total

# %%
output = subprocess.check_output(['nvidia-smi', '--query-gpu=name', '--format=csv'])
output = output.decode('utf-8')  # convert byte string to regular string

# split output into rows and remove header row
rows = output.strip().split('\n')[1:]

# extract GPU names from each row
gpu_names = []
for row in rows:
    name = row.strip()
    gpu_names.append(name)

infodict['GPU'] = gpu_names[0]

# %%
infodict['loss'] = NSSALoss
infodict['num_tokens'] = num_tokens
infodict['embedding_dim'] = embedding_dim
infodict['learning_rate'] = learning_rate
infodict['optimizer'] = Adam
infodict['num_epochs'] = num_epochs
infodict['patience'] = patience
infodict['aggregation'] = 'mlp'

# %%
info_df = pd.DataFrame(columns=['name','value'], data = infodict.items())
info_df.to_csv(f"{model_name}/{model_name}_information.csv")
print(info_df)
# Out:
#                               name  \
# 0                           device
# 1                 parameters bytes
# 2                number parameters
# 3                training duration
# 4     training evaluation duration
# 5   validation evaluation duration
# 6      testing evaluation duration
# 7            Operating system name
# 8         Operating system version
# 9           Processor architecture
# 10                  Python version
# 11            Processor model name
# 12                Number cpu cores
# 13           Total physical memory
# 14                             GPU
# 15                            loss
# 16                      num_tokens
# 17                   embedding_dim
# 18                   learning_rate
# 19                       optimizer
# 20                      num_epochs
# 21                        patience
# 22                     aggregation
#
#                                                 value
# 0                                              cuda:0
# 1                                             6732800
# 2                                             1683200
# 3                                           72.856738
# 4                                           27.356919
# 5                                            1.114038
# 6                                            1.217404
# 7                                               Linux
# 8                         3.10.0-1160.88.1.el7.x86_64
# 9                                              x86_64
# 10  3.10.9 (main, Mar  8 2023, 10:47:38) [GCC 11.2.0]
# 11           Intel(R) Xeon(R) Gold 6130 CPU @ 2.10GHz
# 12                                                 32
# 13                                        99980713984
# 14                                           Tesla T4
# 15                   <class 'pykeen.losses.NSSALoss'>
# 16                                                 20
# 17                                                200
# 18                                              0.001
# 19                    <class 'torch.optim.adam.Adam'>
# 20                                               2000
# 21                                                 20
# 22                                                mlp

# %%
def zip_folder(folder_path, output_path):
    with zipfile.ZipFile(output_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                zipf.write(os.path.join(root, file))

folder_path = model_name
output_path = f'{model_name}.zip'

zip_folder(folder_path, output_path)
