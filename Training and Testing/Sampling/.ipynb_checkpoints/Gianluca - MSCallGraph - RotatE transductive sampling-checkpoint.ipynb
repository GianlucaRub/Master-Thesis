# %%
from pykeen.pipeline import pipeline
from pykeen.datasets import Nations, get_dataset
import torch
from pykeen.evaluation import evaluate, RankBasedEvaluator
from pykeen.metrics.ranking import HitsAtK
import pandas as pd


import logging
from pathlib import Path

import click
import more_click
import torch
from pykeen.evaluation import RankBasedEvaluator
from pykeen.losses import NSSALoss,CrossEntropyLoss
from pykeen.models.inductive import InductiveNodePiece, InductiveNodePieceGNN
from pykeen.trackers import ConsoleResultTracker, WANDBResultTracker, FileResultTracker
from pykeen.training import SLCWATrainingLoop
from pykeen.typing import TESTING, TRAINING, VALIDATION
from pykeen.utils import resolve_device, set_random_seed
from torch.optim import Adam


from pykeen.metrics.ranking import HitsAtK

from pathlib import Path

from pykeen.datasets.inductive.base import DisjointInductivePathDataset
from pykeen.datasets.base import PathDataset, Dataset
from typing_extensions import Literal
import os
from pykeen.hpo import hpo_pipeline
from pykeen.triples import TriplesFactory
from pykeen.models import InductiveNodePiece, TransE, RGCN, QuatE, RotatE
from pykeen.typing import TESTING, TRAINING, VALIDATION

import time

import platform

import sys

import cpuinfo

import psutil

import subprocess

import zipfile

seed = 1234

# %%
def show_metrics(dictionary,model_name,csv_name):
    for key in dictionary.keys():
        print(key)
        df = pd.DataFrame(dictionary[key])
        df.to_csv(f"{model_name}/{model_name}_{csv_name}_{key}.csv")
        print(df)

# %%
DATA_TYPE = "_transductive_sampled.tsv"
TRAIN_PATH = "MSCallGraph_train" + DATA_TYPE
TEST_PATH = "MSCallGraph_test" + DATA_TYPE
VALIDATE_PATH = "MSCallGraph_validation" + DATA_TYPE

# %%
dataset = PathDataset(training_path = TRAIN_PATH,
                     validation_path = VALIDATE_PATH,
                      testing_path = TEST_PATH,
                      eager = True
                     )

# %%
model_name = 'rotatE_transductive_sampling'

# %%
tracker = ConsoleResultTracker()

# %%
loss = NSSALoss() #used by RotatE and NodePiece
embedding_dim = 200

# %%
model = RotatE(
        triples_factory=dataset.training,
        random_seed = seed,
        loss = loss,
        embedding_dim = embedding_dim
    ).to(resolve_device())
print(f"Number of parameters: {sum(p.numel() for p in model.parameters())}")
print(f"Space occupied: {model.num_parameter_bytes} bytes")
# Out:
# Number of parameters: 6665200
# Space occupied: 26660800 bytes

# %%
directory = model_name

if not os.path.exists(directory):
    os.makedirs(directory)
    print(f'Directory {directory} created successfully!')
else:
    print(f'Directory {directory} already exists.')
# Out:
# Directory rotatE_transductive_sampling created successfully!

# %%
learning_rate = 5e-2 #1e-3, and 1e-4 stops after 20 iterations and actually does not reduce the error too much
optimizer = Adam(params=model.parameters(), lr=learning_rate)
num_epochs = 2000
patience = 20

# %%
metrics = ['meanreciprocalrank', HitsAtK(1),
                 HitsAtK(3), HitsAtK(5), HitsAtK(10)]

train_evaluator = RankBasedEvaluator(
        metrics=metrics,
        add_defaults=False,
    )
valid_evaluator = RankBasedEvaluator(
        metrics=metrics,
        add_defaults=False,
    )
test_evaluator = RankBasedEvaluator(
        metrics = metrics,
        add_defaults=False
    )

# %%
from pykeen.stoppers import EarlyStopper

stopper = EarlyStopper(
    model = model,
    metric='meanreciprocalrank',
    patience=patience,
    frequency=1,
    evaluator = valid_evaluator,
    training_triples_factory = dataset.training,
    evaluation_triples_factory = dataset.validation,
    result_tracker = tracker

)

# %%
# default training regime is negative sampling (SLCWA)
# you can also use the 1-N regime with the LCWATrainingLoop
# the LCWA loop does not need negative sampling kwargs, but accepts label_smoothing in the .train() method
training_loop = SLCWATrainingLoop(
        triples_factory=dataset.training,
        model=model,
        result_tracker=tracker,
        optimizer=optimizer
)

# %%
training_start = time.time()
train_epoch =  training_loop.train(
        triples_factory=dataset.training,
        num_epochs=num_epochs,
#         callbacks="evaluation",
#         callback_kwargs=dict(
#             evaluator=valid_evaluator,
#             evaluation_triples=dataset.validation.mapped_triples,
#             prefix="validation",
#             frequency=1,
#             additional_filter_triples=dataset.training.mapped_triples,
#         ),
        stopper = stopper
        
    )
training_duration = time.time() - training_start
# Out:
# Training epochs on cuda:0:   0%|          | 0/2000 [00:00<?, ?epoch/s]
# Training batches on cuda:0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Step: 1
# Metric: loss = 3.5007872581481934
# Step: 1
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.00039230077723441994
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.00012219658409804614
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.0002572486806662331
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.00039230071706697345
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.00012219652126077563
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.0002572486118879169
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.00039230057315016795
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.0001221964536562034
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.0002572485134031857
# Metric: validation.head.optimistic.hits_at_1 = 6.711859856366199e-05
# Metric: validation.tail.optimistic.hits_at_1 = 0.0
# Metric: validation.both.optimistic.hits_at_1 = 3.3559299281830995e-05
# Metric: validation.head.realistic.hits_at_1 = 6.711859856366199e-05
# Metric: validation.tail.realistic.hits_at_1 = 0.0
# Metric: validation.both.realistic.hits_at_1 = 3.3559299281830995e-05
# Metric: validation.head.pessimistic.hits_at_1 = 6.711859856366199e-05
# Metric: validation.tail.pessimistic.hits_at_1 = 0.0
# Metric: validation.both.pessimistic.hits_at_1 = 3.3559299281830995e-05
# Metric: validation.head.optimistic.hits_at_3 = 0.00013423719712732398
# Metric: validation.tail.optimistic.hits_at_3 = 0.0
# Metric: validation.both.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.realistic.hits_at_3 = 0.00013423719712732398
# Metric: validation.tail.realistic.hits_at_3 = 0.0
# Metric: validation.both.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.pessimistic.hits_at_3 = 0.00013423719712732398
# Metric: validation.tail.pessimistic.hits_at_3 = 0.0
# Metric: validation.both.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.optimistic.hits_at_5 = 0.00020135579569098599
# Metric: validation.tail.optimistic.hits_at_5 = 0.0
# Metric: validation.both.optimistic.hits_at_5 = 0.00010067789784549299
# Metric: validation.head.realistic.hits_at_5 = 0.00020135579569098599
# Metric: validation.tail.realistic.hits_at_5 = 0.0
# Metric: validation.both.realistic.hits_at_5 = 0.00010067789784549299
# Metric: validation.head.pessimistic.hits_at_5 = 0.00020135579569098599
# Metric: validation.tail.pessimistic.hits_at_5 = 0.0
# Metric: validation.both.pessimistic.hits_at_5 = 0.00010067789784549299
# Metric: validation.head.optimistic.hits_at_10 = 0.00026847439425464796
# Metric: validation.tail.optimistic.hits_at_10 = 0.0
# Metric: validation.both.optimistic.hits_at_10 = 0.00013423719712732398
# Metric: validation.head.realistic.hits_at_10 = 0.00026847439425464796
# Metric: validation.tail.realistic.hits_at_10 = 0.0
# Metric: validation.both.realistic.hits_at_10 = 0.00013423719712732398
# Metric: validation.head.pessimistic.hits_at_10 = 0.00026847439425464796
# Metric: validation.tail.pessimistic.hits_at_10 = 0.0
# Metric: validation.both.pessimistic.hits_at_10 = 0.00013423719712732398
# Training batches on cuda:0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Step: 2
# Metric: loss = 2.9338836669921875
# Step: 2
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.00027679983861005254
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.00011281489714548427
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.00019480736787776842
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.00027679975028149784
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.00011281482875347137
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.00019480727496556938
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.00027679963090498726
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.00011281475165072947
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.00019480719127785835
# Metric: validation.head.optimistic.hits_at_1 = 0.0
# Metric: validation.tail.optimistic.hits_at_1 = 0.0
# Metric: validation.both.optimistic.hits_at_1 = 0.0
# Metric: validation.head.realistic.hits_at_1 = 0.0
# Metric: validation.tail.realistic.hits_at_1 = 0.0
# Metric: validation.both.realistic.hits_at_1 = 0.0
# Metric: validation.head.pessimistic.hits_at_1 = 0.0
# Metric: validation.tail.pessimistic.hits_at_1 = 0.0
# Metric: validation.both.pessimistic.hits_at_1 = 0.0
# Metric: validation.head.optimistic.hits_at_3 = 0.0
# Metric: validation.tail.optimistic.hits_at_3 = 0.0
# Metric: validation.both.optimistic.hits_at_3 = 0.0
# Metric: validation.head.realistic.hits_at_3 = 0.0
# Metric: validation.tail.realistic.hits_at_3 = 0.0
# Metric: validation.both.realistic.hits_at_3 = 0.0
# Metric: validation.head.pessimistic.hits_at_3 = 0.0
# Metric: validation.tail.pessimistic.hits_at_3 = 0.0
# Metric: validation.both.pessimistic.hits_at_3 = 0.0
# Metric: validation.head.optimistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.tail.optimistic.hits_at_5 = 0.0
# Metric: validation.both.optimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.head.realistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.tail.realistic.hits_at_5 = 0.0
# Metric: validation.both.realistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.head.pessimistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.tail.pessimistic.hits_at_5 = 0.0
# Metric: validation.both.pessimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.head.optimistic.hits_at_10 = 0.00026847439425464796
# Metric: validation.tail.optimistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_10 = 0.00016779649640915497
# Metric: validation.head.realistic.hits_at_10 = 0.00026847439425464796
# Metric: validation.tail.realistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_10 = 0.00016779649640915497
# Metric: validation.head.pessimistic.hits_at_10 = 0.00026847439425464796
# Metric: validation.tail.pessimistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_10 = 0.00016779649640915497
# Training batches on cuda:0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Step: 3
# Metric: loss = 2.363729476928711
# Step: 3
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.00028474686634583947
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.00015594798300541313
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.0002203474246756263
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.0002847468131221831
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.0001559479278512299
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.00022034735593479124
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.0002847467216662056
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.0001559478773534337
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.00022034729950981964
# Metric: validation.head.optimistic.hits_at_1 = 0.0
# Metric: validation.tail.optimistic.hits_at_1 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_1 = 3.3559299281830995e-05
# Metric: validation.head.realistic.hits_at_1 = 0.0
# Metric: validation.tail.realistic.hits_at_1 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_1 = 3.3559299281830995e-05
# Metric: validation.head.pessimistic.hits_at_1 = 0.0
# Metric: validation.tail.pessimistic.hits_at_1 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_1 = 3.3559299281830995e-05
# Metric: validation.head.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.optimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.tail.optimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.head.realistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.tail.realistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.head.pessimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.tail.pessimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.head.optimistic.hits_at_10 = 0.00026847439425464796
# Metric: validation.tail.optimistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_10 = 0.00016779649640915497
# Metric: validation.head.realistic.hits_at_10 = 0.00026847439425464796
# Metric: validation.tail.realistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_10 = 0.00016779649640915497
# Metric: validation.head.pessimistic.hits_at_10 = 0.00026847439425464796
# Metric: validation.tail.pessimistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_10 = 0.00016779649640915497
# Training batches on cuda:0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Step: 4
# Metric: loss = 1.8148192167282104
# Step: 4
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.00026705470711594384
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.00011635793063445985
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.0001917063188752018
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.0002670546236913651
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.00011635791452135891
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.0001917062472784892
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.000267054520189481
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.00011635788886835987
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.00019170620452892045
# Metric: validation.head.optimistic.hits_at_1 = 0.0
# Metric: validation.tail.optimistic.hits_at_1 = 0.0
# Metric: validation.both.optimistic.hits_at_1 = 0.0
# Metric: validation.head.realistic.hits_at_1 = 0.0
# Metric: validation.tail.realistic.hits_at_1 = 0.0
# Metric: validation.both.realistic.hits_at_1 = 0.0
# Metric: validation.head.pessimistic.hits_at_1 = 0.0
# Metric: validation.tail.pessimistic.hits_at_1 = 0.0
# Metric: validation.both.pessimistic.hits_at_1 = 0.0
# Metric: validation.head.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.optimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.tail.optimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.head.realistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.tail.realistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.head.pessimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.tail.pessimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.head.optimistic.hits_at_10 = 0.00020135579569098599
# Metric: validation.tail.optimistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_10 = 0.00013423719712732398
# Metric: validation.head.realistic.hits_at_10 = 0.00020135579569098599
# Metric: validation.tail.realistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_10 = 0.00013423719712732398
# Metric: validation.head.pessimistic.hits_at_10 = 0.00020135579569098599
# Metric: validation.tail.pessimistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_10 = 0.00013423719712732398
# Training batches on cuda:0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Step: 5
# Metric: loss = 1.3189544677734375
# Step: 5
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.00026808434700994745
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.0001134363171583497
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.00019076033208414853
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.0002680841716937721
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.00011343629012117164
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.00019076022726949304
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.0002680839829762769
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.00011343627010379311
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.00019076012654003498
# Metric: validation.head.optimistic.hits_at_1 = 0.0
# Metric: validation.tail.optimistic.hits_at_1 = 0.0
# Metric: validation.both.optimistic.hits_at_1 = 0.0
# Metric: validation.head.realistic.hits_at_1 = 0.0
# Metric: validation.tail.realistic.hits_at_1 = 0.0
# Metric: validation.both.realistic.hits_at_1 = 0.0
# Metric: validation.head.pessimistic.hits_at_1 = 0.0
# Metric: validation.tail.pessimistic.hits_at_1 = 0.0
# Metric: validation.both.pessimistic.hits_at_1 = 0.0
# Metric: validation.head.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.optimistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.tail.optimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_5 = 0.00010067789784549299
# Metric: validation.head.realistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.tail.realistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_5 = 0.00010067789784549299
# Metric: validation.head.pessimistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.tail.pessimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_5 = 0.00010067789784549299
# Metric: validation.head.optimistic.hits_at_10 = 0.00033559299281830994
# Metric: validation.tail.optimistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_10 = 0.00020135579569098599
# Metric: validation.head.realistic.hits_at_10 = 0.00033559299281830994
# Metric: validation.tail.realistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_10 = 0.00020135579569098599
# Metric: validation.head.pessimistic.hits_at_10 = 0.00033559299281830994
# Metric: validation.tail.pessimistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_10 = 0.00020135579569098599
# Training batches on cuda:0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Step: 6
# Metric: loss = 0.9542402625083923
# Step: 6
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.00026929723197652246
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.00011243344054398623
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.0001908653362602543
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.0002692971029318869
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.00011243341577937825
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.0001908652629936114
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.0002692969866017105
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.00011243339670978899
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.00019086519165574975
# Metric: validation.head.optimistic.hits_at_1 = 0.0
# Metric: validation.tail.optimistic.hits_at_1 = 0.0
# Metric: validation.both.optimistic.hits_at_1 = 0.0
# Metric: validation.head.realistic.hits_at_1 = 0.0
# Metric: validation.tail.realistic.hits_at_1 = 0.0
# Metric: validation.both.realistic.hits_at_1 = 0.0
# Metric: validation.head.pessimistic.hits_at_1 = 0.0
# Metric: validation.tail.pessimistic.hits_at_1 = 0.0
# Metric: validation.both.pessimistic.hits_at_1 = 0.0
# Metric: validation.head.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.optimistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.tail.optimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_5 = 0.00010067789784549299
# Metric: validation.head.realistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.tail.realistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_5 = 0.00010067789784549299
# Metric: validation.head.pessimistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.tail.pessimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_5 = 0.00010067789784549299
# Metric: validation.head.optimistic.hits_at_10 = 0.00033559299281830994
# Metric: validation.tail.optimistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_10 = 0.00020135579569098599
# Metric: validation.head.realistic.hits_at_10 = 0.00033559299281830994
# Metric: validation.tail.realistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_10 = 0.00020135579569098599
# Metric: validation.head.pessimistic.hits_at_10 = 0.00033559299281830994
# Metric: validation.tail.pessimistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_10 = 0.00020135579569098599
# Training batches on cuda:0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Step: 7
# Metric: loss = 0.8256763815879822
# Step: 7
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.00027417429922816446
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.00011546789348960145
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.00019482109635888297
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.0002741740900091827
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.0001154678684542887
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.0001948209828697145
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.0002741739128330583
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.00011546782733892294
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.00019482087008599062
# Metric: validation.head.optimistic.hits_at_1 = 0.0
# Metric: validation.tail.optimistic.hits_at_1 = 0.0
# Metric: validation.both.optimistic.hits_at_1 = 0.0
# Metric: validation.head.realistic.hits_at_1 = 0.0
# Metric: validation.tail.realistic.hits_at_1 = 0.0
# Metric: validation.both.realistic.hits_at_1 = 0.0
# Metric: validation.head.pessimistic.hits_at_1 = 0.0
# Metric: validation.tail.pessimistic.hits_at_1 = 0.0
# Metric: validation.both.pessimistic.hits_at_1 = 0.0
# Metric: validation.head.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.optimistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.tail.optimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_5 = 0.00010067789784549299
# Metric: validation.head.realistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.tail.realistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_5 = 0.00010067789784549299
# Metric: validation.head.pessimistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.tail.pessimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_5 = 0.00010067789784549299
# Metric: validation.head.optimistic.hits_at_10 = 0.00033559299281830994
# Metric: validation.tail.optimistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_10 = 0.00020135579569098599
# Metric: validation.head.realistic.hits_at_10 = 0.00033559299281830994
# Metric: validation.tail.realistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_10 = 0.00020135579569098599
# Metric: validation.head.pessimistic.hits_at_10 = 0.00033559299281830994
# Metric: validation.tail.pessimistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_10 = 0.00020135579569098599
# Training batches on cuda:0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Step: 8
# Metric: loss = 0.8776763677597046
# Step: 8
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.0002941609619051989
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.0001297416674723117
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.00021195131468875532
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.0002941607963293791
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.00012974160199519247
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.00021195122099015862
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.000294160676855962
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.00012974154978990672
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.00021195111332293433
# Metric: validation.head.optimistic.hits_at_1 = 0.0
# Metric: validation.tail.optimistic.hits_at_1 = 0.0
# Metric: validation.both.optimistic.hits_at_1 = 0.0
# Metric: validation.head.realistic.hits_at_1 = 0.0
# Metric: validation.tail.realistic.hits_at_1 = 0.0
# Metric: validation.both.realistic.hits_at_1 = 0.0
# Metric: validation.head.pessimistic.hits_at_1 = 0.0
# Metric: validation.tail.pessimistic.hits_at_1 = 0.0
# Metric: validation.both.pessimistic.hits_at_1 = 0.0
# Metric: validation.head.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.optimistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.tail.optimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_5 = 0.00010067789784549299
# Metric: validation.head.realistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.tail.realistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_5 = 0.00010067789784549299
# Metric: validation.head.pessimistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.tail.pessimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_5 = 0.00010067789784549299
# Metric: validation.head.optimistic.hits_at_10 = 0.00033559299281830994
# Metric: validation.tail.optimistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_10 = 0.00020135579569098599
# Metric: validation.head.realistic.hits_at_10 = 0.00033559299281830994
# Metric: validation.tail.realistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_10 = 0.00020135579569098599
# Metric: validation.head.pessimistic.hits_at_10 = 0.00033559299281830994
# Metric: validation.tail.pessimistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_10 = 0.00020135579569098599
# Training batches on cuda:0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Step: 9
# Metric: loss = 0.9452256560325623
# Step: 9
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.000331291274817839
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.00018120396733760195
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.0002562476210777204
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.00033129064831882715
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.00018120388267561793
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.0002562472363933921
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.000331289974535163
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.0001812037697645703
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.00025624687214986666
# Metric: validation.head.optimistic.hits_at_1 = 0.0
# Metric: validation.tail.optimistic.hits_at_1 = 0.0
# Metric: validation.both.optimistic.hits_at_1 = 0.0
# Metric: validation.head.realistic.hits_at_1 = 0.0
# Metric: validation.tail.realistic.hits_at_1 = 0.0
# Metric: validation.both.realistic.hits_at_1 = 0.0
# Metric: validation.head.pessimistic.hits_at_1 = 0.0
# Metric: validation.tail.pessimistic.hits_at_1 = 0.0
# Metric: validation.both.pessimistic.hits_at_1 = 0.0
# Metric: validation.head.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.optimistic.hits_at_5 = 0.00020135579569098599
# Metric: validation.tail.optimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.head.realistic.hits_at_5 = 0.00020135579569098599
# Metric: validation.tail.realistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.head.pessimistic.hits_at_5 = 0.00020135579569098599
# Metric: validation.tail.pessimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.head.optimistic.hits_at_10 = 0.00033559299281830994
# Metric: validation.tail.optimistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_10 = 0.00020135579569098599
# Metric: validation.head.realistic.hits_at_10 = 0.00033559299281830994
# Metric: validation.tail.realistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_10 = 0.00020135579569098599
# Metric: validation.head.pessimistic.hits_at_10 = 0.00033559299281830994
# Metric: validation.tail.pessimistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_10 = 0.00020135579569098599
# Training batches on cuda:0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Step: 10
# Metric: loss = 0.9578346610069275
# Step: 10
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.00042565542219142656
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.00033904980086065753
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.00038235261152604207
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.000425655220169574
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.0003390494966879487
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.0003823523875325919
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.00042565501937495194
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.0003390492332999726
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.0003823521263374623
# Metric: validation.head.optimistic.hits_at_1 = 0.0
# Metric: validation.tail.optimistic.hits_at_1 = 0.0
# Metric: validation.both.optimistic.hits_at_1 = 0.0
# Metric: validation.head.realistic.hits_at_1 = 0.0
# Metric: validation.tail.realistic.hits_at_1 = 0.0
# Metric: validation.both.realistic.hits_at_1 = 0.0
# Metric: validation.head.pessimistic.hits_at_1 = 0.0
# Metric: validation.tail.pessimistic.hits_at_1 = 0.0
# Metric: validation.both.pessimistic.hits_at_1 = 0.0
# Metric: validation.head.optimistic.hits_at_3 = 0.00013423719712732398
# Metric: validation.tail.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_3 = 0.00010067789784549299
# Metric: validation.head.realistic.hits_at_3 = 0.00013423719712732398
# Metric: validation.tail.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_3 = 0.00010067789784549299
# Metric: validation.head.pessimistic.hits_at_3 = 0.00013423719712732398
# Metric: validation.tail.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_3 = 0.00010067789784549299
# Metric: validation.head.optimistic.hits_at_5 = 0.00020135579569098599
# Metric: validation.tail.optimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.head.realistic.hits_at_5 = 0.00020135579569098599
# Metric: validation.tail.realistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.head.pessimistic.hits_at_5 = 0.00020135579569098599
# Metric: validation.tail.pessimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.head.optimistic.hits_at_10 = 0.00033559299281830994
# Metric: validation.tail.optimistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_10 = 0.00020135579569098599
# Metric: validation.head.realistic.hits_at_10 = 0.00033559299281830994
# Metric: validation.tail.realistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_10 = 0.00020135579569098599
# Metric: validation.head.pessimistic.hits_at_10 = 0.00033559299281830994
# Metric: validation.tail.pessimistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_10 = 0.00020135579569098599
# Training batches on cuda:0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Step: 11
# Metric: loss = 0.9065002799034119
# Step: 11
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.0006987677222059753
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.000870123530597806
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.0007844456264018905
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.0006987673696130514
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.0008701226324774326
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.0007844449719414115
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.0006987671098618759
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.0008701216138868727
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.0007844443618743744
# Metric: validation.head.optimistic.hits_at_1 = 0.0
# Metric: validation.tail.optimistic.hits_at_1 = 0.0
# Metric: validation.both.optimistic.hits_at_1 = 0.0
# Metric: validation.head.realistic.hits_at_1 = 0.0
# Metric: validation.tail.realistic.hits_at_1 = 0.0
# Metric: validation.both.realistic.hits_at_1 = 0.0
# Metric: validation.head.pessimistic.hits_at_1 = 0.0
# Metric: validation.tail.pessimistic.hits_at_1 = 0.0
# Metric: validation.both.pessimistic.hits_at_1 = 0.0
# Metric: validation.head.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.head.optimistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.tail.optimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_5 = 0.00010067789784549299
# Metric: validation.head.realistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.tail.realistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_5 = 0.00010067789784549299
# Metric: validation.head.pessimistic.hits_at_5 = 0.00013423719712732398
# Metric: validation.tail.pessimistic.hits_at_5 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_5 = 0.00010067789784549299
# Metric: validation.head.optimistic.hits_at_10 = 0.00026847439425464796
# Metric: validation.tail.optimistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_10 = 0.00016779649640915497
# Metric: validation.head.realistic.hits_at_10 = 0.00026847439425464796
# Metric: validation.tail.realistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_10 = 0.00016779649640915497
# Metric: validation.head.pessimistic.hits_at_10 = 0.00026847439425464796
# Metric: validation.tail.pessimistic.hits_at_10 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_10 = 0.00016779649640915497
# Training batches on cuda:0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Step: 12
# Metric: loss = 0.8099312782287598
# Step: 12
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.0019973268670505345
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.0034108925481697782
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.0027041097076101563
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.0019973262678831816
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.003410890232771635
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.00270410836674273
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.001997325632566504
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.0034108882778574484
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.002704106955211976
# Metric: validation.head.optimistic.hits_at_1 = 0.0
# Metric: validation.tail.optimistic.hits_at_1 = 6.711859856366199e-05
# Metric: validation.both.optimistic.hits_at_1 = 3.3559299281830995e-05
# Metric: validation.head.realistic.hits_at_1 = 0.0
# Metric: validation.tail.realistic.hits_at_1 = 6.711859856366199e-05
# Metric: validation.both.realistic.hits_at_1 = 3.3559299281830995e-05
# Metric: validation.head.pessimistic.hits_at_1 = 0.0
# Metric: validation.tail.pessimistic.hits_at_1 = 6.711859856366199e-05
# Metric: validation.both.pessimistic.hits_at_1 = 3.3559299281830995e-05
# Metric: validation.head.optimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.optimistic.hits_at_3 = 0.00020135579569098599
# Metric: validation.both.optimistic.hits_at_3 = 0.00013423719712732398
# Metric: validation.head.realistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.realistic.hits_at_3 = 0.00020135579569098599
# Metric: validation.both.realistic.hits_at_3 = 0.00013423719712732398
# Metric: validation.head.pessimistic.hits_at_3 = 6.711859856366199e-05
# Metric: validation.tail.pessimistic.hits_at_3 = 0.00020135579569098599
# Metric: validation.both.pessimistic.hits_at_3 = 0.00013423719712732398
# Metric: validation.head.optimistic.hits_at_5 = 0.00033559299281830994
# Metric: validation.tail.optimistic.hits_at_5 = 0.00040271159138197197
# Metric: validation.both.optimistic.hits_at_5 = 0.00036915229210014093
# Metric: validation.head.realistic.hits_at_5 = 0.00033559299281830994
# Metric: validation.tail.realistic.hits_at_5 = 0.00040271159138197197
# Metric: validation.both.realistic.hits_at_5 = 0.00036915229210014093
# Metric: validation.head.pessimistic.hits_at_5 = 0.00033559299281830994
# Metric: validation.tail.pessimistic.hits_at_5 = 0.00040271159138197197
# Metric: validation.both.pessimistic.hits_at_5 = 0.00036915229210014093
# Metric: validation.head.optimistic.hits_at_10 = 0.0014094905698369018
# Metric: validation.tail.optimistic.hits_at_10 = 0.0016108463655278879
# Metric: validation.both.optimistic.hits_at_10 = 0.0015101684676823949
# Metric: validation.head.realistic.hits_at_10 = 0.0014094905698369018
# Metric: validation.tail.realistic.hits_at_10 = 0.0016108463655278879
# Metric: validation.both.realistic.hits_at_10 = 0.0015101684676823949
# Metric: validation.head.pessimistic.hits_at_10 = 0.0014094905698369018
# Metric: validation.tail.pessimistic.hits_at_10 = 0.0016108463655278879
# Metric: validation.both.pessimistic.hits_at_10 = 0.0015101684676823949
# Training batches on cuda:0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Step: 13
# Metric: loss = 0.6938732862472534
# Step: 13
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.00801744530934866
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.014639104878169782
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.01132827509375922
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.008017444051802158
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.014639093540608885
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.01132826879620552
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.00801744229478707
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.01463908103655777
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.011328261665672417
# Metric: validation.head.optimistic.hits_at_1 = 0.0018122021612188737
# Metric: validation.tail.optimistic.hits_at_1 = 0.0033559299281830995
# Metric: validation.both.optimistic.hits_at_1 = 0.0025840660447009867
# Metric: validation.head.realistic.hits_at_1 = 0.0018122021612188737
# Metric: validation.tail.realistic.hits_at_1 = 0.0033559299281830995
# Metric: validation.both.realistic.hits_at_1 = 0.0025840660447009867
# Metric: validation.head.pessimistic.hits_at_1 = 0.0018122021612188737
# Metric: validation.tail.pessimistic.hits_at_1 = 0.0033559299281830995
# Metric: validation.both.pessimistic.hits_at_1 = 0.0025840660447009867
# Metric: validation.head.optimistic.hits_at_3 = 0.004631183300892678
# Metric: validation.tail.optimistic.hits_at_3 = 0.007450164440566481
# Metric: validation.both.optimistic.hits_at_3 = 0.0060406738707295795
# Metric: validation.head.realistic.hits_at_3 = 0.004631183300892678
# Metric: validation.tail.realistic.hits_at_3 = 0.007450164440566481
# Metric: validation.both.realistic.hits_at_3 = 0.0060406738707295795
# Metric: validation.head.pessimistic.hits_at_3 = 0.004631183300892678
# Metric: validation.tail.pessimistic.hits_at_3 = 0.007450164440566481
# Metric: validation.both.pessimistic.hits_at_3 = 0.0060406738707295795
# Metric: validation.head.optimistic.hits_at_5 = 0.007315927243439157
# Metric: validation.tail.optimistic.hits_at_5 = 0.012215584938586483
# Metric: validation.both.optimistic.hits_at_5 = 0.00976575609101282
# Metric: validation.head.realistic.hits_at_5 = 0.007315927243439157
# Metric: validation.tail.realistic.hits_at_5 = 0.012215584938586483
# Metric: validation.both.realistic.hits_at_5 = 0.00976575609101282
# Metric: validation.head.pessimistic.hits_at_5 = 0.007315927243439157
# Metric: validation.tail.pessimistic.hits_at_5 = 0.012215584938586483
# Metric: validation.both.pessimistic.hits_at_5 = 0.00976575609101282
# Metric: validation.head.optimistic.hits_at_10 = 0.013893549902678033
# Metric: validation.tail.optimistic.hits_at_10 = 0.02422981408148198
# Metric: validation.both.optimistic.hits_at_10 = 0.019061681992080005
# Metric: validation.head.realistic.hits_at_10 = 0.013893549902678033
# Metric: validation.tail.realistic.hits_at_10 = 0.02422981408148198
# Metric: validation.both.realistic.hits_at_10 = 0.019061681992080005
# Metric: validation.head.pessimistic.hits_at_10 = 0.013893549902678033
# Metric: validation.tail.pessimistic.hits_at_10 = 0.02422981408148198
# Metric: validation.both.pessimistic.hits_at_10 = 0.019061681992080005
# Training batches on cuda:0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Step: 14
# Metric: loss = 0.5816258192062378
# Step: 14
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.013205114463874472
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.023098310250790878
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.018151712357332674
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.013205111026763914
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.023098308593034744
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.01815170980989933
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.013205106334125536
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.023098305244957006
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.01815170578954127
# Metric: validation.head.optimistic.hits_at_1 = 0.004832539096583663
# Metric: validation.tail.optimistic.hits_at_1 = 0.006309148264984227
# Metric: validation.both.optimistic.hits_at_1 = 0.0055708436807839455
# Metric: validation.head.realistic.hits_at_1 = 0.004832539096583663
# Metric: validation.tail.realistic.hits_at_1 = 0.006309148264984227
# Metric: validation.both.realistic.hits_at_1 = 0.0055708436807839455
# Metric: validation.head.pessimistic.hits_at_1 = 0.004832539096583663
# Metric: validation.tail.pessimistic.hits_at_1 = 0.006309148264984227
# Metric: validation.both.pessimistic.hits_at_1 = 0.0055708436807839455
# Metric: validation.head.optimistic.hits_at_3 = 0.009530840996040003
# Metric: validation.tail.optimistic.hits_at_3 = 0.015235921873951272
# Metric: validation.both.optimistic.hits_at_3 = 0.012383381434995637
# Metric: validation.head.realistic.hits_at_3 = 0.009530840996040003
# Metric: validation.tail.realistic.hits_at_3 = 0.015235921873951272
# Metric: validation.both.realistic.hits_at_3 = 0.012383381434995637
# Metric: validation.head.pessimistic.hits_at_3 = 0.009530840996040003
# Metric: validation.tail.pessimistic.hits_at_3 = 0.015235921873951272
# Metric: validation.both.pessimistic.hits_at_3 = 0.012383381434995637
# Metric: validation.head.optimistic.hits_at_5 = 0.013625075508423384
# Metric: validation.tail.optimistic.hits_at_5 = 0.023491509497281696
# Metric: validation.both.optimistic.hits_at_5 = 0.01855829250285254
# Metric: validation.head.realistic.hits_at_5 = 0.013625075508423384
# Metric: validation.tail.realistic.hits_at_5 = 0.023491509497281696
# Metric: validation.both.realistic.hits_at_5 = 0.01855829250285254
# Metric: validation.head.pessimistic.hits_at_5 = 0.013625075508423384
# Metric: validation.tail.pessimistic.hits_at_5 = 0.023491509497281696
# Metric: validation.both.pessimistic.hits_at_5 = 0.01855829250285254
# Metric: validation.head.optimistic.hits_at_10 = 0.02429693268004564
# Metric: validation.tail.optimistic.hits_at_10 = 0.04322437747499832
# Metric: validation.both.optimistic.hits_at_10 = 0.03376065507752198
# Metric: validation.head.realistic.hits_at_10 = 0.02429693268004564
# Metric: validation.tail.realistic.hits_at_10 = 0.04322437747499832
# Metric: validation.both.realistic.hits_at_10 = 0.03376065507752198
# Metric: validation.head.pessimistic.hits_at_10 = 0.02429693268004564
# Metric: validation.tail.pessimistic.hits_at_10 = 0.04322437747499832
# Metric: validation.both.pessimistic.hits_at_10 = 0.03376065507752198
# Training batches on cuda:0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Step: 15
# Metric: loss = 0.4920289218425751
# Step: 15
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.013767482127408201
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.025637170060339456
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.019702326093873828
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.013767474330961703
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.025637142360210415
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.019702307879924774
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.013767467496795907
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.025637110397125643
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.019702288946960776
# Metric: validation.head.optimistic.hits_at_1 = 0.004899657695147325
# Metric: validation.tail.optimistic.hits_at_1 = 0.006913215652057185
# Metric: validation.both.optimistic.hits_at_1 = 0.005906436673602255
# Metric: validation.head.realistic.hits_at_1 = 0.004899657695147325
# Metric: validation.tail.realistic.hits_at_1 = 0.006913215652057185
# Metric: validation.both.realistic.hits_at_1 = 0.005906436673602255
# Metric: validation.head.pessimistic.hits_at_1 = 0.004899657695147325
# Metric: validation.tail.pessimistic.hits_at_1 = 0.006913215652057185
# Metric: validation.both.pessimistic.hits_at_1 = 0.005906436673602255
# Metric: validation.head.optimistic.hits_at_3 = 0.009665078193167326
# Metric: validation.tail.optimistic.hits_at_3 = 0.017719310020806765
# Metric: validation.both.optimistic.hits_at_3 = 0.013692194106987046
# Metric: validation.head.realistic.hits_at_3 = 0.009665078193167326
# Metric: validation.tail.realistic.hits_at_3 = 0.017719310020806765
# Metric: validation.both.realistic.hits_at_3 = 0.013692194106987046
# Metric: validation.head.pessimistic.hits_at_3 = 0.009665078193167326
# Metric: validation.tail.pessimistic.hits_at_3 = 0.017719310020806765
# Metric: validation.both.pessimistic.hits_at_3 = 0.013692194106987046
# Metric: validation.head.optimistic.hits_at_5 = 0.013960668501241695
# Metric: validation.tail.optimistic.hits_at_5 = 0.026176253439828177
# Metric: validation.both.optimistic.hits_at_5 = 0.020068460970534937
# Metric: validation.head.realistic.hits_at_5 = 0.013960668501241695
# ...
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.2736106216907501
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.41775619983673096
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.34568342566490173
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.2736106204795152
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.4177562094701252
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.3456834149748202
# Metric: validation.head.optimistic.hits_at_1 = 0.1889388549567085
# Metric: validation.tail.optimistic.hits_at_1 = 0.3249211356466877
# Metric: validation.both.optimistic.hits_at_1 = 0.2569299953016981
# Metric: validation.head.realistic.hits_at_1 = 0.1889388549567085
# Metric: validation.tail.realistic.hits_at_1 = 0.3249211356466877
# Metric: validation.both.realistic.hits_at_1 = 0.2569299953016981
# Metric: validation.head.pessimistic.hits_at_1 = 0.1889388549567085
# Metric: validation.tail.pessimistic.hits_at_1 = 0.3249211356466877
# Metric: validation.both.pessimistic.hits_at_1 = 0.2569299953016981
# Metric: validation.head.optimistic.hits_at_3 = 0.29552318947580375
# Metric: validation.tail.optimistic.hits_at_3 = 0.47472984764078124
# Metric: validation.both.optimistic.hits_at_3 = 0.3851265185582925
# Metric: validation.head.realistic.hits_at_3 = 0.29552318947580375
# Metric: validation.tail.realistic.hits_at_3 = 0.47472984764078124
# Metric: validation.both.realistic.hits_at_3 = 0.3851265185582925
# Metric: validation.head.pessimistic.hits_at_3 = 0.29552318947580375
# Metric: validation.tail.pessimistic.hits_at_3 = 0.47472984764078124
# Metric: validation.both.pessimistic.hits_at_3 = 0.3851265185582925
# Metric: validation.head.optimistic.hits_at_5 = 0.3535136586348077
# Metric: validation.tail.optimistic.hits_at_5 = 0.5259413383448553
# Metric: validation.both.optimistic.hits_at_5 = 0.43972749848983156
# Metric: validation.head.realistic.hits_at_5 = 0.3535136586348077
# Metric: validation.tail.realistic.hits_at_5 = 0.5259413383448553
# Metric: validation.both.realistic.hits_at_5 = 0.43972749848983156
# Metric: validation.head.pessimistic.hits_at_5 = 0.3535136586348077
# Metric: validation.tail.pessimistic.hits_at_5 = 0.5259413383448553
# Metric: validation.both.pessimistic.hits_at_5 = 0.43972749848983156
# Metric: validation.head.optimistic.hits_at_10 = 0.45392308208604604
# Metric: validation.tail.optimistic.hits_at_10 = 0.5832606215182227
# Metric: validation.both.optimistic.hits_at_10 = 0.5185918518021344
# Metric: validation.head.realistic.hits_at_10 = 0.45392308208604604
# Metric: validation.tail.realistic.hits_at_10 = 0.5832606215182227
# Metric: validation.both.realistic.hits_at_10 = 0.5185918518021344
# Metric: validation.head.pessimistic.hits_at_10 = 0.45392308208604604
# Metric: validation.tail.pessimistic.hits_at_10 = 0.5832606215182227
# Metric: validation.both.pessimistic.hits_at_10 = 0.5185918518021344
# Training batches on cuda:0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Step: 185
# Metric: loss = 0.03504178673028946
# Step: 185
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.2735159734361585
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.41708240574307487
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.3452991895896167
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.2735159695148468
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.41708236932754517
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.34529921412467957
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.2735159732468635
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.4170824036410997
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.3452991884439816
# Metric: validation.head.optimistic.hits_at_1 = 0.18799919457681724
# Metric: validation.tail.optimistic.hits_at_1 = 0.32324317068259617
# Metric: validation.both.optimistic.hits_at_1 = 0.2556211826297067
# Metric: validation.head.realistic.hits_at_1 = 0.18799919457681724
# Metric: validation.tail.realistic.hits_at_1 = 0.32324317068259617
# Metric: validation.both.realistic.hits_at_1 = 0.2556211826297067
# Metric: validation.head.pessimistic.hits_at_1 = 0.18799919457681724
# Metric: validation.tail.pessimistic.hits_at_1 = 0.32324317068259617
# Metric: validation.both.pessimistic.hits_at_1 = 0.2556211826297067
# Metric: validation.head.optimistic.hits_at_3 = 0.29706691724276796
# Metric: validation.tail.optimistic.hits_at_3 = 0.47419289885227195
# Metric: validation.both.optimistic.hits_at_3 = 0.38562990804751995
# Metric: validation.head.realistic.hits_at_3 = 0.29706691724276796
# Metric: validation.tail.realistic.hits_at_3 = 0.47419289885227195
# Metric: validation.both.realistic.hits_at_3 = 0.38562990804751995
# Metric: validation.head.pessimistic.hits_at_3 = 0.29706691724276796
# Metric: validation.tail.pessimistic.hits_at_3 = 0.47419289885227195
# Metric: validation.both.pessimistic.hits_at_3 = 0.38562990804751995
# Metric: validation.head.optimistic.hits_at_5 = 0.35384925162762604
# Metric: validation.tail.optimistic.hits_at_5 = 0.5263440499362373
# Metric: validation.both.optimistic.hits_at_5 = 0.44009665078193166
# Metric: validation.head.realistic.hits_at_5 = 0.35384925162762604
# Metric: validation.tail.realistic.hits_at_5 = 0.5263440499362373
# Metric: validation.both.realistic.hits_at_5 = 0.44009665078193166
# Metric: validation.head.pessimistic.hits_at_5 = 0.35384925162762604
# Metric: validation.tail.pessimistic.hits_at_5 = 0.5263440499362373
# Metric: validation.both.pessimistic.hits_at_5 = 0.44009665078193166
# Metric: validation.head.optimistic.hits_at_10 = 0.4556681656487013
# Metric: validation.tail.optimistic.hits_at_10 = 0.5834619773139137
# Metric: validation.both.optimistic.hits_at_10 = 0.5195650714813075
# Metric: validation.head.realistic.hits_at_10 = 0.4556681656487013
# Metric: validation.tail.realistic.hits_at_10 = 0.5834619773139137
# Metric: validation.both.realistic.hits_at_10 = 0.5195650714813075
# Metric: validation.head.pessimistic.hits_at_10 = 0.4556681656487013
# Metric: validation.tail.pessimistic.hits_at_10 = 0.5834619773139137
# Metric: validation.both.pessimistic.hits_at_10 = 0.5195650714813075
# Training batches on cuda:0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Step: 186
# Metric: loss = 0.03358152508735657
# Step: 186
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.2730693626191514
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.41713608953955716
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.3451027260793542
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.2730693519115448
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.4171361029148102
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.3451027274131775
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.27306936261583625
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.4171360895349865
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.3451027260754113
# Metric: validation.head.optimistic.hits_at_1 = 0.18638834821128936
# Metric: validation.tail.optimistic.hits_at_1 = 0.3236458822739781
# Metric: validation.both.optimistic.hits_at_1 = 0.2550171152426337
# Metric: validation.head.realistic.hits_at_1 = 0.18638834821128936
# Metric: validation.tail.realistic.hits_at_1 = 0.3236458822739781
# Metric: validation.both.realistic.hits_at_1 = 0.2550171152426337
# Metric: validation.head.pessimistic.hits_at_1 = 0.18638834821128936
# Metric: validation.tail.pessimistic.hits_at_1 = 0.3236458822739781
# Metric: validation.both.pessimistic.hits_at_1 = 0.2550171152426337
# Metric: validation.head.optimistic.hits_at_3 = 0.29807369622122293
# Metric: validation.tail.optimistic.hits_at_3 = 0.47372306866232633
# Metric: validation.both.optimistic.hits_at_3 = 0.3858983824417746
# Metric: validation.head.realistic.hits_at_3 = 0.29807369622122293
# Metric: validation.tail.realistic.hits_at_3 = 0.47372306866232633
# Metric: validation.both.realistic.hits_at_3 = 0.3858983824417746
# Metric: validation.head.pessimistic.hits_at_3 = 0.29807369622122293
# Metric: validation.tail.pessimistic.hits_at_3 = 0.47372306866232633
# Metric: validation.both.pessimistic.hits_at_3 = 0.3858983824417746
# Metric: validation.head.optimistic.hits_at_5 = 0.35465467481039
# Metric: validation.tail.optimistic.hits_at_5 = 0.5266796429290557
# Metric: validation.both.optimistic.hits_at_5 = 0.4406671588697228
# Metric: validation.head.realistic.hits_at_5 = 0.35465467481039
# Metric: validation.tail.realistic.hits_at_5 = 0.5266796429290557
# Metric: validation.both.realistic.hits_at_5 = 0.4406671588697228
# Metric: validation.head.pessimistic.hits_at_5 = 0.35465467481039
# Metric: validation.tail.pessimistic.hits_at_5 = 0.5266796429290557
# Metric: validation.both.pessimistic.hits_at_5 = 0.4406671588697228
# Metric: validation.head.optimistic.hits_at_10 = 0.455131216860192
# Metric: validation.tail.optimistic.hits_at_10 = 0.5839318075038593
# Metric: validation.both.optimistic.hits_at_10 = 0.5195315121820256
# Metric: validation.head.realistic.hits_at_10 = 0.455131216860192
# Metric: validation.tail.realistic.hits_at_10 = 0.5839318075038593
# Metric: validation.both.realistic.hits_at_10 = 0.5195315121820256
# Metric: validation.head.pessimistic.hits_at_10 = 0.455131216860192
# Metric: validation.tail.pessimistic.hits_at_10 = 0.5839318075038593
# Metric: validation.both.pessimistic.hits_at_10 = 0.5195315121820256
# Training batches on cuda:0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Step: 187
# Metric: loss = 0.033987775444984436
# Step: 187
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.27303794993988323
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.41661522617418517
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.3448265880570342
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.27303797006607056
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.41661524772644043
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.3448265790939331
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.2730379478056652
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.41661522406088836
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.34482658593327686
# Metric: validation.head.optimistic.hits_at_1 = 0.18618699241559836
# Metric: validation.tail.optimistic.hits_at_1 = 0.32290757768977785
# Metric: validation.both.optimistic.hits_at_1 = 0.2545472850526881
# Metric: validation.head.realistic.hits_at_1 = 0.18618699241559836
# Metric: validation.tail.realistic.hits_at_1 = 0.32290757768977785
# Metric: validation.both.realistic.hits_at_1 = 0.2545472850526881
# Metric: validation.head.pessimistic.hits_at_1 = 0.18618699241559836
# Metric: validation.tail.pessimistic.hits_at_1 = 0.32290757768977785
# Metric: validation.both.pessimistic.hits_at_1 = 0.2545472850526881
# Metric: validation.head.optimistic.hits_at_3 = 0.29867776360829584
# Metric: validation.tail.optimistic.hits_at_3 = 0.47278340828243504
# Metric: validation.both.optimistic.hits_at_3 = 0.38573058594536547
# Metric: validation.head.realistic.hits_at_3 = 0.29867776360829584
# Metric: validation.tail.realistic.hits_at_3 = 0.47278340828243504
# Metric: validation.both.realistic.hits_at_3 = 0.38573058594536547
# Metric: validation.head.pessimistic.hits_at_3 = 0.29867776360829584
# Metric: validation.tail.pessimistic.hits_at_3 = 0.47278340828243504
# Metric: validation.both.pessimistic.hits_at_3 = 0.38573058594536547
# Metric: validation.head.optimistic.hits_at_5 = 0.3551916235988993
# Metric: validation.tail.optimistic.hits_at_5 = 0.5274179475132559
# Metric: validation.both.optimistic.hits_at_5 = 0.4413047855560776
# Metric: validation.head.realistic.hits_at_5 = 0.3551916235988993
# Metric: validation.tail.realistic.hits_at_5 = 0.5274179475132559
# Metric: validation.both.realistic.hits_at_5 = 0.4413047855560776
# Metric: validation.head.pessimistic.hits_at_5 = 0.3551916235988993
# Metric: validation.tail.pessimistic.hits_at_5 = 0.5274179475132559
# Metric: validation.both.pessimistic.hits_at_5 = 0.4413047855560776
# Metric: validation.head.optimistic.hits_at_10 = 0.4550640982616283
# Metric: validation.tail.optimistic.hits_at_10 = 0.5849385864823142
# Metric: validation.both.optimistic.hits_at_10 = 0.5200013423719713
# Metric: validation.head.realistic.hits_at_10 = 0.4550640982616283
# Metric: validation.tail.realistic.hits_at_10 = 0.5849385864823142
# Metric: validation.both.realistic.hits_at_10 = 0.5200013423719713
# Metric: validation.head.pessimistic.hits_at_10 = 0.4550640982616283
# Metric: validation.tail.pessimistic.hits_at_10 = 0.5849385864823142
# Metric: validation.both.pessimistic.hits_at_10 = 0.5200013423719713
# Training batches on cuda:0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Step: 188
# Metric: loss = 0.03407420963048935
# Step: 188
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.2732651274420541
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.4163720576610145
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.34481859255153435
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.27326512336730957
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.41637206077575684
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.3448185920715332
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.27326512737232755
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.4163720565107689
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.3448185919415483
# Metric: validation.head.optimistic.hits_at_1 = 0.186656822605544
# Metric: validation.tail.optimistic.hits_at_1 = 0.3225719846969595
# Metric: validation.both.optimistic.hits_at_1 = 0.25461440365125176
# Metric: validation.head.realistic.hits_at_1 = 0.186656822605544
# Metric: validation.tail.realistic.hits_at_1 = 0.3225719846969595
# Metric: validation.both.realistic.hits_at_1 = 0.25461440365125176
# Metric: validation.head.pessimistic.hits_at_1 = 0.186656822605544
# Metric: validation.tail.pessimistic.hits_at_1 = 0.3225719846969595
# Metric: validation.both.pessimistic.hits_at_1 = 0.25461440365125176
# Metric: validation.head.optimistic.hits_at_3 = 0.29814081481978655
# Metric: validation.tail.optimistic.hits_at_3 = 0.4717766293039801
# Metric: validation.both.optimistic.hits_at_3 = 0.38495872206188336
# Metric: validation.head.realistic.hits_at_3 = 0.29814081481978655
# Metric: validation.tail.realistic.hits_at_3 = 0.4717766293039801
# Metric: validation.both.realistic.hits_at_3 = 0.38495872206188336
# Metric: validation.head.pessimistic.hits_at_3 = 0.29814081481978655
# Metric: validation.tail.pessimistic.hits_at_3 = 0.4717766293039801
# Metric: validation.both.pessimistic.hits_at_3 = 0.38495872206188336
# Metric: validation.head.optimistic.hits_at_5 = 0.3556614537888449
# Metric: validation.tail.optimistic.hits_at_5 = 0.5282233706960199
# Metric: validation.both.optimistic.hits_at_5 = 0.44194241224243236
# Metric: validation.head.realistic.hits_at_5 = 0.3556614537888449
# Metric: validation.tail.realistic.hits_at_5 = 0.5282233706960199
# Metric: validation.both.realistic.hits_at_5 = 0.44194241224243236
# Metric: validation.head.pessimistic.hits_at_5 = 0.3556614537888449
# Metric: validation.tail.pessimistic.hits_at_5 = 0.5282233706960199
# Metric: validation.both.pessimistic.hits_at_5 = 0.44194241224243236
# Metric: validation.head.optimistic.hits_at_10 = 0.4545942680716827
# Metric: validation.tail.optimistic.hits_at_10 = 0.5852070608765689
# Metric: validation.both.optimistic.hits_at_10 = 0.5199006644741258
# Metric: validation.head.realistic.hits_at_10 = 0.4545942680716827
# Metric: validation.tail.realistic.hits_at_10 = 0.5852070608765689
# Metric: validation.both.realistic.hits_at_10 = 0.5199006644741258
# Metric: validation.head.pessimistic.hits_at_10 = 0.4545942680716827
# Metric: validation.tail.pessimistic.hits_at_10 = 0.5852070608765689
# Metric: validation.both.pessimistic.hits_at_10 = 0.5199006644741258

# %%
torch.save(model,f"{model_name}/model.pth")
model = torch.load(f"{model_name}/model.pth")

# %%
print("Train error per epoch:")
df = pd.DataFrame(train_epoch)
print(df)
df.to_csv(f"{model_name}/{model_name}_train_error_per_epoch.csv")
# Out:
# Train error per epoch:
#             0
# 0    3.500787
# 1    2.933884
# 2    2.363729
# 3    1.814819
# 4    1.318954
# ..        ...
# 183  0.034680
# 184  0.035042
# 185  0.033582
# 186  0.033988
# 187  0.034074
#
# [188 rows x 1 columns]

# %%
training_evaluation_start = time.time()
# train
print("Train error")
show_metrics(train_evaluator.evaluate(
        model=model,
        mapped_triples=dataset.training.mapped_triples,
        additional_filter_triples=[
        dataset.training.mapped_triples,
    ]
    ).to_dict(),model_name,'train_metrics')
training_evaluation_duration = time.time() - training_evaluation_start
# Out:
# Train error
# Evaluating on cuda:0:   0%|          | 0.00/26.5k [00:00<?, ?triple/s]
# head
#                             optimistic  realistic  pessimistic
# inverse_harmonic_mean_rank    0.907786   0.907786     0.907786
# hits_at_1                     0.877516   0.877516     0.877516
# hits_at_3                     0.928110   0.928110     0.928110
# hits_at_5                     0.945025   0.945025     0.945025
# hits_at_10                    0.965754   0.965754     0.965754
# tail
#                             optimistic  realistic  pessimistic
# inverse_harmonic_mean_rank    0.929812   0.929811     0.929810
# hits_at_1                     0.906249   0.906249     0.906249
# hits_at_3                     0.946158   0.946158     0.946158
# hits_at_5                     0.958467   0.958467     0.958467
# hits_at_10                    0.970361   0.970361     0.970361
# both
#                             optimistic  realistic  pessimistic
# inverse_harmonic_mean_rank    0.918799   0.918799     0.918798
# hits_at_1                     0.891882   0.891882     0.891882
# hits_at_3                     0.937134   0.937134     0.937134
# hits_at_5                     0.951746   0.951746     0.951746
# hits_at_10                    0.968057   0.968057     0.968057

# %%
validation_evaluation_start = time.time()
# validation
print("Validation error")
show_metrics(valid_evaluator.evaluate(
        model=model,
        mapped_triples=dataset.validation.mapped_triples,
        additional_filter_triples=[
            # filtering of other positive triples
            dataset.training.mapped_triples
        ],
    ).to_dict(),model_name,'validation_metrics')
validation_evaluation_duration = time.time() - validation_evaluation_start
# Out:
# Validation error
# Evaluating on cuda:0:   0%|          | 0.00/14.9k [00:00<?, ?triple/s]
# head
#                             optimistic  realistic  pessimistic
# inverse_harmonic_mean_rank    0.272440   0.272440     0.272440
# hits_at_1                     0.188737   0.188737     0.188737
# hits_at_3                     0.296530   0.296530     0.296530
# hits_at_5                     0.350762   0.350762     0.350762
# hits_at_10                    0.444392   0.444392     0.444392
# tail
#                             optimistic  realistic  pessimistic
# inverse_harmonic_mean_rank    0.420272   0.420270     0.420269
# hits_at_1                     0.328680   0.328680     0.328680
# hits_at_3                     0.474461   0.474461     0.474461
# hits_at_5                     0.526545   0.526478     0.526478
# hits_at_10                    0.580643   0.580643     0.580643
# both
#                             optimistic  realistic  pessimistic
# inverse_harmonic_mean_rank    0.346356   0.346355     0.346355
# hits_at_1                     0.258709   0.258709     0.258709
# hits_at_3                     0.385496   0.385496     0.385496
# hits_at_5                     0.438654   0.438620     0.438620
# hits_at_10                    0.512518   0.512518     0.512518

# %%
testing_evaluation_start = time.time()
# result on the test set
print("Test error")
show_metrics(test_evaluator.evaluate(
        model=model,
        mapped_triples=dataset.testing.mapped_triples,
        additional_filter_triples=[
            # filtering of other positive triples
            dataset.training.mapped_triples,
            dataset.validation.mapped_triples,
        ],
    ).to_dict(),model_name,'test_metrics')
testing_evaluation_duration = time.time() - testing_evaluation_start

# %%
infodict = {}
infodict['device'] = model.device
infodict['parameters bytes'] = model.num_parameter_bytes
infodict['number parameters'] = model.num_parameters
infodict['training duration'] = training_duration
infodict['training evaluation duration'] = training_evaluation_duration
infodict['validation evaluation duration'] = validation_evaluation_duration
infodict['testing evaluation duration'] = testing_evaluation_duration
infodict["Operating system name"] = platform.system()
infodict["Operating system version"] = platform.release()
infodict["Processor architecture"] = platform.machine()
infodict["Python version"] = sys.version
infodict["Processor model name"] = cpuinfo.get_cpu_info()['brand_raw']
infodict['Number cpu cores'] = os.cpu_count()
infodict["Total physical memory"] = psutil.virtual_memory().total

# %%
output = subprocess.check_output(['nvidia-smi', '--query-gpu=name', '--format=csv'])
output = output.decode('utf-8')  # convert byte string to regular string

# split output into rows and remove header row
rows = output.strip().split('\n')[1:]

# extract GPU names from each row
gpu_names = []
for row in rows:
    name = row.strip()
    gpu_names.append(name)

infodict['GPU'] = gpu_names[0]

# %%
infodict['loss'] = NSSALoss
infodict['embedding_dim'] = embedding_dim
infodict['learning_rate'] = learning_rate
infodict['optimizer'] = Adam
infodict['num_epochs'] = num_epochs
infodict['patience'] = patience

# %%
info_df = pd.DataFrame(columns=['name','value'], data = infodict.items())
info_df.to_csv(f"{model_name}/{model_name}_information.csv")
print(info_df)
# Out:
#                               name  \
# 0                           device
# 1                 parameters bytes
# 2                number parameters
# 3                training duration
# 4     training evaluation duration
# 5   validation evaluation duration
# 6            Operating system name
# 7         Operating system version
# 8           Processor architecture
# 9                   Python version
# 10            Processor model name
# 11                Number cpu cores
# 12           Total physical memory
# 13                             GPU
# 14                            loss
# 15                   embedding_dim
# 16                   learning_rate
# 17                       optimizer
# 18                      num_epochs
# 19                        patience
#
#                                                 value
# 0                                              cuda:0
# 1                                            26660800
# 2                                             6665200
# 3                                         1995.330162
# 4                                             20.4025
# 5                                           12.732675
# 6                                               Linux
# 7                         3.10.0-1160.90.1.el7.x86_64
# 8                                              x86_64
# 9   3.10.9 (main, Mar  8 2023, 10:47:38) [GCC 11.2.0]
# 10           Intel(R) Xeon(R) Gold 6130 CPU @ 2.10GHz
# 11                                                 32
# 12                                        99980713984
# 13                                           Tesla T4
# 14                   <class 'pykeen.losses.NSSALoss'>
# 15                                                200
# 16                                               0.05
# 17                    <class 'torch.optim.adam.Adam'>
# 18                                               2000
# 19                                                 20

# %%
def zip_folder(folder_path, output_path):
    with zipfile.ZipFile(output_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                zipf.write(os.path.join(root, file))

folder_path = model_name
output_path = f'{model_name}.zip'

zip_folder(folder_path, output_path)
