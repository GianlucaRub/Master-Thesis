# %%
import networkx as nx
from pykeen.pipeline import pipeline
from pykeen.datasets import Nations, get_dataset
import matplotlib.pyplot as plt
import matplotlib as mpl
import torch
from pykeen.models import predict
import json

# %%
from pykeen.hpo import hpo_pipeline
import os
from pykeen.triples import TriplesFactory


NATIONS_TRAIN_PATH = "20_social_graph_service_0.tsv"
NATIONS_TEST_PATH = "20_social_graph_service_1.tsv"
NATIONS_VALIDATE_PATH = "20_social_graph_service_2.tsv"


training = TriplesFactory.from_path(NATIONS_TRAIN_PATH)
testing = TriplesFactory.from_path(
    NATIONS_TEST_PATH,
    entity_to_id=training.entity_to_id,
    relation_to_id=training.relation_to_id,
)
validation = TriplesFactory.from_path(
    NATIONS_VALIDATE_PATH,
    entity_to_id=training.entity_to_id,
    relation_to_id=training.relation_to_id,
)
pipeline_result = pipeline(
#    n_trials=3,  # you probably want more than this
    training=training,
    testing=testing,
    validation=validation,
    model='TransE',
    epochs=5,  # short epochs for testing - you should go higher
    random_seed = 1234
)
pipeline_result.save_to_directory(os.getcwd()+'/prova_transE')
# Out:
# No cuda devices were available. The model runs on CPU
# Training epochs on cpu:   0%|          | 0/5 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|          | 0/1 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/1 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/1 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/1 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/1 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu:   0%|          | 0.00/9.00 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.08s seconds
# INFO:pykeen.triples.triples_factory:Stored TriplesFactory(num_entities=3, num_relations=9, create_inverse_triples=False, num_triples=9, path="C:\Users\gianl\OneDrive - Politecnico di Milano\Master Thesis\python\dataset\20_social_graph_service_0.tsv") to file:///C:/Users/gianl/OneDrive%20-%20Politecnico%20di%20Milano/Master%20Thesis/python/dataset/prova_transE/training_triples
# INFO:pykeen.pipeline.api:Saved to directory: file:///C:/Users/gianl/OneDrive%20-%20Politecnico%20di%20Milano/Master%20Thesis/python/dataset/prova_transE

# %%
help(pipeline_result)
# Out:
# Help on PipelineResult in module pykeen.pipeline.api object:
#
# class PipelineResult(pykeen.utils.Result)
#  |  PipelineResult(random_seed: int, model: pykeen.models.base.Model, training: pykeen.triples.triples_factory.CoreTriplesFactory, training_loop: pykeen.training.training_loop.TrainingLoop, losses: List[float], metric_results: pykeen.evaluation.evaluator.MetricResults, train_seconds: float, evaluate_seconds: float, stopper: Optional[pykeen.stoppers.stopper.Stopper] = None, configuration: Mapping[str, Any] = <factory>, metadata: MutableMapping[str, Any] = <factory>, version: str = <factory>, git_hash: str = <factory>) -> None
#  |
#  |  A dataclass containing the results of running :func:`pykeen.pipeline.pipeline`.
#  |
#  |  Method resolution order:
#  |      PipelineResult
#  |      pykeen.utils.Result
#  |      abc.ABC
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __eq__(self, other)
#  |
#  |  __init__(self, random_seed: int, model: pykeen.models.base.Model, training: pykeen.triples.triples_factory.CoreTriplesFactory, training_loop: pykeen.training.training_loop.TrainingLoop, losses: List[float], metric_results: pykeen.evaluation.evaluator.MetricResults, train_seconds: float, evaluate_seconds: float, stopper: Optional[pykeen.stoppers.stopper.Stopper] = None, configuration: Mapping[str, Any] = <factory>, metadata: MutableMapping[str, Any] = <factory>, version: str = <factory>, git_hash: str = <factory>) -> None
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |
#  |  get_metric(self, key: str) -> float
#  |      Get the given metric out of the metric result object.
#  |
#  |  plot(self, **kwargs)
#  |      Plot all plots.
#  |
#  |      :param kwargs: The keyword arguments passed to :func:`pykeen.pipeline_plot.plot`
#  |      :returns: The axis
#  |
#  |  plot_early_stopping(self, **kwargs)
#  |      Plot the evaluations during early stopping.
#  |
#  |      :param kwargs: The keyword arguments passed to :func:`pykeen.pipeline.plot_utils.plot_early_stopping`
#  |      :returns: The axis
#  |
#  |  plot_er(self, **kwargs)
#  |      Plot the reduced entities and relation vectors in 2D.
#  |
#  |      :param kwargs: The keyword arguments passed to :func:`pykeen.pipeline.plot_utils.plot_er`
#  |      :returns: The axis
#  |
#  |      .. warning::
#  |
#  |          Plotting relations and entities on the same plot is only
#  |          meaningful for translational distance models like TransE.
#  |
#  |  plot_losses(self, **kwargs)
#  |      Plot the losses per epoch.
#  |
#  |      :param kwargs: The keyword arguments passed to :func:`pykeen.pipeline.plot_utils.plot_losses`.
#  |      :returns: The axis
#  |
#  |  save_model(self, path: Union[str, pathlib.Path]) -> None
#  |      Save the trained model to the given path using :func:`torch.save`.
#  |
#  |      :param path: The path to which the model is saved. Should have an extension appropriate for a pickle,
#  |          like `*.pkl` or `*.pickle`.
#  |
#  |      The model contains within it the triples factory that was used for training.
#  |
#  |  save_to_directory(self, directory: Union[str, pathlib.Path], *, save_metadata: bool = True, save_replicates: bool = True, save_training: bool = True, **_kwargs) -> None
#  |      Save all artifacts in the given directory.
#  |
#  |      The serialization format looks as follows
#  |
#  |      .. code-block::
#  |
#  |          directory/
#  |              results.json
#  |              metadata.json
#  |              trained_model.pkl
#  |              training_triples/
#  |
#  |      All but the first component are optional and can be disabled, e.g. to save disk space during hyperparameter
#  |      tuning. `trained_model.pkl` is the full model saved via :func:`torch.save`, and can thus be loaded via
#  |      :func:`torch.load`, cf. `torch's serialization documentation
#  |      <https://pytorch.org/docs/stable/notes/serialization.html>`_. `training_triples` contains the training triples
#  |      factory, including label-to-id mappings, if used. It has been saved via
#  |      :meth:`pykeen.triples.CoreTriplesFactory.to_path_binary`, and can re-loaded via
#  |      :meth:`pykeen.triples.CoreTriplesFactory.from_path_binary`.
#  |
#  |      :param directory:
#  |          the directory path. It will be created including all parent directories if necessary
#  |      :param save_metadata:
#  |          whether to save metadata, cf. :attr:`PipelineResult.metadata`
#  |      :param save_replicates:
#  |          # TODO: rename param?
#  |          whether to save the trained model, cf. :meth:`PipelineResult.save_model`
#  |      :param save_training:
#  |          whether to save the training triples factory
#  |      :param _kwargs:
#  |          additional keyword-based parameters, which are ignored
#  |
#  |  save_to_ftp(self, directory: str, ftp: ftplib.FTP) -> None
#  |      Save all artifacts to the given directory in the FTP server.
#  |
#  |      :param directory: The directory in the FTP server to save to
#  |      :param ftp: A connection to the FTP server
#  |
#  |      The following code will train a model and upload it to FTP using Python's builtin
#  |      :class:`ftplib.FTP`:
#  |
#  |      .. code-block:: python
#  |
#  |          import ftplib
#  |          from pykeen.pipeline import pipeline
#  |
#  |          directory = 'test/test'
#  |          pipeline_result = pipeline(
#  |              model='TransE',
#  |              dataset='Kinships',
#  |          )
#  |          with ftplib.FTP(host='0.0.0.0', user='user', passwd='12345') as ftp:
#  |              pipeline_result.save_to_ftp(directory, ftp)
#  |
#  |      If you want to try this with your own local server, run this code based on the
#  |      example from Giampaolo Rodola's excellent library,
#  |      `pyftpdlib <https://github.com/giampaolo/pyftpdlib#quick-start>`_.
#  |
#  |      .. code-block:: python
#  |
#  |          import os
#  |          from pyftpdlib.authorizers import DummyAuthorizer
#  |          from pyftpdlib.handlers import FTPHandler
#  |          from pyftpdlib.servers import FTPServer
#  |
#  |          authorizer = DummyAuthorizer()
#  |          authorizer.add_user("user", "12345", homedir=os.path.expanduser('~/ftp'), perm="elradfmwMT")
#  |
#  |          handler = FTPHandler
#  |          handler.authorizer = authorizer
#  |
#  |          address = '0.0.0.0', 21
#  |          server = FTPServer(address, handler)
#  |          server.serve_forever()
#  |
#  |  save_to_s3(self, directory: str, bucket: str, s3=None) -> None
#  |      Save all artifacts to the given directory in an S3 Bucket.
#  |
#  |      :param directory: The directory in the S3 bucket
#  |      :param bucket: The name of the S3 bucket
#  |      :param s3: A client from :func:`boto3.client`, if already instantiated
#  |
#  |      .. note:: Need to have ``~/.aws/credentials`` file set up. Read: https://realpython.com/python-boto3-aws-s3/
#  |
#  |      The following code will train a model and upload it to S3 using :mod:`boto3`:
#  |
#  |      .. code-block:: python
#  |
#  |          import time
#  |          from pykeen.pipeline import pipeline
#  |          pipeline_result = pipeline(
#  |              dataset='Kinships',
#  |              model='TransE',
#  |          )
#  |          directory = f'tests/{time.strftime("%Y-%m-%d-%H%M%S")}'
#  |          bucket = 'pykeen'
#  |          pipeline_result.save_to_s3(directory, bucket=bucket)
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  title
#  |      The title of the experiment.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  METADATA_FILE_NAME = 'metadata.json'
#  |
#  |  MODEL_FILE_NAME = 'trained_model.pkl'
#  |
#  |  RESULT_FILE_NAME = 'results.json'
#  |
#  |  TRAINING_TRIPLES_FILE_NAME = 'training_triples'
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  __annotations__ = {'METADATA_FILE_NAME': typing.ClassVar[str], 'MODEL_...
#  |
#  |  __dataclass_fields__ = {'METADATA_FILE_NAME': Field(name='METADATA_FIL...
#  |
#  |  __dataclass_params__ = _DataclassParams(init=True,repr=True,eq=True,or...
#  |
#  |  __hash__ = None
#  |
#  |  stopper = None
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from pykeen.utils.Result:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
pipeline_result.metric_results.to_dict()
# Out:
# {'head': {'optimistic': {'inverse_harmonic_mean_rank': 0.8703703703703702,
#    'inverse_geometric_mean_rank': 0.8194807381480528,
#    'variance': 0.4444444444444444,
#    'median_absolute_deviation': 0.0,
#    'adjusted_inverse_harmonic_mean_rank': 0.6666666666666665,
#    'adjusted_arithmetic_mean_rank_index': 0.6666666666666667,
#    'standard_deviation': 0.6666666666666666,
#    'count': 9.0,
#    'z_inverse_harmonic_mean_rank': 2.7456258919345746,
#    'adjusted_arithmetic_mean_rank': 0.6666666666666666,
#    'adjusted_geometric_mean_rank_index': 0.7370974924752878,
#    'median_rank': 1.0,
#    'arithmetic_mean_rank': 1.3333333333333333,
#    'geometric_mean_rank': 1.2202849358728105,
#    'inverse_median_rank': 1.0,
#    'z_arithmetic_mean_rank': 2.4494897427831788,
#    'z_geometric_mean_rank': 2.2297856045790088,
#    'harmonic_mean_rank': 1.148936170212766,
#    'inverse_arithmetic_mean_rank': 0.75,
#    'hits_at_1': 0.7777777777777778,
#    'hits_at_3': 1.0,
#    'hits_at_5': 1.0,
#    'hits_at_10': 1.0,
#    'z_hits_at_k': 0.0,
#    'adjusted_hits_at_k': 0.0},
#   'realistic': {'inverse_harmonic_mean_rank': 0.8703703880310057,
#    'inverse_geometric_mean_rank': 0.8194807171821594,
#    'variance': 0.4444444477558136,
#    'median_absolute_deviation': 0.0,
#    'adjusted_inverse_harmonic_mean_rank': 0.6666667120797292,
#    'adjusted_arithmetic_mean_rank_index': 0.6666666269302368,
#    'standard_deviation': 0.6666666865348816,
#    'count': 9.0,
#    'z_inverse_harmonic_mean_rank': 2.745626078965495,
#    'adjusted_arithmetic_mean_rank': 0.6666666865348816,
#    'adjusted_geometric_mean_rank_index': 0.7370974889671609,
#    'median_rank': 1.0,
#    'arithmetic_mean_rank': 1.3333333730697632,
#    'geometric_mean_rank': 1.2202849388122559,
#    'inverse_median_rank': 1.0,
#    'z_arithmetic_mean_rank': 2.449489596782212,
#    'z_geometric_mean_rank': 2.2297855939666116,
#    'harmonic_mean_rank': 1.1489361468997683,
#    'inverse_arithmetic_mean_rank': 0.75,
#    'hits_at_1': 0.7777777777777778,
#    'hits_at_3': 1.0,
#    'hits_at_5': 1.0,
#    'hits_at_10': 1.0,
#    'z_hits_at_k': 0.0,
#    'adjusted_hits_at_k': 0.0},
#   'pessimistic': {'inverse_harmonic_mean_rank': 0.8703703703703702,
#    'inverse_geometric_mean_rank': 0.8194807381480528,
#    'variance': 0.4444444444444444,
#    'median_absolute_deviation': 0.0,
#    'adjusted_inverse_harmonic_mean_rank': 0.6666666666666665,
#    'adjusted_arithmetic_mean_rank_index': 0.6666666666666667,
#    'standard_deviation': 0.6666666666666666,
#    'count': 9.0,
#    'z_inverse_harmonic_mean_rank': 2.7456258919345746,
#    'adjusted_arithmetic_mean_rank': 0.6666666666666666,
#    'adjusted_geometric_mean_rank_index': 0.7370974924752878,
#    'median_rank': 1.0,
#    'arithmetic_mean_rank': 1.3333333333333333,
#    'geometric_mean_rank': 1.2202849358728105,
#    'inverse_median_rank': 1.0,
#    'z_arithmetic_mean_rank': 2.4494897427831788,
#    'z_geometric_mean_rank': 2.2297856045790088,
#    'harmonic_mean_rank': 1.148936170212766,
#    'inverse_arithmetic_mean_rank': 0.75,
#    'hits_at_1': 0.7777777777777778,
#    'hits_at_3': 1.0,
#    'hits_at_5': 1.0,
#    'hits_at_10': 1.0,
#    'z_hits_at_k': 0.0,
#    'adjusted_hits_at_k': 0.0}},
#  'tail': {'optimistic': {'inverse_harmonic_mean_rank': 0.8888888888888888,
#    'inverse_geometric_mean_rank': 0.8572439828530729,
#    'variance': 0.1728395061728395,
#    'median_absolute_deviation': 0.0,
#    'adjusted_inverse_harmonic_mean_rank': 0.714285714285714,
#    'adjusted_arithmetic_mean_rank_index': 0.7777777777777777,
#    'standard_deviation': 0.41573970964154905,
#    'count': 9.0,
#    'z_inverse_harmonic_mean_rank': 2.9417420270727597,
#    'adjusted_arithmetic_mean_rank': 0.6111111111111112,
#    'adjusted_geometric_mean_rank_index': 0.8012533090073779,
#    'median_rank': 1.0,
#    'arithmetic_mean_rank': 1.2222222222222223,
#    'geometric_mean_rank': 1.1665290395761165,
#    'inverse_median_rank': 1.0,
#    'z_arithmetic_mean_rank': 2.857738033247041,
#    'z_geometric_mean_rank': 2.4238626671299466,
#    'harmonic_mean_rank': 1.125,
#    'inverse_arithmetic_mean_rank': 0.8181818181818181,
#    'hits_at_1': 0.7777777777777778,
#    'hits_at_3': 1.0,
#    'hits_at_5': 1.0,
#    'hits_at_10': 1.0,
#    'z_hits_at_k': 0.0,
#    'adjusted_hits_at_k': 0.0},
#   'realistic': {'inverse_harmonic_mean_rank': 0.8888888955116272,
#    'inverse_geometric_mean_rank': 0.8572439551353455,
#    'variance': 0.17283949255943298,
#    'median_absolute_deviation': 0.0,
#    'adjusted_inverse_harmonic_mean_rank': 0.7142857313156128,
#    'adjusted_arithmetic_mean_rank_index': 0.7777777910232544,
#    'standard_deviation': 0.41573968529701233,
#    'count': 9.0,
#    'z_inverse_harmonic_mean_rank': 2.941742097209355,
#    'adjusted_arithmetic_mean_rank': 0.6111111044883728,
#    'adjusted_geometric_mean_rank_index': 0.8012532853362053,
#    'median_rank': 1.0,
#    'arithmetic_mean_rank': 1.2222222089767456,
#    'geometric_mean_rank': 1.1665290594100952,
#    'inverse_median_rank': 1.0,
#    'z_arithmetic_mean_rank': 2.8577380819140297,
#    'z_geometric_mean_rank': 2.4238625955225404,
#    'harmonic_mean_rank': 1.1249999916180968,
#    'inverse_arithmetic_mean_rank': 0.8181818127632141,
#    'hits_at_1': 0.7777777777777778,
#    'hits_at_3': 1.0,
#    'hits_at_5': 1.0,
#    'hits_at_10': 1.0,
#    'z_hits_at_k': 0.0,
#    'adjusted_hits_at_k': 0.0},
#   'pessimistic': {'inverse_harmonic_mean_rank': 0.8888888888888888,
#    'inverse_geometric_mean_rank': 0.8572439828530729,
#    'variance': 0.1728395061728395,
#    'median_absolute_deviation': 0.0,
#    'adjusted_inverse_harmonic_mean_rank': 0.714285714285714,
#    'adjusted_arithmetic_mean_rank_index': 0.7777777777777777,
#    'standard_deviation': 0.41573970964154905,
#    'count': 9.0,
#    'z_inverse_harmonic_mean_rank': 2.9417420270727597,
#    'adjusted_arithmetic_mean_rank': 0.6111111111111112,
#    'adjusted_geometric_mean_rank_index': 0.8012533090073779,
#    'median_rank': 1.0,
#    'arithmetic_mean_rank': 1.2222222222222223,
#    'geometric_mean_rank': 1.1665290395761165,
#    'inverse_median_rank': 1.0,
#    'z_arithmetic_mean_rank': 2.857738033247041,
#    'z_geometric_mean_rank': 2.4238626671299466,
#    'harmonic_mean_rank': 1.125,
#    'inverse_arithmetic_mean_rank': 0.8181818181818181,
#    'hits_at_1': 0.7777777777777778,
#    'hits_at_3': 1.0,
#    'hits_at_5': 1.0,
#    'hits_at_10': 1.0,
#    'z_hits_at_k': 0.0,
#    'adjusted_hits_at_k': 0.0}},
#  'both': {'optimistic': {'inverse_harmonic_mean_rank': 0.8796296296296294,
#    'inverse_geometric_mean_rank': 0.8381497072966219,
#    'variance': 0.31172839506172845,
#    'median_absolute_deviation': 0.0,
#    'adjusted_inverse_harmonic_mean_rank': 0.6904761904761898,
#    'adjusted_arithmetic_mean_rank_index': 0.7222222222222223,
#    'standard_deviation': 0.558326423395605,
#    'count': 18.0,
#    'z_inverse_harmonic_mean_rank': 4.021576422632906,
#    'adjusted_arithmetic_mean_rank': 0.6388888888888888,
#    'adjusted_geometric_mean_rank_index': 0.7666436600482591,
#    'median_rank': 1.0,
#    'arithmetic_mean_rank': 1.2777777777777777,
#    'geometric_mean_rank': 1.1931042763534596,
#    'inverse_median_rank': 1.0,
#    'z_arithmetic_mean_rank': 3.7527767497325684,
#    'z_geometric_mean_rank': 3.2512040810463088,
#    'harmonic_mean_rank': 1.136842105263158,
#    'inverse_arithmetic_mean_rank': 0.782608695652174,
#    'hits_at_1': 0.7777777777777778,
#    'hits_at_3': 1.0,
#    'hits_at_5': 1.0,
#    'hits_at_10': 1.0,
#    'z_hits_at_k': 0.0,
#    'adjusted_hits_at_k': 0.0},
#   'realistic': {'inverse_harmonic_mean_rank': 0.8796296715736388,
#    'inverse_geometric_mean_rank': 0.8381497263908386,
#    'variance': 0.3117283880710602,
#    'median_absolute_deviation': 0.0,
#    'adjusted_inverse_harmonic_mean_rank': 0.6904762983322139,
#    'adjusted_arithmetic_mean_rank_index': 0.7222222089767456,
#    'standard_deviation': 0.5583264231681824,
#    'count': 18.0,
#    'z_inverse_harmonic_mean_rank': 4.021577050824362,
#    'adjusted_arithmetic_mean_rank': 0.6388888955116272,
#    'adjusted_geometric_mean_rank_index': 0.7666436712059717,
#    'median_rank': 1.0,
#    'arithmetic_mean_rank': 1.2777777910232544,
#    'geometric_mean_rank': 1.1931042671203613,
#    'inverse_median_rank': 1.0,
#    'z_arithmetic_mean_rank': 3.7527766809070524,
#    'z_geometric_mean_rank': 3.251204128364251,
#    'harmonic_mean_rank': 1.1368420510543047,
#    'inverse_arithmetic_mean_rank': 0.782608687877655,
#    'hits_at_1': 0.7777777777777778,
#    'hits_at_3': 1.0,
#    'hits_at_5': 1.0,
#    'hits_at_10': 1.0,
#    'z_hits_at_k': 0.0,
#    'adjusted_hits_at_k': 0.0},
#   'pessimistic': {'inverse_harmonic_mean_rank': 0.8796296296296294,
#    'inverse_geometric_mean_rank': 0.8381497072966219,
#    'variance': 0.31172839506172845,
#    'median_absolute_deviation': 0.0,
#    'adjusted_inverse_harmonic_mean_rank': 0.6904761904761898,
#    'adjusted_arithmetic_mean_rank_index': 0.7222222222222223,
#    'standard_deviation': 0.558326423395605,
#    'count': 18.0,
#    'z_inverse_harmonic_mean_rank': 4.021576422632906,
#    'adjusted_arithmetic_mean_rank': 0.6388888888888888,
#    'adjusted_geometric_mean_rank_index': 0.7666436600482591,
#    'median_rank': 1.0,
#    'arithmetic_mean_rank': 1.2777777777777777,
#    'geometric_mean_rank': 1.1931042763534596,
#    'inverse_median_rank': 1.0,
#    'z_arithmetic_mean_rank': 3.7527767497325684,
#    'z_geometric_mean_rank': 3.2512040810463088,
#    'harmonic_mean_rank': 1.136842105263158,
#    'inverse_arithmetic_mean_rank': 0.782608695652174,
#    'hits_at_1': 0.7777777777777778,
#    'hits_at_3': 1.0,
#    'hits_at_5': 1.0,
#    'hits_at_10': 1.0,
#    'z_hits_at_k': 0.0,
#    'adjusted_hits_at_k': 0.0}}}

# %%
pipeline_result.plot_losses()
# Out:
# <AxesSubplot:title={'center':'Losses Plot'}, xlabel='Epoch', ylabel='marginranking Loss'>

# %%
model = pipeline_result.model
# Predict tails
predicted_tails_df = predict.get_prediction_df(
    model=model, head_label = "user-service", relation_label="get_user_id_server", triples_factory=pipeline_result.training,
)


predicted_tails_df
# Out:
#    tail_id            tail_label      score  in_training
# 2        2          user-service  -5.823895        False
# 1        1  social-graph-service  -9.602411         True
# 0        0      nginx-web-server -10.023479        False

# %%
# Predict relations
predicted_relations_df = predict.get_prediction_df(
    model=model, head_label="user-service", tail_label="user-service", triples_factory=pipeline_result.training,
)
predicted_relations_df
# Out:
#    relation_id                    relation_label     score  in_training
# 4            4                get_user_id_server -5.823895        False
# 3            3       follow_with_username_server -5.824523        False
# 1            1                            Follow -5.927852        False
# 2            2                     follow_server -5.965435        False
# 6            6  social_graph_mongo_update_client -6.206998        False
# 7            7  social_graph_redis_update_client -6.237367        False
# 0            0             /wrk2-api/user/follow -6.250849        False
# 8            8       user_mmc_get_user_id_client -6.321355         True
# 5            5               mongo_update_client -6.402029        False

# %%
# Predict heads
predicted_heads_df = predict.get_prediction_df(
    model=model, relation_label="get_user_id_server", tail_label="user-service", triples_factory=pipeline_result.training
)
predicted_heads_df
# Out:
#    head_id            head_label      score  in_training
# 2        2          user-service  -5.823895        False
# 1        1  social-graph-service -10.022802        False
# 0        0      nginx-web-server -10.277517        False

# %%
# Score all triples (memory intensive)
predictions_df = predict.get_all_prediction_df(model, triples_factory=pipeline_result.training)
predictions_df
# Out:
# WARNING:pykeen.models.predict:_predict is an expensive operation, involving 81 score evaluations.
# WARNING:pykeen.models.predict:Not providing k to score_all_triples entails huge memory requirements for reasonably-sized knowledge graphs.
# scoring:   0%|          | 0.00/27.0 [00:00<?, ?batch/s]
#     head_id            head_label  relation_id               relation_label  \
# 0         2          user-service            4           get_user_id_server
# 1         0      nginx-web-server            4           get_user_id_server
# 2         1  social-graph-service            4           get_user_id_server
# 3         2          user-service            3  follow_with_username_server
# 4         1  social-graph-service            3  follow_with_username_server
# ..      ...                   ...          ...                          ...
# 76        2          user-service            5          mongo_update_client
# 77        0      nginx-web-server            0        /wrk2-api/user/follow
# 78        2          user-service            1                       Follow
# 79        0      nginx-web-server            0        /wrk2-api/user/follow
# 80        2          user-service            1                       Follow
#
#     tail_id            tail_label      score  in_training
# 0         2          user-service  -5.823895        False
# 1         0      nginx-web-server  -5.823895        False
# 2         1  social-graph-service  -5.823895        False
# 3         2          user-service  -5.824523        False
# 4         1  social-graph-service  -5.824523        False
# ..      ...                   ...        ...          ...
# 76        0      nginx-web-server -10.698528        False
# 77        1  social-graph-service -10.793466        False
# 78        1  social-graph-service -11.090796        False
# 79        2          user-service -11.332861        False
# 80        0      nginx-web-server -11.926935        False
#
# [81 rows x 8 columns]

# %%
# Score top K triples (computationally expensive)
top_k_predictions_df = predict.get_all_prediction_df(model, k=10, triples_factory=pipeline_result.training)
top_k_predictions_df
# Out:
# WARNING:pykeen.models.predict:_predict is an expensive operation, involving 81 score evaluations.
# scoring:   0%|          | 0.00/27.0 [00:00<?, ?batch/s]
#    head_id            head_label  relation_id               relation_label  \
# 0        0      nginx-web-server            4           get_user_id_server
# 1        1  social-graph-service            4           get_user_id_server
# 2        2          user-service            4           get_user_id_server
# 3        0      nginx-web-server            3  follow_with_username_server
# 4        1  social-graph-service            3  follow_with_username_server
# 5        2          user-service            3  follow_with_username_server
# 6        0      nginx-web-server            1                       Follow
# 7        1  social-graph-service            1                       Follow
# 8        2          user-service            1                       Follow
# 9        0      nginx-web-server            2                follow_server
#
#    tail_id            tail_label     score  in_training
# 0        0      nginx-web-server -5.823895        False
# 1        1  social-graph-service -5.823895        False
# 2        2          user-service -5.823895        False
# 3        0      nginx-web-server -5.824523        False
# 4        1  social-graph-service -5.824523        False
# 5        2          user-service -5.824523        False
# 6        0      nginx-web-server -5.927852         True
# 7        1  social-graph-service -5.927852        False
# 8        2          user-service -5.927852        False
# 9        0      nginx-web-server -5.965435        False

# %%
# Score a given list of triples
score_df = predict.predict_triples_df(
    model=model,
    triples=[('user-service', 'user_mmc_get_user_id_client', 'user-service'), ('user-service', 'get_user_id_server', 'social-graph-service')],
    triples_factory=pipeline_result.training,
)
score_df
# Out:
#    head_id    head_label  relation_id               relation_label  tail_id  \
# 0        2  user-service            4           get_user_id_server        1
# 1        2  user-service            8  user_mmc_get_user_id_client        2
#
#              tail_label     score
# 0  social-graph-service -9.602411
# 1          user-service -6.321355

# %% [markdown]
# ## Evaluation
# If the results are the same, it means that the traces are the same

# %%
from pykeen.evaluation import evaluate, ClassificationEvaluator
results_training = evaluate(model=model,mapped_triples=pipeline_result.training.mapped_triples,evaluator = ClassificationEvaluator(),mode=None,additional_filter_triples=[pipeline_result.training.mapped_triples])
results_training.to_dict()
# Out:
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu:   0%|          | 0.00/9.00 [00:00<?, ?triple/s]
# C:\Users\gianl\anaconda3\envs\MasterThesis\lib\site-packages\rexmex\metrics\classification.py:484: RuntimeWarning: invalid value encountered in power
#   pthr = (fpr**0.5) / (fpr**0.5 + tpr**0.5)
# C:\Users\gianl\anaconda3\envs\MasterThesis\lib\site-packages\rexmex\metrics\classification.py:547: RuntimeWarning: invalid value encountered in power
#   fm = (ppv * tpr) ** 0.5
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.05s seconds
# {'true_negative_rate': 10.239038467407227,
#  'true_positive_rate': -6.893648147583008,
#  'positive_predictive_value': 0.2717059254646301,
#  'negative_predictive_value': 0.721777617931366,
#  'false_negative_rate': 7.893648147583008,
#  'false_positive_rate': -9.239038467407227,
#  'false_discovery_rate': 0.7282940745353699,
#  'false_omission_rate': 0.27822235226631165,
#  'positive_likelihood_ratio': 0.7461434602737427,
#  'negative_likelihood_ratio': 0.7709364891052246,
#  'prevalence_threshold': nan,
#  'threat_score': 0.39441683888435364,
#  'fowlkes_mallows_index': nan,
#  'informedness': 2.3453903198242188,
#  'markedness': -0.006516456604003906,
#  'diagnostic_odds_ratio': 0.9678403735160828,
#  'roc_auc_score': 0.8179012345679012,
#  'accuracy_score': 0.8518518518518519,
#  'balanced_accuracy_score': 0.8333333333333333,
#  'f1_score': 0.7777777777777778,
#  'average_precision_score': 0.594685657041979,
#  'matthews_correlation_coefficient': 0.6666666666666666}

# %%
results_validation = evaluate(model=model,mapped_triples=validation.mapped_triples,evaluator = ClassificationEvaluator(),mode=None,additional_filter_triples=[pipeline_result.training.mapped_triples])
results_validation.to_dict()
# Out:
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu:   0%|          | 0.00/9.00 [00:00<?, ?triple/s]
# C:\Users\gianl\anaconda3\envs\MasterThesis\lib\site-packages\rexmex\metrics\classification.py:484: RuntimeWarning: invalid value encountered in power
#   pthr = (fpr**0.5) / (fpr**0.5 + tpr**0.5)
# C:\Users\gianl\anaconda3\envs\MasterThesis\lib\site-packages\rexmex\metrics\classification.py:547: RuntimeWarning: invalid value encountered in power
#   fm = (ppv * tpr) ** 0.5
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.04s seconds
# {'true_negative_rate': 10.239038467407227,
#  'true_positive_rate': -6.893648147583008,
#  'positive_predictive_value': 0.2717059254646301,
#  'negative_predictive_value': 0.721777617931366,
#  'false_negative_rate': 7.893648147583008,
#  'false_positive_rate': -9.239038467407227,
#  'false_discovery_rate': 0.7282940745353699,
#  'false_omission_rate': 0.27822235226631165,
#  'positive_likelihood_ratio': 0.7461434602737427,
#  'negative_likelihood_ratio': 0.7709364891052246,
#  'prevalence_threshold': nan,
#  'threat_score': 0.39441683888435364,
#  'fowlkes_mallows_index': nan,
#  'informedness': 2.3453903198242188,
#  'markedness': -0.006516456604003906,
#  'diagnostic_odds_ratio': 0.9678403735160828,
#  'roc_auc_score': 0.8179012345679012,
#  'accuracy_score': 0.8518518518518519,
#  'balanced_accuracy_score': 0.8333333333333333,
#  'f1_score': 0.7777777777777778,
#  'average_precision_score': 0.594685657041979,
#  'matthews_correlation_coefficient': 0.6666666666666666}

# %%
results_testing = evaluate(model=model,mapped_triples=testing.mapped_triples,evaluator = ClassificationEvaluator(),mode=None,additional_filter_triples=[pipeline_result.training.mapped_triples])
results_testing.to_dict()
# Out:
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu:   0%|          | 0.00/9.00 [00:00<?, ?triple/s]
# C:\Users\gianl\anaconda3\envs\MasterThesis\lib\site-packages\rexmex\metrics\classification.py:484: RuntimeWarning: invalid value encountered in power
#   pthr = (fpr**0.5) / (fpr**0.5 + tpr**0.5)
# C:\Users\gianl\anaconda3\envs\MasterThesis\lib\site-packages\rexmex\metrics\classification.py:547: RuntimeWarning: invalid value encountered in power
#   fm = (ppv * tpr) ** 0.5
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.04s seconds
# {'true_negative_rate': 10.239038467407227,
#  'true_positive_rate': -6.893648147583008,
#  'positive_predictive_value': 0.2717059254646301,
#  'negative_predictive_value': 0.721777617931366,
#  'false_negative_rate': 7.893648147583008,
#  'false_positive_rate': -9.239038467407227,
#  'false_discovery_rate': 0.7282940745353699,
#  'false_omission_rate': 0.27822235226631165,
#  'positive_likelihood_ratio': 0.7461434602737427,
#  'negative_likelihood_ratio': 0.7709364891052246,
#  'prevalence_threshold': nan,
#  'threat_score': 0.39441683888435364,
#  'fowlkes_mallows_index': nan,
#  'informedness': 2.3453903198242188,
#  'markedness': -0.006516456604003906,
#  'diagnostic_odds_ratio': 0.9678403735160828,
#  'roc_auc_score': 0.8179012345679012,
#  'accuracy_score': 0.8518518518518519,
#  'balanced_accuracy_score': 0.8333333333333333,
#  'f1_score': 0.7777777777777778,
#  'average_precision_score': 0.594685657041979,
#  'matthews_correlation_coefficient': 0.6666666666666666}
