# %%
import json
  
# Opening JSON file
f = open('socialNetwork/traces/397d8cae76d1c0a7.json')
  
# returns JSON object as 
# a dictionary
data = json.load(f)
  
# Iterating through the json
# list
# for i in data['emp_details']:
#     print(i)
print(data) 
# Closing file
f.close()
# Out:
# {'data': [{'traceID': '397d8cae76d1c0a7', 'spans': [{'traceID': '397d8cae76d1c0a7', 'spanID': '8dd50673f63ceb07', 'flags': 1, 'operationName': 'UploadUserMentions', 'references': [{'refType': 'CHILD_OF', 'traceID': '397d8cae76d1c0a7', 'spanID': '6304ae45b9ab3871'}], 'startTime': 1557906198321583, 'duration': 4309, 'tags': [{'key': 'internal.span.format', 'type': 'string', 'value': 'proto'}], 'logs': [], 'processID': 'p1', 'warnings': None}, {'traceID': '397d8cae76d1c0a7', 'spanID': '35d3b28304dbc2f7', 'flags': 1, 'operationName': 'MongoInsertPost', 'references': [{'refType': 'CHILD_OF', 'traceID': '397d8cae76d1c0a7', 'spanID': '7969ca8bc2b0116e'}], 'startTime': 1557906198330524, 'duration': 785, 'tags': [{'key': 'internal.span.format', 'type': 'string', 'value': 'proto'}], 'logs': [], 'processID': 'p2', 'warnings': None}, {'traceID': '397d8cae76d1c0a7', 'spanID': '7969ca8bc2b0116e', 'flags': 1, 'operationName': 'StorePost', 'references': [{'refType': 'CHILD_OF', 'traceID': '397d8cae7
# ...

# %%
print(type(data))
print(data.keys())
content = data['data']
print(type(content))
print(len(content))
# Out:
# <class 'dict'>
# dict_keys(['data', 'total', 'limit', 'offset', 'errors'])
# <class 'list'>
# 1

# %%
print(content)
# Out:
# [{'traceID': '397d8cae76d1c0a7', 'spans': [{'traceID': '397d8cae76d1c0a7', 'spanID': '8dd50673f63ceb07', 'flags': 1, 'operationName': 'UploadUserMentions', 'references': [{'refType': 'CHILD_OF', 'traceID': '397d8cae76d1c0a7', 'spanID': '6304ae45b9ab3871'}], 'startTime': 1557906198321583, 'duration': 4309, 'tags': [{'key': 'internal.span.format', 'type': 'string', 'value': 'proto'}], 'logs': [], 'processID': 'p1', 'warnings': None}, {'traceID': '397d8cae76d1c0a7', 'spanID': '35d3b28304dbc2f7', 'flags': 1, 'operationName': 'MongoInsertPost', 'references': [{'refType': 'CHILD_OF', 'traceID': '397d8cae76d1c0a7', 'spanID': '7969ca8bc2b0116e'}], 'startTime': 1557906198330524, 'duration': 785, 'tags': [{'key': 'internal.span.format', 'type': 'string', 'value': 'proto'}], 'logs': [], 'processID': 'p2', 'warnings': None}, {'traceID': '397d8cae76d1c0a7', 'spanID': '7969ca8bc2b0116e', 'flags': 1, 'operationName': 'StorePost', 'references': [{'refType': 'CHILD_OF', 'traceID': '397d8cae76d1c0a7',
# ...

# %%
first = content[0]
print(type(first))
print(first.keys())
# Out:
# <class 'dict'>
# dict_keys(['traceID', 'spans', 'processes', 'warnings'])

# %%
print(first['traceID'])
# Out:
# 397d8cae76d1c0a7

# %%
print(first['spans'])
# Out:
# [{'traceID': '397d8cae76d1c0a7', 'spanID': '8dd50673f63ceb07', 'flags': 1, 'operationName': 'UploadUserMentions', 'references': [{'refType': 'CHILD_OF', 'traceID': '397d8cae76d1c0a7', 'spanID': '6304ae45b9ab3871'}], 'startTime': 1557906198321583, 'duration': 4309, 'tags': [{'key': 'internal.span.format', 'type': 'string', 'value': 'proto'}], 'logs': [], 'processID': 'p1', 'warnings': None}, {'traceID': '397d8cae76d1c0a7', 'spanID': '35d3b28304dbc2f7', 'flags': 1, 'operationName': 'MongoInsertPost', 'references': [{'refType': 'CHILD_OF', 'traceID': '397d8cae76d1c0a7', 'spanID': '7969ca8bc2b0116e'}], 'startTime': 1557906198330524, 'duration': 785, 'tags': [{'key': 'internal.span.format', 'type': 'string', 'value': 'proto'}], 'logs': [], 'processID': 'p2', 'warnings': None}, {'traceID': '397d8cae76d1c0a7', 'spanID': '7969ca8bc2b0116e', 'flags': 1, 'operationName': 'StorePost', 'references': [{'refType': 'CHILD_OF', 'traceID': '397d8cae76d1c0a7', 'spanID': 'a206848afe46ed43'}], 'startTim
# ...

# %%
print(first['processes'])
# Out:
# {'p1': {'serviceName': 'user-mention-service', 'tags': [{'key': 'hostname', 'type': 'string', 'value': 'user-mention-service'}, {'key': 'ip', 'type': 'string', 'value': '127.0.0.1'}, {'key': 'jaeger.version', 'type': 'string', 'value': 'C++-0.4.2'}]}, 'p10': {'serviceName': 'user-service', 'tags': [{'key': 'hostname', 'type': 'string', 'value': 'user-service'}, {'key': 'ip', 'type': 'string', 'value': '127.0.0.1'}, {'key': 'jaeger.version', 'type': 'string', 'value': 'C++-0.4.2'}]}, 'p11': {'serviceName': 'nginx-web-server', 'tags': [{'key': 'hostname', 'type': 'string', 'value': 'nginx-thrift'}, {'key': 'ip', 'type': 'string', 'value': '127.0.0.1'}, {'key': 'jaeger.version', 'type': 'string', 'value': 'C++-0.4.2'}]}, 'p12': {'serviceName': 'user-timeline-service', 'tags': [{'key': 'hostname', 'type': 'string', 'value': 'user-timeline-service'}, {'key': 'ip', 'type': 'string', 'value': '127.0.0.1'}, {'key': 'jaeger.version', 'type': 'string', 'value': 'C++-0.4.2'}]}, 'p2': {'serviceN
# ...

# %%
print(first['warnings'])
# Out:
# None

# %%
second = first['spans']
print(type(second))
print(len(second))
# Out:
# <class 'list'>
# 32

# %%
print(second[1])
# Out:
# {'traceID': '397d8cae76d1c0a7', 'spanID': '35d3b28304dbc2f7', 'flags': 1, 'operationName': 'MongoInsertPost', 'references': [{'refType': 'CHILD_OF', 'traceID': '397d8cae76d1c0a7', 'spanID': '7969ca8bc2b0116e'}], 'startTime': 1557906198330524, 'duration': 785, 'tags': [{'key': 'internal.span.format', 'type': 'string', 'value': 'proto'}], 'logs': [], 'processID': 'p2', 'warnings': None}

# %%
print(type(second[1]))
# Out:
# <class 'dict'>

# %%
print(second[1].keys())
# Out:
# dict_keys(['traceID', 'spanID', 'flags', 'operationName', 'references', 'startTime', 'duration', 'tags', 'logs', 'processID', 'warnings'])

# %%
for elem in second:
    print(elem.keys())
# Out:
# dict_keys(['traceID', 'spanID', 'flags', 'operationName', 'references', 'startTime', 'duration', 'tags', 'logs', 'processID', 'warnings'])
# dict_keys(['traceID', 'spanID', 'flags', 'operationName', 'references', 'startTime', 'duration', 'tags', 'logs', 'processID', 'warnings'])
# dict_keys(['traceID', 'spanID', 'flags', 'operationName', 'references', 'startTime', 'duration', 'tags', 'logs', 'processID', 'warnings'])
# dict_keys(['traceID', 'spanID', 'flags', 'operationName', 'references', 'startTime', 'duration', 'tags', 'logs', 'processID', 'warnings'])
# dict_keys(['traceID', 'spanID', 'flags', 'operationName', 'references', 'startTime', 'duration', 'tags', 'logs', 'processID', 'warnings'])
# dict_keys(['traceID', 'spanID', 'flags', 'operationName', 'references', 'startTime', 'duration', 'tags', 'logs', 'processID', 'warnings'])
# dict_keys(['traceID', 'spanID', 'flags', 'operationName', 'references', 'startTime', 'duration', 'tags', 'logs', 'processID', 'warnings'])
# ...

# %%
print(second[1]['references'])
# Out:
# [{'refType': 'CHILD_OF', 'traceID': '397d8cae76d1c0a7', 'spanID': '7969ca8bc2b0116e'}]

# %%
for elem in second:
    print(elem['traceID'])
# Out:
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7
# 397d8cae76d1c0a7

# %%
for elem in second:
    print(elem['spanID'])
# Out:
# 8dd50673f63ceb07
# 35d3b28304dbc2f7
# 7969ca8bc2b0116e
# 6304ae45b9ab3871
# 97146ed569d4e555
# 539c8d513a1cd27e
# 700b17a14e3a9bea
# 248aaa6c0378cdde
# a74ab6c184e22059
# 6f86267ede580702
# f3cc0977a79d6d09
# d5b11a3960911f2f
# 8b43aa1bb5d1c09f
# 3b131fa92a7d50ca
# 6ab5a7cff6246731
# a206848afe46ed43
# 2c48023dac7419f3
# fbeb7c745c18f3d9
# d73b74c1d5bdaa1b
# 68dc3e9ce6dd9627
# e69a3147e61574ba
# ef1d161731725801
# ff00a49164058a93
# 761fe114b79371d7
# 84e5d55ff0beb45d
# 7f2a7a10004cd79c
# 8bdf1f74bb9cd7d2
# 397d8cae76d1c0a7
# 15c04fa3feb96384
# 650be1a368f28098
# 7ff7862b6ed3ccad
# 8a0844f6a8608ab6

# %%
for elem in second:
    print(elem['operationName'])
# Out:
# UploadUserMentions
# MongoInsertPost
# StorePost
# UploadText
# RedisHashSet
# UploadMedia
# RedisHashSet
# UploadUrls
# RedisHashSet
# UploadUserMentions
# RedisHashSet
# UploadCreator
# RedisHashSet
# UploadUniqueId
# RedisHashSet
# UploadText
# UploadMedia
# MongoFindUser
# GetFollowers
# RedisGet
# RedisUpdate
# FanoutHomeTimelines
# UploadUrls
# UploadUniqueId
# UploadUserWithUserId
# ComposePost
# /wrk2-api/post/compose
# /wrk2-api/post/compose
# MongoInsert
# RedisUpdate
# WriteUserTimeline
# MongoFindUser

# %%
for elem in second:
    print(elem['processID'])
# Out:
# p1
# p2
# p2
# p3
# p4
# p4
# p4
# p4
# p4
# p4
# p4
# p4
# p4
# p4
# p4
# p4
# p5
# p6
# p6
# p6
# p7
# p7
# p8
# p9
# p10
# p11
# p11
# p11
# p12
# p12
# p12
# p12

# %%
for elem in second:
    print(elem['startTime'])
# Out:
# 1557906198321583
# 1557906198330524
# 1557906198330473
# 1557906198319795
# 1557906198319487
# 1557906198319453
# 1557906198322116
# 1557906198322085
# 1557906198323258
# 1557906198323237
# 1557906198320981
# 1557906198320954
# 1557906198321310
# 1557906198321298
# 1557906198326353
# 1557906198326256
# 1557906198319206
# 1557906198335099
# 1557906198333827
# 1557906198333849
# 1557906198336260
# 1557906198333344
# 1557906198320962
# 1557906198321123
# 1557906198320091
# 1557906198318752
# 1557906198318628
# 1557906198316000
# 1557906198332912
# 1557906198334120
# 1557906198331385
# 1557906198331423

# %%
print(type(second[0]['references']))
print(len(second[0]['references']))
print(type(second[0]['references'][0]))
print(second[0]['references'][0].keys())
# Out:
# <class 'list'>
# 1
# <class 'dict'>
# dict_keys(['refType', 'traceID', 'spanID'])

# %%
for elem in second:
    print(elem['references'][0]['spanID'])
# Out:
# 6304ae45b9ab3871
# 7969ca8bc2b0116e
# a206848afe46ed43
# 7f2a7a10004cd79c
# 539c8d513a1cd27e
# 2c48023dac7419f3
# 248aaa6c0378cdde
# ff00a49164058a93
# 6f86267ede580702
# 8dd50673f63ceb07
# d5b11a3960911f2f
# 84e5d55ff0beb45d
# 3b131fa92a7d50ca
# 761fe114b79371d7
# a206848afe46ed43
# 6304ae45b9ab3871
# 7f2a7a10004cd79c
# d73b74c1d5bdaa1b
# ef1d161731725801
# d73b74c1d5bdaa1b
# ef1d161731725801
# a206848afe46ed43
# 6304ae45b9ab3871
# 7f2a7a10004cd79c
# 7f2a7a10004cd79c
# 8bdf1f74bb9cd7d2
# 397d8cae76d1c0a7
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 for elem in second:
# ----> 2     print(elem['references'][0]['spanID'])
#
# IndexError: list index out of range

# %%
root = first['traceID']
for elem in second:
    spanID = elem['spanID']
    print(spanID)
    if spanID == root:
        print("I am root")
    else:
        print(elem['references'][0]['spanID'])
    print()
# Out:
# 8dd50673f63ceb07
# 6304ae45b9ab3871
#
# 35d3b28304dbc2f7
# 7969ca8bc2b0116e
#
# 7969ca8bc2b0116e
# a206848afe46ed43
#
# 6304ae45b9ab3871
# 7f2a7a10004cd79c
#
# 97146ed569d4e555
# 539c8d513a1cd27e
#
# 539c8d513a1cd27e
# 2c48023dac7419f3
#
# 700b17a14e3a9bea
# 248aaa6c0378cdde
#
# 248aaa6c0378cdde
# ff00a49164058a93
#
# a74ab6c184e22059
# 6f86267ede580702
#
# 6f86267ede580702
# 8dd50673f63ceb07
#
# f3cc0977a79d6d09
# d5b11a3960911f2f
#
# d5b11a3960911f2f
# 84e5d55ff0beb45d
#
# 8b43aa1bb5d1c09f
# 3b131fa92a7d50ca
#
# 3b131fa92a7d50ca
# 761fe114b79371d7
#
# 6ab5a7cff6246731
# a206848afe46ed43
#
# a206848afe46ed43
# 6304ae45b9ab3871
#
# 2c48023dac7419f3
# 7f2a7a10004cd79c
#
# fbeb7c745c18f3d9
# d73b74c1d5bdaa1b
#
# d73b74c1d5bdaa1b
# ef1d161731725801
#
# 68dc3e9ce6dd9627
# d73b74c1d5bdaa1b
#
# e69a3147e61574ba
# ef1d161731725801
#
# ef1d161731725801
# a206848afe46ed43
#
# ff00a49164058a93
# 6304ae45b9ab3871
#
# 761fe114b79371d7
# 7f2a7a10004cd79c
#
# 84e5d55ff0beb45d
# 7f2a7a10004cd79c
#
# ...

# %%
triplets = [] #head, link, tail ---> spanID, operationName, references_spanID
root = first['traceID']

for elem in second:
    head = elem['spanID']
    link = elem['operationName']
    tail = None
    if head == root:
        tail = 'root'
    else:
        tail = elem['references'][0]['spanID']
    triplets.append([head,link,tail])

# %%
triplets
# Out:
# [['8dd50673f63ceb07', 'UploadUserMentions', '6304ae45b9ab3871'],
#  ['35d3b28304dbc2f7', 'MongoInsertPost', '7969ca8bc2b0116e'],
#  ['7969ca8bc2b0116e', 'StorePost', 'a206848afe46ed43'],
#  ['6304ae45b9ab3871', 'UploadText', '7f2a7a10004cd79c'],
#  ['97146ed569d4e555', 'RedisHashSet', '539c8d513a1cd27e'],
#  ['539c8d513a1cd27e', 'UploadMedia', '2c48023dac7419f3'],
#  ['700b17a14e3a9bea', 'RedisHashSet', '248aaa6c0378cdde'],
#  ['248aaa6c0378cdde', 'UploadUrls', 'ff00a49164058a93'],
#  ['a74ab6c184e22059', 'RedisHashSet', '6f86267ede580702'],
#  ['6f86267ede580702', 'UploadUserMentions', '8dd50673f63ceb07'],
#  ['f3cc0977a79d6d09', 'RedisHashSet', 'd5b11a3960911f2f'],
#  ['d5b11a3960911f2f', 'UploadCreator', '84e5d55ff0beb45d'],
#  ['8b43aa1bb5d1c09f', 'RedisHashSet', '3b131fa92a7d50ca'],
#  ['3b131fa92a7d50ca', 'UploadUniqueId', '761fe114b79371d7'],
#  ['6ab5a7cff6246731', 'RedisHashSet', 'a206848afe46ed43'],
#  ['a206848afe46ed43', 'UploadText', '6304ae45b9ab3871'],
# ...

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a graph object
G = nx.Graph()

# Add the edges from the PyKEEN dataset
for triplet in triplets:
    G.add_edge(triplet[0], triplet[2], label=triplet[1])

# Use NetworkX's built-in drawing function to visualize the graph
nx.draw(G)

# Import matplotlib library to show the graph
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a graph object
G = nx.Graph()

# Add the edges from the PyKEEN dataset
for triplet in triplets:
    G.add_edge(triplet[0], triplet[2], label=triplet[1])

node_size = 30
# Use NetworkX's built-in drawing function to visualize the graph
# nx.draw(G)
pos = nx.spring_layout(G,seed = 42)
nx.draw_networkx_edges(G,pos,arrowstyle="-|>",arrowsize=10,width=1,arrows=True,node_size=node_size)
nx.draw_networkx_nodes(G,pos,node_size = node_size)

# Import matplotlib library to show the graph
plt.show()

# %%
import matplotlib as mpl

seed = 42  # Seed random number generators for reproducibility
pos = nx.spring_layout(G, seed=seed)

node_sizes = [3 + 10 * i for i in range(len(G))]
M = G.number_of_edges()
edge_colors = range(2, M + 2)
edge_alphas = [(5 + i) / (M + 4) for i in range(M)]
cmap = plt.cm.plasma

nodes = nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color="indigo")
edges = nx.draw_networkx_edges(
    G,
    pos,
    node_size=node_sizes,
    arrowstyle="->",
    arrowsize=10,
    edge_color=edge_colors,
    edge_cmap=cmap,
    width=2,
)
# set alpha value for each edge
for i in range(M):
    edges[i].set_alpha(edge_alphas[i])

pc = mpl.collections.PatchCollection(edges, cmap=cmap)
pc.set_array(edge_colors)

ax = plt.gca()
ax.set_axis_off()
# plt.colorbar(pc, ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 25
#      23 # set alpha value for each edge
#      24 for i in range(M):
# ---> 25     edges[i].set_alpha(edge_alphas[i])
#      27 pc = mpl.collections.PatchCollection(edges, cmap=cmap)
#      28 pc.set_array(edge_colors)
#
# TypeError: 'LineCollection' object is not subscriptable

# %%
def draw_graph(path):
    import json
  
    # Opening JSON file
    f = open(path)

    # returns JSON object as 
    # a dictionary
    data = json.load(f)

    # Closing file
    f.close()
    content = data['data']
    first = content[0]
    second = first['spans']

    triplets = [] #head, link, tail ---> spanID, operationName, references_spanID
    root = first['traceID']

    for elem in second:
        head = elem['spanID']
        link = elem['operationName']
        tail = None
        if head == root:
            tail = root
        else:
            tail = elem['references'][0]['spanID']
        triplets.append([head,link,tail])
        
    import networkx as nx
    import matplotlib.pyplot as plt

    # Create a graph object
    G = nx.Graph()
        
    for triplet in triplets:
        G.add_edge(triplet[0], triplet[2], label=triplet[1])

    node_size = 30
    # Use NetworkX's built-in drawing function to visualize the graph
    # nx.draw(G)
    pos = nx.spring_layout(G,seed = 42)
    nx.draw_networkx_edges(G,pos,arrowstyle="-|>",arrowsize=10,width=1,arrows=True,node_size=node_size)
    nx.draw_networkx_nodes(G,pos,node_size = node_size)

    # Import matplotlib library to show the graph
    plt.show()

# %%
draw_graph('socialNetwork/traces/397d8cae76d1c0a7.json')

# %%
draw_graph('socialNetwork/traces/944c8368543f21fb.json')

# %%
draw_graph('socialNetwork/traces/f78363e3cc31c563.json')

# %%
def draw_tree(path):
    import json
  
    # Opening JSON file
    f = open(path)

    # returns JSON object as 
    # a dictionary
    data = json.load(f)

    # Closing file
    f.close()
    content = data['data']
    first = content[0]
    second = first['spans']

    triplets = [] #head, link, tail ---> spanID, operationName, references_spanID
    root = first['traceID']
    print("root, ",root)
    for elem in second:
        head = elem['spanID']
        link = elem['operationName']
        tail = None
        if head == root:
            tail = 'root'
        else:
            tail = elem['references'][0]['spanID']
#         triplets.append([head,link,tail])
            triplets.append([head,link,tail])

        
    from anytree import Node, RenderTree
    treeDict = {}
    rootNode = Node(root)
    treeDict[root] = rootNode
    
    i = 0
    while len(triplets)>0 and i<len(triplets):
        try:
            tempNode = treeDict[triplets[i][2]]
            newNode = Node(triplets[i][0],parent = tempNode)
            treeDict[triplets[i][0]] = newNode
            triplets.pop(i)
            i = 0
        except:
            i +=1
    print("Left elements: ", len(triplets))
    from anytree.exporter import DotExporter
    DotExporter(rootNode).to_picture("rootNode.png")
    for pre, fill, node in RenderTree(rootNode):
        print("%s%s" % (pre, node.name))

# %%
draw_graph('socialNetwork/traces/397d8cae76d1c0a7.json')

# %%
draw_tree('socialNetwork/traces/397d8cae76d1c0a7.json')
# Out:
# root,  397d8cae76d1c0a7
# Left elements:  0
# 397d8cae76d1c0a7
# └── 8bdf1f74bb9cd7d2
#     └── 7f2a7a10004cd79c
#         ├── 6304ae45b9ab3871
#         │   ├── 8dd50673f63ceb07
#         │   │   └── 6f86267ede580702
#         │   │       └── a74ab6c184e22059
#         │   ├── a206848afe46ed43
#         │   │   ├── 7969ca8bc2b0116e
#         │   │   │   └── 35d3b28304dbc2f7
#         │   │   ├── 6ab5a7cff6246731
#         │   │   ├── ef1d161731725801
#         │   │   │   ├── d73b74c1d5bdaa1b
#         │   │   │   │   ├── fbeb7c745c18f3d9
#         │   │   │   │   └── 68dc3e9ce6dd9627
#         │   │   │   └── e69a3147e61574ba
#         │   │   └── 7ff7862b6ed3ccad
#         │   │       ├── 15c04fa3feb96384
#         │   │       ├── 650be1a368f28098
#         │   │       └── 8a0844f6a8608ab6
#         │   └── ff00a49164058a93
#         │       └── 248aaa6c0378cdde
#         │           └── 700b17a14e3a9bea
#         ├── 2c48023dac7419f3
#         │   └── 539c8d513a1cd27e
# ...

# %%
for elem in second:
    print(hash(elem['spanID']))
# Out:
# 2320607190449486926
# -2004561522706322683
# 858648573262204161
# 3930945892919373867
# -824828883072791979
# 5908099196859533906
# -112997944818534752
# -1352252918493537283
# 1945543525750603639
# 7387428311178546398
# -1091319352487571959
# 887989574063800486
# -8174870110201525776
# 44393771037236615
# -5327314348358132087
# -8634428456141043852
# 1136824152448272267
# -1541533486303810304
# 5498671125069692492
# -7225509749086534364
# -1758262021423013195
# 6382670550302857580
# -3616846247672669673
# 4812252229471360773
# -2896041407494714821
# 2244891731405045700
# -8811856266417498010
# 7151782284663410814
# -783614162676127462
# -5073357468372844761
# 5070275074132501098
# 6903368630803691181

# %%
def draw_graph_hashed(path):
    import json
  
    # Opening JSON file
    f = open(path)

    # returns JSON object as 
    # a dictionary
    data = json.load(f)

    # Closing file
    f.close()
    content = data['data']
    first = content[0]
    second = first['spans']

    triplets = [] #head, link, tail ---> spanID, operationName, references_spanID
    root = first['traceID']

    for elem in second:
        head = elem['spanID']
        link = elem['operationName']
        tail = None
        if head == root:
            tail = root
        else:
            tail = elem['references'][0]['spanID']
        triplets.append([hash(head),link,hash(tail)])
        
    import networkx as nx
    import matplotlib.pyplot as plt

    # Create a graph object
    G = nx.Graph()
    for triplet in triplets:
        G.add_node(triplet[0])
        
    for triplet in triplets:
        G.add_edge(triplet[0], triplet[2], label=triplet[1])

    node_size = 30
    # Use NetworkX's built-in drawing function to visualize the graph
    # nx.draw(G)
    pos = nx.spring_layout(G,seed = 42)
    nx.draw_networkx_edges(G,pos,arrowstyle="-|>",arrowsize=10,width=1,arrows=True,node_size=node_size)
    nx.draw_networkx_nodes(G,pos,node_size = node_size)

    # Import matplotlib library to show the graph
    plt.show()

# %%
draw_graph_hashed('socialNetwork/traces/397d8cae76d1c0a7.json')

# %%
def draw_tree_graph(path):
    import json
  
    # Opening JSON file
    f = open(path)

    # returns JSON object as 
    # a dictionary
    data = json.load(f)

    # Closing file
    f.close()
    content = data['data']
    first = content[0]
    second = first['spans']

    triplets = [] #head, link, tail ---> spanID, operationName, references_spanID
    root = first['traceID']
    print("root, ",root)
    for elem in second:
        head = elem['spanID']
        link = elem['operationName']
        tail = None
        if head == root:
            tail = 'root'
        else:
            tail = elem['references'][0]['spanID']
#         triplets.append([head,link,tail])
            triplets.append([head,link,tail])

        
    from anytree import Node, RenderTree
    treeDict = {}
    rootNode = Node(root)
    treeDict[root] = rootNode
    
    i = 0
    while len(triplets)>0 and i<len(triplets):
        try:
            tempNode = treeDict[triplets[i][2]]
            newNode = Node(triplets[i][0],parent = tempNode)
            treeDict[triplets[i][0]] = newNode
            triplets.pop(i)
            i = 0
        except:
            i +=1
    print("Left elements: ", len(triplets))
    from anytree.exporter import DotExporter
    for pre, fill, node in RenderTree(rootNode):
        print("%s%s" % (pre, node.name))
    from anytree import PreOrderIter
    node_list = [node.name for node in PreOrderIter(rootNode)]
    
    import networkx as nx
    import matplotlib.pyplot as plt

    # Create a graph object
    G = nx.Graph()
    for node in node_list:
        G.add_node(node)
    for elem in second:
        head = elem['spanID']
        link = elem['operationName']
        tail = None
        if head == root:
            tail = root
        else:
            tail = elem['references'][0]['spanID']
        triplets.append([head,link,tail])
    for triplet in triplets:
        G.add_edge(triplet[0], triplet[2], label=triplet[1])

    node_size = 30
    # Use NetworkX's built-in drawing function to visualize the graph
    # nx.draw(G)
    pos = nx.spring_layout(G,seed = 42)
    nx.draw_networkx_edges(G,pos,arrowstyle="-|>",arrowsize=10,width=1,arrows=True,node_size=node_size)
    nx.draw_networkx_nodes(G,pos,node_size = node_size)

    # Import matplotlib library to show the graph
    plt.show()

# %%
draw_tree_graph('socialNetwork/traces/397d8cae76d1c0a7.json')
# Out:
# root,  397d8cae76d1c0a7
# Left elements:  0
# 397d8cae76d1c0a7
# └── 8bdf1f74bb9cd7d2
#     └── 7f2a7a10004cd79c
#         ├── 6304ae45b9ab3871
#         │   ├── 8dd50673f63ceb07
#         │   │   └── 6f86267ede580702
#         │   │       └── a74ab6c184e22059
#         │   ├── a206848afe46ed43
#         │   │   ├── 7969ca8bc2b0116e
#         │   │   │   └── 35d3b28304dbc2f7
#         │   │   ├── 6ab5a7cff6246731
#         │   │   ├── ef1d161731725801
#         │   │   │   ├── d73b74c1d5bdaa1b
#         │   │   │   │   ├── fbeb7c745c18f3d9
#         │   │   │   │   └── 68dc3e9ce6dd9627
#         │   │   │   └── e69a3147e61574ba
#         │   │   └── 7ff7862b6ed3ccad
#         │   │       ├── 15c04fa3feb96384
#         │   │       ├── 650be1a368f28098
#         │   │       └── 8a0844f6a8608ab6
#         │   └── ff00a49164058a93
#         │       └── 248aaa6c0378cdde
#         │           └── 700b17a14e3a9bea
#         ├── 2c48023dac7419f3
#         │   └── 539c8d513a1cd27e
# ...

# %%
def draw_tree_graph_hierarchical(path):
    import json
  
    # Opening JSON file
    f = open(path)

    # returns JSON object as 
    # a dictionary
    data = json.load(f)

    # Closing file
    f.close()
    content = data['data']
    first = content[0]
    second = first['spans']

    triplets = [] #head, link, tail ---> spanID, operationName, references_spanID
    root = first['traceID']
    print("root, ",root)
    for elem in second:
        head = elem['spanID']
        link = elem['operationName']
        tail = None
        if head == root:
            tail = 'root'
        else:
            tail = elem['references'][0]['spanID']
#         triplets.append([head,link,tail])
            triplets.append([head,link,tail])

        
    from anytree import Node, RenderTree
    treeDict = {}
    rootNode = Node(root)
    treeDict[root] = rootNode
    
    i = 0
    while len(triplets)>0 and i<len(triplets):
        try:
            tempNode = treeDict[triplets[i][2]]
            newNode = Node(triplets[i][0],parent = tempNode)
            treeDict[triplets[i][0]] = newNode
            triplets.pop(i)
            i = 0
        except:
            i +=1
    print("Left elements: ", len(triplets))
    from anytree.exporter import DotExporter
#     for pre, fill, node in RenderTree(rootNode):
#         print("%s%s" % (pre, node.name))
    from anytree import LevelOrderGroupIter
    level_list = [[node.name for node in children] for children in LevelOrderGroupIter(rootNode, stop=lambda n: n == None)]
#     print(level_list)
    import networkx as nx
    import matplotlib.pyplot as plt

    # Create a graph object
    G = nx.Graph()
    for i in range(len(level_list)):
        for j in range(len(level_list[i])):
            G.add_node(level_list[i][j],layer = i)
    for elem in second:
        head = elem['spanID']
        link = elem['operationName']
        tail = None
        if head == root:
            tail = root
        else:
            tail = elem['references'][0]['spanID']
            triplets.append([head,link,tail])
    for triplet in triplets:
        G.add_edge(triplet[0], triplet[2], label=triplet[1])

    node_size = 30
    # Use NetworkX's built-in drawing function to visualize the graph
    # nx.draw(G)
    pos = nx.multipartite_layout(G,subset_key="layer")
    nx.draw_networkx_edges(G,pos,arrowstyle="-|>",arrowsize=10,width=1,arrows=True,node_size=node_size)
    nx.draw_networkx_nodes(G,pos,node_size = node_size)

    # Import matplotlib library to show the graph
    plt.show()

# %%
draw_tree_graph_hierarchical('socialNetwork/traces/397d8cae76d1c0a7.json')
# Out:
# root,  397d8cae76d1c0a7
# Left elements:  0

# %%
draw_tree_graph_hierarchical('socialNetwork/traces/944c8368543f21fb.json')
# Out:
# root,  944c8368543f21fb
# Left elements:  0

# %%
draw_tree_graph_hierarchical('socialNetwork/traces/f78363e3cc31c563.json')
# Out:
# root,  f78363e3cc31c563
# Left elements:  0
